# %% [markdown]
# # Sentiment Analysis

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json

# %% [markdown]
# ### Natural Language Processing
#
# We begin by parsing the text and pre-processing it to prepare it for Latent Dirichlet Analysis. This step is meant to remove stopwords and identify nouns and adjectives.

# %%
from pattern.en import parse
from pattern.en import pprint
from pattern.vector import stem, PORTER, LEMMA
punctuation = list('.,;:!?()[]{}`''\"@#$^&*+-|=~_')

# %%
from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS

# %% [markdown]
# ### Financial Vocabulary and Adjectives
#
# **TO CHANGE: WE ARE GOING TO DO THIS FOR NAIVE BAYES PART!!!!!!!!**
# Since our analysis will focus on financial information and so will be heavily reliant on the "sentiments" of vocabulary from this field, we can enhance our analysis by using a financial dictionary. The **Loughran-McDonald 2014 Master Dictionary** is a good tool to use as it includes words that often appear in 10-K documents. The dictionary includes 9 sentiment categories, including "negative", "positive", "uncertainty", "litigious", "modal", and "constraining", among others.

# %% [markdown]
# Ther are two main modifications to getting the parts-of-speech of the FOMC statements. Firstly, the statements are full of phrases like "growth is expected to continue--given the current data--at a moderate pace". The two hyphens should be treated as a space. Secondly, we must ignore the HTML code at the beginning of the statements.

# %%
regex1=re.compile('[,]+(?![0-9])') # For situations like "window,document" => "window, document" becomes two words

# %%
import re
regex1=re.compile(r"\-{2,}")

def modified_get_parts(thetext):
    thetext=re.sub(regex1, ', ', thetext)
    nouns=[]
    descriptives=[]
    for i,sentence in enumerate(parse(thetext, tokenize=True, lemmata=True).split()):
        # Skip the first three sentences that include the HTML
        nouns.append([])
        descriptives.append([])
        if i in [0]:
            continue
        for token in sentence:
            #print token
            if len(token[4]) >0:
                if token[1] in ['JJ', 'JJR', 'JJS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    # We check for longer words as a method to filter out the long HTML code at the beginning of each document
                    if len(token[4]) > 20:
                        continue
                    descriptives[i].append(token[4])
                elif token[1] in ['NN', 'NNS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    # We check for longer words as a method to filter out the long HTML code at the beginning of each document
                    if len(token[4]) > 20:
                        continue
                    nouns[i].append(token[4])
    out=zip(nouns, descriptives)
    nouns2=[]
    descriptives2=[]
    for n,d in out:
        if len(n)!=0 and len(d)!=0:
            nouns2.append(n)
            descriptives2.append(d)
    return nouns2, descriptives2

# %%
thetext=re.sub('[,]+(?![0-9])', ', ', "hello,right")
print thetext
# Out:
# hello, right

# %%
get_parts("In determining how long to maintain this target range, the Committee will assess progress--both realized and expected--toward its objectives of maximum employment and 2 percent inflation.")
# Out:
# ([[u'target',
#    u'range',
#    u'progress',
#    u'objective',
#    u'employment',
#    u'percent',
#    u'inflation']],
#  [[u'long', u'maximum']])

# %% [markdown]
# We load in the fomc_mins dictionary that we created in the Scraping.ipynb iPython Notebook.

# %%
with open("fomc_mins.json", "rb") as infile:
    fomc_mins = json.load(infile)

# %%
modified_get_parts(fomc_mins['20110921'])
# Out:
# ([[u'meeting', u'governor', u'office', u'governor', u'present'],
#   [u'member'],
#   [u'development', u'development', u'market', u'period'],
#   [u'market',
#    u'operation',
#    u'reinvestment',
#    u'security',
#    u'payment',
#    u'holding',
#    u'agency',
#    u'debt',
#    u'security'],
#   [u'vote', u'transaction', u'period'],
#   [u'staff',
#    u'presentation',
#    u'staff',
#    u'presentation',
#    u'tool',
#    u'policy',
#    u'framework',
#    u'policy',
#    u'accommodation',
#    u'recovery'],
#   [u'presentation',
#    u'option',
#    u'size',
#    u'composition',
#    u'portfolio',
#    u'reinvestment',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'portfolio',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'asset',
#    u'purchase',
#    u'program'],
#   [u'option', u'payment', u'holding', u'agency', u'security', u'security'],
#   [u'option',
#    u'security',
#    u'security',
#    u'transaction',
#    u'maturity',
#    u'portfolio',
#    u'size',
#    u'balance',
#    u'sheet',
#    u'level',
#    u'reserve',
#    u'balance',
#    u'term'],
#   [u'option',
#    u'security',
#    u'size',
#    u'balance',
#    u'sheet',
#    u'supply',
#    u'reserve',
#    u'balance'],
#   [u'staff',
#    u'set',
#    u'option',
#    u'public',
#    u'objective',
#    u'mandate',
#    u'guidance',
#    u'future',
#    u'stance',
#    u'policy'],
#   [u'option', u'way', u'condition', u'level', u'rate'],
#   [u'staff',
#    u'presentation',
#    u'implication',
#    u'rate',
#    u'reserve',
#    u'institution',
#    u'account',
#    u'rate'],
#   [u'participant',
#    u'range',
#    u'view',
#    u'efficacy',
#    u'policy',
#    u'tool',
#    u'size',
#    u'composition',
#    u'balance',
#    u'sheet'],
#   [u'policy',
#    u'policy',
#    u'accommodation',
#    u'rate',
#    u'condition',
#    u'time',
#    u'reduction',
#    u'fund',
#    u'rate'],
#   [u'number',
#    u'effect',
#    u'activity',
#    u'environment',
#    u'balance',
#    u'sheet',
#    u'deleveraging',
#    u'credit',
#    u'constraint',
#    u'household',
#    u'business',
#    u'uncertainty',
#    u'outlook'],
#   [u'number',
#    u'participant',
#    u'asset',
#    u'purchase',
#    u'tool',
#    u'option',
#    u'event',
#    u'policy',
#    u'action',
#    u'recovery'],
#   [u'asset',
#    u'purchase',
#    u'expansion',
#    u'balance',
#    u'sheet',
#    u'inflation',
#    u'inflation',
#    u'expectation',
#    u'activity',
#    u'tool',
#    u'circumstance',
#    u'risk',
#    u'deflation'],
#   [u'implication',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'asset',
#    u'purchase',
#    u'program',
#    u'participant',
#    u'proportion',
#    u'stock',
#    u'security',
#    u'portfolio',
#    u'result',
#    u'deterioration',
#    u'market',
#    u'functioning'],
#   [u'number',
#    u'participant',
#    u'purchase',
#    u'agency',
#    u'couple',
#    u'participant',
#    u'action',
#    u'benefit',
#    u'form',
#    u'credit',
#    u'allocation'],
#   [u'participant',
#    u'step',
#    u'transparency',
#    u'policy',
#    u'information',
#    u'policy',
#    u'objective',
#    u'factor',
#    u'policy',
#    u'decision'],
#   [u'participant',
#    u'statement',
#    u'policy',
#    u'objective',
#    u'linkage',
#    u'objective',
#    u'approach',
#    u'stance',
#    u'policy',
#    u'medium',
#    u'run'],
#   [u'number',
#    u'participant',
#    u'concern',
#    u'issue',
#    u'objective',
#    u'unemployment',
#    u'rate',
#    u'measure',
#    u'labor',
#    u'market',
#    u'condition',
#    u'equilibrium',
#    u'level',
#    u'measure',
#    u'factor',
#    u'time',
#    u'uncertainty'],
#   [u'contrast', u'participant', u'level', u'inflation', u'policy'],
#   [u'consensus',
#    u'statement',
#    u'objective',
#    u'explanation',
#    u'public',
#    u'objective',
#    u'framework'],
#   [u'participant',
#    u'advantage',
#    u'conditionality',
#    u'guidance',
#    u'information',
#    u'condition',
#    u'guidance'],
#   [u'step',
#    u'guidance',
#    u'likelihood',
#    u'market',
#    u'information',
#    u'way',
#    u'policy',
#    u'goal'],
#   [u'participant',
#    u'risk',
#    u'statement',
#    u'condition',
#    u'guidance',
#    u'statement',
#    u'objective'],
#   [u'risk', u'misinterpretation', u'communication'],
#   [u'number',
#    u'participant',
#    u'projection',
#    u'information',
#    u'view',
#    u'objective',
#    u'evolution',
#    u'policy'],
#   [u'participant', u'rate', u'benefit', u'cost'],
#   [u'number',
#    u'participant',
#    u'reduction',
#    u'money',
#    u'market',
#    u'rate',
#    u'bank',
#    u'lending'],
#   [u'rate', u'intention', u'fund', u'rate'],
#   [u'participant',
#    u'rate',
#    u'market',
#    u'rate',
#    u'instrument',
#    u'banking',
#    u'institution'],
#   [u'change',
#    u'deposit',
#    u'insurance',
#    u'assessment',
#    u'effect',
#    u'return',
#    u'bank',
#    u'reserve',
#    u'balance'],
#   [u'participant',
#    u'concern',
#    u'rate',
#    u'disruption',
#    u'money',
#    u'market',
#    u'intermediation',
#    u'credit',
#    u'magnitude',
#    u'effect',
#    u'advance'],
#   [u'addition',
#    u'fund',
#    u'market',
#    u'contract',
#    u'result',
#    u'fund',
#    u'rate',
#    u'rate'],
#   [u'participant',
#    u'information',
#    u'effect',
#    u'reduction',
#    u'rate',
#    u'order',
#    u'judge',
#    u'usefulness',
#    u'policy',
#    u'tool',
#    u'environment'],
#   [u'information',
#    u'meeting',
#    u'activity',
#    u'pace',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'price',
#    u'inflation',
#    u'year',
#    u'measure',
#    u'inflation',
#    u'expectation',
#    u'stable'],
#   [u'employment',
#    u'job',
#    u'gain',
#    u'effect',
#    u'strike',
#    u'communication',
#    u'worker',
#    u'month'],
#   [u'employment', u'state', u'government', u'budget', u'condition'],
#   [u'unemployment',
#    u'rate',
#    u'percent',
#    u'unemployment',
#    u'share',
#    u'worker',
#    u'time',
#    u'reason'],
#   [u'claim',
#    u'unemployment',
#    u'insurance',
#    u'net',
#    u'week',
#    u'indicator',
#    u'firm',
#    u'hiring',
#    u'plan',
#    u'month'],
#   [u'contrast',
#    u'pace',
#    u'factory',
#    u'production',
#    u'industry',
#    u'supply',
#    u'disruption'],
#   [u'vehicle',
#    u'assembly',
#    u'quarter',
#    u'indicator',
#    u'manufacturing',
#    u'activity',
#    u'diffusion',
#    u'index',
#    u'order',
#    u'manufacturing',
#    u'survey',
#    u'level',
#    u'gain',
#    u'output',
#    u'month'],
#   [u'consumer',
#    u'spending',
#    u'gain',
#    u'rebound',
#    u'motor',
#    u'vehicle',
#    u'purchase',
#    u'level',
#    u'spring',
#    u'availability',
#    u'model'],
#   [u'sale',
#    u'purchase',
#    u'motor',
#    u'vehicle',
#    u'outlet',
#    u'sale',
#    u'light',
#    u'motor',
#    u'vehicle'],
#   [u'income', u'gain', u'income', u'rise', u'consumer', u'price'],
#   [u'sentiment', u'downbeat'],
#   [u'activity',
#    u'housing',
#    u'market',
#    u'demand',
#    u'uncertainty',
#    u'home',
#    u'price',
#    u'credit',
#    u'condition',
#    u'mortgage',
#    u'construction',
#    u'loan',
#    u'inventory',
#    u'property'],
#   [u'permit', u'home', u'level', u'middle', u'year'],
#   [u'sale', u'home', u'month', u'home', u'price'],
#   [u'business', u'spending', u'equipment', u'software'],
#   [u'shipment',
#    u'capital',
#    u'good',
#    u'business',
#    u'purchase',
#    u'motor',
#    u'vehicle'],
#   [u'order',
#    u'capital',
#    u'good',
#    u'shipment',
#    u'backlog',
#    u'order',
#    u'gain',
#    u'outlay',
#    u'business',
#    u'equipment',
#    u'month'],
#   [u'contrast',
#    u'survey',
#    u'measure',
#    u'business',
#    u'condition',
#    u'sentiment',
#    u'level'],
#   [u'business',
#    u'expenditure',
#    u'office',
#    u'building',
#    u'month',
#    u'outlay',
#    u'level',
#    u'vacancy',
#    u'rate',
#    u'credit',
#    u'condition',
#    u'construction',
#    u'loan'],
#   [u'business',
#    u'inventory',
#    u'pace',
#    u'motor',
#    u'vehicle',
#    u'inventory',
#    u'production',
#    u'disruption',
#    u'accumulation',
#    u'sector'],
#   [u'government',
#    u'purchase',
#    u'month',
#    u'defense',
#    u'expenditure',
#    u'level',
#    u'year'],
#   [u'state',
#    u'level',
#    u'government',
#    u'purchase',
#    u'payroll',
#    u'construction',
#    u'spending'],
#   [u'trade', u'deficit'],
#   [u'export', u'supply', u'capital', u'good'],
#   [u'import',
#    u'month',
#    u'decline',
#    u'petroleum',
#    u'product',
#    u'price',
#    u'volume',
#    u'gain',
#    u'product',
#    u'supply',
#    u'chain',
#    u'disruption'],
#   [u'data', u'export', u'product', u'growth', u'quarter'],
#   [u'energy',
#    u'price',
#    u'decline',
#    u'month',
#    u'increase',
#    u'food',
#    u'price',
#    u'pace',
#    u'year'],
#   [u'consumer', u'price', u'index', u'food', u'energy', u'rate', u'quarter'],
#   [u'inflation',
#    u'expectation',
#    u'survey',
#    u'consumer',
#    u'level',
#    u'spring',
#    u'inflation',
#    u'expectation',
#    u'stable'],
#   [u'measure',
#    u'labor',
#    u'compensation',
#    u'wage',
#    u'increase',
#    u'margin',
#    u'slack',
#    u'labor',
#    u'market'],
#   [u'earning', u'employee', u'gain', u'net', u'rate', u'increase', u'month'],
#   [u'growth', u'quarter'],
#   [u'growth', u'activity', u'market', u'economy'],
#   [u'decline', u'export'],
#   [u'downshift', u'growth', u'supply', u'chain', u'disruption', u'earthquake'],
#   [u'disruption',
#    u'rebound',
#    u'growth',
#    u'quarter',
#    u'indicator',
#    u'gain',
#    u'activity'],
#   [u'intensification',
#    u'stress',
#    u'area',
#    u'measure',
#    u'consumer',
#    u'business',
#    u'confidence',
#    u'indicator',
#    u'manufacturing',
#    u'activity',
#    u'region'],
#   [u'market',
#    u'economy',
#    u'slowing',
#    u'growth',
#    u'activity',
#    u'export',
#    u'production',
#    u'indicator',
#    u'manufacturing',
#    u'activity'],
#   [u'inflation',
#    u'quarter',
#    u'effect',
#    u'increase',
#    u'food',
#    u'energy',
#    u'price'],
#   [u'increase',
#    u'food',
#    u'price',
#    u'consumer',
#    u'price',
#    u'inflation',
#    u'economy'],
#   [u'market', u'period', u'investor', u'news', u'activity'],
#   [u'fluctuation',
#    u'investor',
#    u'level',
#    u'concern',
#    u'prospect',
#    u'market',
#    u'volatility'],
#   [u'path', u'fund', u'rate', u'period'],
#   [u'investor',
#    u'guidance',
#    u'statement',
#    u'condition',
#    u'level',
#    u'fund',
#    u'rate',
#    u'mid-2013'],
#   [u'week',
#    u'datum',
#    u'expectation',
#    u'accommodation',
#    u'expectation',
#    u'concern',
#    u'situation',
#    u'decline',
#    u'yield'],
#   [u'reaction',
#    u'outlook',
#    u'measure',
#    u'inflation',
#    u'compensation',
#    u'year',
#    u'year',
#    u'security',
#    u'end',
#    u'range',
#    u'year'],
#   [u'equity',
#    u'price',
#    u'institution',
#    u'credit',
#    u'default',
#    u'swap',
#    u'spread'],
#   [u'decline', u'equity', u'price', u'increase', u'spread', u'institution'],
#   [u'bank',
#    u'week',
#    u'dollar',
#    u'funding',
#    u'term',
#    u'condition',
#    u'institution',
#    u'market'],
#   [u'funding',
#    u'market',
#    u'term',
#    u'financing',
#    u'institution',
#    u'agreement',
#    u'agency',
#    u'collateral'],
#   [u'strain',
#    u'period',
#    u'market',
#    u'repurchase',
#    u'agreement',
#    u'lower-quality',
#    u'collateral'],
#   [u'response',
#    u'dollar',
#    u'funding',
#    u'pressure',
#    u'bank',
#    u'jurisdiction',
#    u'dollar',
#    u'loan',
#    u'period',
#    u'month',
#    u'dollar',
#    u'loan',
#    u'period',
#    u'program',
#    u'dollar',
#    u'loan'],
#   [u'stock',
#    u'price',
#    u'index',
#    u'net',
#    u'meeting',
#    u'decline',
#    u'day',
#    u'meeting'],
#   [u'public',
#    u'equity',
#    u'issuance',
#    u'firm',
#    u'week',
#    u'number',
#    u'public',
#    u'offering',
#    u'market',
#    u'volatility'],
#   [u'spread',
#    u'yield',
#    u'investment',
#    u'bond',
#    u'comparable-maturity',
#    u'security',
#    u'period',
#    u'level',
#    u'registered',
#    u'bid',
#    u'price',
#    u'market',
#    u'loan'],
#   [u'evidence', u'debt', u'market', u'firm'],
#   [u'bond', u'issuance', u'firm', u'halt', u'volume', u'loan', u'investor'],
#   [u'bond', u'issuance', u'company', u'spread', u'paper'],
#   [u'term',
#    u'dealer',
#    u'change',
#    u'credit',
#    u'term',
#    u'class',
#    u'counterparty',
#    u'month'],
#   [u'respondent', u'use', u'leverage', u'fund', u'period'],
#   [u'dealer', u'client', u'willingness', u'risk', u'fund'],
#   [u'financing', u'condition', u'estate'],
#   [u'issuance', u'security', u'investor', u'compensation', u'risk'],
#   [u'price',
#    u'type',
#    u'property',
#    u'decline',
#    u'vacancy',
#    u'rate',
#    u'quarter'],
#   [u'rate',
#    u'loan',
#    u'level',
#    u'delinquency',
#    u'rate',
#    u'estate',
#    u'loan',
#    u'bank',
#    u'quarter'],
#   [u'yield',
#    u'mortgage',
#    u'rate',
#    u'net',
#    u'period',
#    u'level',
#    u'spread',
#    u'yield',
#    u'security'],
#   [u'mortgage',
#    u'rate',
#    u'refinancing',
#    u'activity',
#    u'underwriting',
#    u'standard',
#    u'level',
#    u'home',
#    u'equity',
#    u'household'],
#   [u'mortgage',
#    u'debt',
#    u'quarter',
#    u'volume',
#    u'mortgage',
#    u'application',
#    u'home',
#    u'quarter'],
#   [u'mortgage',
#    u'delinquency',
#    u'rate',
#    u'mortgage',
#    u'delinquency',
#    u'balance',
#    u'month'],
#   [u'credit',
#    u'pace',
#    u'increase',
#    u'credit',
#    u'surge',
#    u'student',
#    u'loan',
#    u'decrease',
#    u'credit'],
#   [u'issuance', u'consumer', u'security', u'security'],
#   [u'rate',
#    u'category',
#    u'consumer',
#    u'loan',
#    u'month',
#    u'level',
#    u'recession'],
#   [u'bank', u'loan', u'sum', u'estate', u'consumer', u'loan'],
#   [u'loan', u'consumer', u'loan', u'growth', u'estate', u'loan'],
#   [u'upturn',
#    u'lending',
#    u'institution',
#    u'bank',
#    u'loan',
#    u'pace',
#    u'quarters'],
#   [u'investor',
#    u'asset',
#    u'manager',
#    u'safety',
#    u'liquidity',
#    u'bank',
#    u'deposit',
#    u'asset',
#    u'aggregate'],
#   [u'investor',
#    u'exposure',
#    u'money',
#    u'fund',
#    u'institution',
#    u'money',
#    u'fund',
#    u'bank',
#    u'deposit',
#    u'money',
#    u'fund',
#    u'manager',
#    u'bank',
#    u'deposit',
#    u'anticipation',
#    u'redemption',
#    u'investor'],
#   [u'addition',
#    u'investor',
#    u'redemption',
#    u'equity',
#    u'bond',
#    u'fund',
#    u'bank',
#    u'deposit',
#    u'money',
#    u'market',
#    u'fund'],
#   [u'exchange',
#    u'value',
#    u'dollar',
#    u'period',
#    u'flight',
#    u'safety',
#    u'yield'],
#   [u'contrast',
#    u'yield',
#    u'greek',
#    u'bond',
#    u'market',
#    u'participant',
#    u'debt'],
#   [u'price', u'area', u'period', u'decline'],
#   [u'market', u'debt', u'country'],
#   [u'yield', u'debt', u'ecb', u'purchase', u'period'],
#   [u'price', u'money', u'market', u'future', u'contract', u'policy', u'area'],
#   [u'step',
#    u'policy',
#    u'exchange',
#    u'market',
#    u'appreciation',
#    u'currency',
#    u'quantity',
#    u'currency',
#    u'franc',
#    u'trading',
#    u'exchange',
#    u'market',
#    u'rate',
#    u'franc',
#    u'euro'],
#   [u'concern', u'outlook', u'bank', u'policy', u'rate', u'time', u'year'],
#   [u'contrast',
#    u'policy',
#    u'reserve',
#    u'requirement',
#    u'range',
#    u'bank',
#    u'liability',
#    u'lending',
#    u'bank'],
#   [u'outlook',
#    u'forecast',
#    u'meeting',
#    u'staff',
#    u'projection',
#    u'increase',
#    u'half',
#    u'medium',
#    u'term'],
#   [u'data',
#    u'household',
#    u'business',
#    u'spending',
#    u'balance',
#    u'labor',
#    u'market',
#    u'condition',
#    u'indicator',
#    u'activity',
#    u'consumer',
#    u'business',
#    u'sentiment'],
#   [u'addition', u'condition', u'time', u'forecast', u'investor', u'asset'],
#   [u'staff',
#    u'activity',
#    u'half',
#    u'year',
#    u'half',
#    u'supply',
#    u'chain',
#    u'disruption',
#    u'motor',
#    u'vehicle',
#    u'sector'],
#   [u'medium',
#    u'term',
#    u'staff',
#    u'policy',
#    u'increase',
#    u'credit',
#    u'availability',
#    u'improvement',
#    u'consumer',
#    u'business',
#    u'confidence',
#    u'level'],
#   [u'increase',
#    u'unemployment',
#    u'rate',
#    u'projection',
#    u'period',
#    u'rate',
#    u'end'],
#   [u'staff',
#    u'projection',
#    u'inflation',
#    u'changed',
#    u'forecast',
#    u'time',
#    u'meeting'],
#   [u'pressure',
#    u'consumer',
#    u'price',
#    u'increase',
#    u'import',
#    u'commodity',
#    u'price',
#    u'year',
#    u'motor',
#    u'vehicle',
#    u'price',
#    u'inventory',
#    u'quarters'],
#   [u'inflation',
#    u'expectation',
#    u'slack',
#    u'labor',
#    u'product',
#    u'market',
#    u'period',
#    u'staff',
#    u'project',
#    u'inflation'],
#   [u'participant',
#    u'view',
#    u'condition',
#    u'outlook',
#    u'discussion',
#    u'situation',
#    u'outlook',
#    u'meeting',
#    u'participant',
#    u'information',
#    u'period',
#    u'growth',
#    u'contraction',
#    u'activity'],
#   [u'factor',
#    u'growth',
#    u'half',
#    u'year',
#    u'rebound',
#    u'sale',
#    u'production',
#    u'manufacturing',
#    u'sector',
#    u'progress',
#    u'supply',
#    u'chain',
#    u'disruption'],
#   [u'stress',
#    u'market',
#    u'growth',
#    u'household',
#    u'income',
#    u'uncertainty',
#    u'prospect',
#    u'consumer',
#    u'business',
#    u'sentiment',
#    u'growth'],
#   [u'indicator',
#    u'weakness',
#    u'labor',
#    u'market',
#    u'condition',
#    u'unemployment',
#    u'rate'],
#   [u'risk',
#    u'growth',
#    u'outlook',
#    u'strain',
#    u'market',
#    u'downside',
#    u'growth',
#    u'recovery',
#    u'shock'],
#   [u'inflation',
#    u'expectation',
#    u'effect',
#    u'increase',
#    u'energy',
#    u'commodity',
#    u'price',
#    u'participant',
#    u'core',
#    u'headline',
#    u'inflation',
#    u'quarters',
#    u'level',
#    u'mandate'],
#   [u'participant', u'outlook', u'growth', u'inflation'],
#   [u'participant',
#    u'growth',
#    u'consumer',
#    u'spending',
#    u'average',
#    u'month',
#    u'rebound',
#    u'purchase',
#    u'motor',
#    u'vehicle',
#    u'manufacturer',
#    u'progress',
#    u'supply',
#    u'chain',
#    u'disruption',
#    u'availability',
#    u'model'],
#   [u'survey', u'household', u'income', u'consumer', u'confidence', u'level'],
#   [u'confidence',
#    u'effort',
#    u'balance',
#    u'sheet',
#    u'caution',
#    u'face',
#    u'environment',
#    u'factor',
#    u'household',
#    u'spending'],
#   [u'participant',
#    u'home',
#    u'price',
#    u'constraint',
#    u'still-tight',
#    u'credit',
#    u'condition',
#    u'household',
#    u'consumer',
#    u'spending',
#    u'time'],
#   [u'household', u'burden', u'progress', u'household', u'balance', u'sheet'],
#   [u'sentiment',
#    u'response',
#    u'prospect',
#    u'downside',
#    u'risk',
#    u'outlook',
#    u'growth'],
#   [u'participant', u'hurricane', u'flooding', u'slowing', u'country'],
#   [u'contrast',
#    u'business',
#    u'contact',
#    u'sector',
#    u'energy',
#    u'agriculture',
#    u'mining',
#    u'gain',
#    u'tourism'],
#   [u'export', u'spot', u'manufacturer', u'commodity', u'producer'],
#   [u'investment',
#    u'equipment',
#    u'software',
#    u'month',
#    u'contact',
#    u'concern',
#    u'firm',
#    u'capital',
#    u'spending',
#    u'sale'],
#   [u'housing',
#    u'sector',
#    u'construction',
#    u'level',
#    u'weakness',
#    u'home',
#    u'sale',
#    u'flow',
#    u'property',
#    u'market'],
#   [u'mortgage',
#    u'rate',
#    u'spread',
#    u'mortgage',
#    u'rate',
#    u'yield',
#    u'security'],
#   [u'still-tight',
#    u'credit',
#    u'standard',
#    u'household',
#    u'loan',
#    u'home',
#    u'drop',
#    u'house',
#    u'price',
#    u'year',
#    u'mortgage'],
#   [u'construction', u'investment', u'industry', u'indicator', u'construction'],
#   [u'participant',
#    u'labor',
#    u'market',
#    u'condition',
#    u'improvement',
#    u'month',
#    u'unemployment',
#    u'rate'],
#   [u'effect',
#    u'strike',
#    u'payroll',
#    u'employment',
#    u'report',
#    u'job',
#    u'gain'],
#   [u'workweek', u'aggregate', u'hour'],
#   [u'growth',
#    u'business',
#    u'confidence',
#    u'uncertainty',
#    u'outlook',
#    u'hiring',
#    u'capital',
#    u'investment',
#    u'uncertainty',
#    u'tax',
#    u'policy',
#    u'business',
#    u'reluctance'],
#   [u'participant',
#    u'job',
#    u'growth',
#    u'unemployment',
#    u'rate',
#    u'demand',
#    u'good',
#    u'service',
#    u'mismatch',
#    u'characteristic',
#    u'need',
#    u'employer',
#    u'job',
#    u'view',
#    u'importance',
#    u'factor'],
#   [u'participant', u'demand', u'importance', u'mismatch'],
#   [u'business',
#    u'contact',
#    u'number',
#    u'application',
#    u'position',
#    u'difficulty',
#    u'finding',
#    u'candidate',
#    u'position'],
#   [u'participant',
#    u'level',
#    u'unemployment',
#    u'effect',
#    u'skill',
#    u'employment',
#    u'prospect',
#    u'economy',
#    u'potential'],
#   [u'participant',
#    u'market',
#    u'period',
#    u'condition',
#    u'time',
#    u'investor',
#    u'datum',
#    u'news',
#    u'development'],
#   [u'participant',
#    u'condition',
#    u'period',
#    u'risk',
#    u'spread',
#    u'willingness',
#    u'investor',
#    u'risk',
#    u'outlook',
#    u'growth',
#    u'uncertainty',
#    u'prospect'],
#   [u'participant',
#    u'reduction',
#    u'leverage',
#    u'increase',
#    u'firm',
#    u'liquidity',
#    u'cushion',
#    u'height',
#    u'crisis',
#    u'effect',
#    u'risk',
#    u'aversion'],
#   [u'banking', u'sector', u'bank', u'customer', u'loan', u'demand'],
#   [u'condition',
#    u'bank',
#    u'market',
#    u'bank',
#    u'participant',
#    u'capital',
#    u'liquidity',
#    u'position',
#    u'bank',
#    u'quarters',
#    u'credit',
#    u'quality',
#    u'business',
#    u'household',
#    u'loan'],
#   [u'bank', u'pressure', u'stock', u'price', u'spread'],
#   [u'participant',
#    u'policymaker',
#    u'debt',
#    u'banking',
#    u'problem',
#    u'spillover',
#    u'economy'],
#   [u'liquidity', u'bank', u'capacity', u'liquidity', u'lending', u'facility'],
#   [u'participant',
#    u'inflation',
#    u'month',
#    u'year',
#    u'price',
#    u'energy',
#    u'commodity',
#    u'peak',
#    u'moderation',
#    u'participant'],
#   [u'inflation', u'expectation', u'stable'],
#   [u'participant',
#    u'inflation',
#    u'expectation',
#    u'slack',
#    u'labor',
#    u'product',
#    u'market',
#    u'wage',
#    u'growth',
#    u'evidence',
#    u'pricing',
#    u'power',
#    u'firm',
#    u'inflation',
#    u'time'],
#   [u'growth', u'surge', u'commodity', u'price'],
#   [u'juxtaposition',
#    u'core',
#    u'inflation',
#    u'unemployment',
#    u'degree',
#    u'slack',
#    u'labor',
#    u'market',
#    u'level',
#    u'output'],
#   [u'rise',
#    u'inflation',
#    u'level',
#    u'stance',
#    u'policy',
#    u'asset',
#    u'purchase',
#    u'response',
#    u'deflation',
#    u'risk',
#    u'year'],
#   [u'medium-run',
#    u'inflation',
#    u'risk',
#    u'downside',
#    u'light',
#    u'resource',
#    u'slack',
#    u'stance',
#    u'policy',
#    u'trend',
#    u'measure',
#    u'inflation',
#    u'year',
#    u'inflation',
#    u'risk',
#    u'upside'],
#   [u'participant', u'risk', u'deflation'],
#   [u'survey',
#    u'forecaster',
#    u'likelihood',
#    u'deflation',
#    u'measure',
#    u'probability',
#    u'deflation',
#    u'price',
#    u'security',
#    u'tip',
#    u'asset',
#    u'purchase',
#    u'program'],
#   [u'participant', u'uncertainty', u'outlook', u'pickup', u'growth'],
#   [u'impetus',
#    u'expansion',
#    u'recovery',
#    u'reason',
#    u'weakness',
#    u'uncertainty',
#    u'outlook'],
#   [u'household',
#    u'business',
#    u'leverage',
#    u'housing',
#    u'market',
#    u'distress',
#    u'mechanism',
#    u'policy',
#    u'action',
#    u'economy'],
#   [u'participant', u'risk', u'growth'],
#   [u'downturn', u'activity', u'growth', u'recovery', u'shock'],
#   [u'risk',
#    u'possibility',
#    u'deleveraging',
#    u'household',
#    u'chance',
#    u'tightening',
#    u'spillover',
#    u'situation'],
#   [u'participant', u'policy', u'liquidity', u'tool', u'shock'],
#   [u'discussion',
#    u'policy',
#    u'period',
#    u'member',
#    u'revision',
#    u'outlook',
#    u'policy',
#    u'accommodation',
#    u'recovery',
#    u'inflation',
#    u'time',
#    u'level',
#    u'mandate'],
#   [u'policy',
#    u'economy',
#    u'ill',
#    u'member',
#    u'accommodation',
#    u'outcome',
#    u'term',
#    u'mandate',
#    u'employment',
#    u'price',
#    u'stability'],
#   [u'policy',
#    u'accommodation',
#    u'meeting',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'asset',
#    u'purchase',
#    u'sale',
#    u'maturity',
#    u'security',
#    u'soma',
#    u'expansion',
#    u'balance',
#    u'sheet',
#    u'reserve',
#    u'balance'],
#   [u'member',
#    u'program',
#    u'intention',
#    u'end',
#    u'security',
#    u'maturity',
#    u'year',
#    u'year',
#    u'security',
#    u'maturity',
#    u'year'],
#   [u'program', u'pressure', u'rate', u'condition'],
#   [u'scale',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'shorter-term',
#    u'security',
#    u'portfolio',
#    u'member',
#    u'action',
#    u'condition',
#    u'outlook'],
#   [u'member',
#    u'condition',
#    u'outlook',
#    u'policy',
#    u'action',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'meeting',
#    u'step',
#    u'meeting'],
#   [u'member', u'accommodation', u'time'],
#   [u'parameter',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'intention',
#    u'set',
#    u'transaction',
#    u'transaction',
#    u'pace'],
#   [u'member',
#    u'benefit',
#    u'approach',
#    u'public',
#    u'clarity',
#    u'scale',
#    u'program',
#    u'flexibility',
#    u'scale',
#    u'program',
#    u'response',
#    u'development'],
#   [u'member', u'size', u'composition', u'security', u'holding', u'holding'],
#   [u'condition',
#    u'mortgage',
#    u'market',
#    u'principal',
#    u'holding',
#    u'agency',
#    u'debt',
#    u'agency',
#    u'agency',
#    u'security',
#    u'practice',
#    u'year'],
#   [u'effect',
#    u'change',
#    u'holding',
#    u'agency',
#    u'security',
#    u'level',
#    u'practice',
#    u'holding',
#    u'basis'],
#   [u'change',
#    u'reinvestment',
#    u'policy',
#    u'spread',
#    u'yield',
#    u'security',
#    u'comparable-maturity',
#    u'security',
#    u'year',
#    u'mortgage',
#    u'rate'],
#   [u'member',
#    u'change',
#    u'reinvestment',
#    u'policy',
#    u'share',
#    u'security',
#    u'level',
#    u'deterioration',
#    u'market',
#    u'functioning'],
#   [u'member',
#    u'maturity',
#    u'extension',
#    u'program',
#    u'change',
#    u'reinvestment',
#    u'policy',
#    u'housing',
#    u'market'],
#   [u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'percent',
#    u'anticipation',
#    u'condition',
#    u'rate',
#    u'resource',
#    u'utilization',
#    u'outlook',
#    u'inflation',
#    u'medium',
#    u'run',
#    u'level',
#    u'fund',
#    u'rate',
#    u'mid-2013'],
#   [u'couple',
#    u'member',
#    u'guidance',
#    u'clarity',
#    u'condition',
#    u'level',
#    u'target',
#    u'fund',
#    u'rate',
#    u'decision',
#    u'point'],
#   [u'statement',
#    u'meeting',
#    u'growth',
#    u'indicator',
#    u'weakness',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'inflation',
#    u'year',
#    u'price',
#    u'energy',
#    u'commodity',
#    u'peak',
#    u'inflation',
#    u'expectation',
#    u'stable'],
#   [u'member',
#    u'pickup',
#    u'pace',
#    u'recovery',
#    u'quarters',
#    u'unemployment',
#    u'rate',
#    u'risk',
#    u'outlook',
#    u'strain',
#    u'market'],
#   [u'inflation',
#    u'quarters',
#    u'level',
#    u'mandate',
#    u'effect',
#    u'energy',
#    u'commodity',
#    u'price'],
#   [u'conclusion',
#    u'discussion',
#    u'transaction',
#    u'accordance',
#    u'policy',
#    u'directive'],
#   [u'condition', u'price', u'stability', u'growth', u'output'],
#   [u'objective',
#    u'condition',
#    u'reserve',
#    u'market',
#    u'fund',
#    u'trading',
#    u'range',
#    u'percent'],
#   [u'end',
#    u'security',
#    u'maturity',
#    u'year',
#    u'year',
#    u'face',
#    u'value',
#    u'security',
#    u'maturity',
#    u'year',
#    u'face',
#    u'value'],
#   [u'existing',
#    u'policy',
#    u'security',
#    u'issue',
#    u'payment',
#    u'agency',
#    u'debt',
#    u'agency',
#    u'security',
#    u'agency',
#    u'security',
#    u'order',
#    u'face',
#    u'value',
#    u'security'],
#   [u'dollar',
#    u'roll',
#    u'transaction',
#    u'settlement',
#    u'agency',
#    u'transaction'],
#   [u'development',
#    u'balance',
#    u'sheet',
#    u'attainment',
#    u'time',
#    u'objective',
#    u'employment',
#    u'price',
#    u'stability'],
#   [u'information', u'growth'],
#   [u'indicator',
#    u'weakness',
#    u'labor',
#    u'market',
#    u'condition',
#    u'unemployment',
#    u'rate'],
#   [u'spending',
#    u'pace',
#    u'month',
#    u'recovery',
#    u'sale',
#    u'motor',
#    u'vehicle',
#    u'disruption'],
#   [u'investment', u'structure', u'housing', u'sector'],
#   [u'inflation', u'expectation', u'stable'],
#   [u'mandate', u'employment', u'price', u'stability'],
#   [u'pickup',
#    u'pace',
#    u'recovery',
#    u'quarters',
#    u'unemployment',
#    u'rate',
#    u'level',
#    u'judge',
#    u'mandate'],
#   [u'risk', u'outlook', u'strain', u'market'],
#   [u'inflation',
#    u'quarters',
#    u'level',
#    u'mandate',
#    u'effect',
#    u'energy',
#    u'commodity',
#    u'price'],
#   [u'attention', u'evolution', u'inflation', u'inflation', u'expectation'],
#   [u'recovery',
#    u'inflation',
#    u'time',
#    u'level',
#    u'mandate',
#    u'today',
#    u'maturity',
#    u'holding',
#    u'security'],
#   [u'end',
#    u'security',
#    u'maturity',
#    u'year',
#    u'year',
#    u'security',
#    u'maturity',
#    u'year'],
#   [u'program', u'pressure', u'rate', u'condition'],
#   [u'size', u'composition', u'security', u'holding', u'holding'],
#   [u'condition',
#    u'mortgage',
#    u'market',
#    u'payment',
#    u'holding',
#    u'agency',
#    u'debt',
#    u'agency',
#    u'security',
#    u'agency',
#    u'security'],
#   [u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'percent',
#    u'condition',
#    u'rate',
#    u'resource',
#    u'utilization',
#    u'outlook',
#    u'inflation',
#    u'medium',
#    u'run',
#    u'level',
#    u'fund',
#    u'rate',
#    u'mid-2013'],
#   [u'range',
#    u'policy',
#    u'tool',
#    u'recovery',
#    u'context',
#    u'price',
#    u'stability'],
#   [u'outlook', u'light', u'information', u'tool'],
#   [u'policy', u'accommodation', u'time'],
#   [u'maturity',
#    u'extension',
#    u'program',
#    u'benefit',
#    u'support',
#    u'job',
#    u'creation',
#    u'growth',
#    u'removal',
#    u'policy',
#    u'accommodation'],
#   [u'view',
#    u'reduction',
#    u'rate',
#    u'policy',
#    u'action',
#    u'hoarding',
#    u'saver',
#    u'result',
#    u'business',
#    u'consumer',
#    u'confidence',
#    u'spending',
#    u'behavior'],
#   [u'policymaker',
#    u'attention',
#    u'policy',
#    u'transmission',
#    u'mechanism',
#    u'regard',
#    u'activity',
#    u'community',
#    u'bank',
#    u'business',
#    u'lending',
#    u'job',
#    u'creation'],
#   [u'inflation',
#    u'forecast',
#    u'inflation',
#    u'unemployment',
#    u'forecast',
#    u'unemployment'],
#   [u'accommodation',
#    u'response',
#    u'change',
#    u'economy',
#    u'policy',
#    u'framework'],
#   [u'maturity',
#    u'extension',
#    u'program',
#    u'growth',
#    u'employment',
#    u'light',
#    u'adjustment',
#    u'challenge'],
#   [u'view',
#    u'inflation',
#    u'forecast',
#    u'program',
#    u'pressure',
#    u'exit',
#    u'period',
#    u'policy'],
#   [u'maturity',
#    u'extension',
#    u'program',
#    u'purchase',
#    u'security',
#    u'year',
#    u'maturity',
#    u'year',
#    u'maturity',
#    u'year',
#    u'maturity',
#    u'tip',
#    u'maturity',
#    u'year'],
#   [u'distribution',
#    u'share',
#    u'purchase',
#    u'maturity',
#    u'case',
#    u'asset',
#    u'purchase',
#    u'program'],
#   [u'purchase', u'sale', u'auction'],
#   [u'respect',
#    u'reinvestment',
#    u'program',
#    u'purchase',
#    u'purchase',
#    u'bidding',
#    u'process'],
#   [u'information', u'meeting', u'minute'],
#   [u'vote',
#    u'meeting',
#    u'transaction',
#    u'meeting',
#    u'notation',
#    u'minute',
#    u'meeting']],
#  [[u'joint'],
#   [u'alternate'],
#   [u'domestic', u'foreign', u'financial'],
#   [u'open', u'longer-term', u'principal', u'mortgage-backed'],
#   [u'unanimous', u'domestic', u'intermeeting'],
#   [u'current', u'additional', u'monetary', u'economic'],
#   [u'large-scale'],
#   [u'principal', u'long-term'],
#   [u'second',
#    u'long-term',
#    u'shorter-term',
#    u'average',
#    u'unaffected',
#    u'near'],
#   [u'longer-term'],
#   [u'longer-run', u'dual', u'forward', u'likely', u'monetary'],
#   [u'economic', u'short-term'],
#   [u'potential', u'depository', u'ior'],
#   [u'potential'],
#   [u'additional',
#    u'monetary',
#    u'longer-term',
#    u'financial',
#    u'federal',
#    u'infeasible'],
#   [u'potential',
#    u'real',
#    u'economic',
#    u'limited',
#    u'transitory',
#    u'current',
#    u'economic'],
#   [u'large-scale', u'potent', u'stronger', u'economic'],
#   [u'large-scale', u'likely', u'economic'],
#   [u'large-scale', u'large', u'outstanding', u'longer-term'],
#   [u'unlikely'],
#   [u'monetary', u'longer-run'],
#   [u'clear',
#    u'longer-run',
#    u'helpful',
#    u'useful',
#    u'longer-run',
#    u'monetary',
#    u'short'],
#   [u'expressed',
#    u'conceptual',
#    u'explicit',
#    u'longer-run',
#    u'long-run',
#    u'nonmonetary',
#    u'subject',
#    u'considerable'],
#   [u'long-run', u'monetary'],
#   [u'explicit', u'longer-run', u'in-depth', u'policymaking'],
#   [u'transparent', u'forward', u'economic'],
#   [u'forward',
#    u'effective',
#    u'financial',
#    u'incoming',
#    u'economic',
#    u'monetary'],
#   [u'explicit', u'economic', u'forward', u'longer-run'],
#   [u'careful'],
#   [u'periodic', u'longer-run', u'likely', u'monetary'],
#   [u'ior', u'potential'],
#   [u'lower'],
#   [u'ior', u'federal', u'low'],
#   [u'ior', u'safe', u'short-term'],
#   [u'recent', u'net'],
#   [u'voiced', u'ior', u'costly', u'difficult'],
#   [u'federal', u'effective', u'federal', u'short-term'],
#   [u'likely', u'ior', u'current'],
#   [u'20-21', u'economic', u'slow', u'weak'],
#   [u'long-run'],
#   [u'private', u'nonfarm', u'weak'],
#   [u'local', u'tight'],
#   [u'long-duration', u'economic'],
#   [u'initial', u'previous', u'recent'],
#   [u'unlikely'],
#   [u'fourth',
#    u'broader',
#    u'near-term',
#    u'new',
#    u'national',
#    u'regional',
#    u'consistent',
#    u'meager',
#    u'coming'],
#   [u'real', u'solid', u'low'],
#   [u'nominal', u'retail', u'new'],
#   [u'real', u'disposable', u'nominal'],
#   [u'early'],
#   [u'weak', u'future', u'tight', u'substantial', u'foreclosed', u'distressed'],
#   [u'new', u'single-family', u'low'],
#   [u'new', u'recent'],
#   [u'real'],
#   [u'nominal', u'nondefense', u'new', u'higher'],
#   [u'nondefense', u'unfilled', u'pointed', u'subsequent'],
#   [u'muted'],
#   [u'real', u'commercial', u'recent', u'low', u'high', u'tight'],
#   [u'modest', u'earlier'],
#   [u'real', u'federal', u'recent', u'low'],
#   [u'local', u'real'],
#   [u'nominal', u'international'],
#   [u'industrial'],
#   [u'lower', u'decreased', u'large', u'automotive'],
#   [u'net', u'real', u'gross', u'domestic'],
#   [u'previous'],
#   [u'average', u'monthly', u'second'],
#   [u'near-term', u'elevated', u'longer-term'],
#   [u'available', u'large'],
#   [u'average', u'hourly', u'small'],
#   [u'foreign', u'economic', u'second'],
#   [u'economic'],
#   [u'real', u'large'],
#   [u'global', u'economic', u'temporary'],
#   [u'foreign', u'recent', u'sluggish', u'underlying', u'economic'],
#   [u'fiscal', u'financial', u'euro'],
#   [u'recent', u'economic', u'evident', u'industrial'],
#   [u'second', u'earlier'],
#   [u'domestic'],
#   [u'volatile', u'intermeeting', u'downbeat', u'economic'],
#   [u'european', u'fiscal', u'financial'],
#   [u'expected', u'federal', u'intermeeting'],
#   [u'firmer', u'forward', u'economic', u'likely', u'low', u'federal'],
#   [u'subsequent',
#    u'weak',
#    u'economic',
#    u'additional',
#    u'monetary',
#    u'financial',
#    u'appreciable',
#    u'intermediate',
#    u'longer-term',
#    u'nominal'],
#   [u'softer', u'economic', u'nominal', u'inflation-protected', u'low'],
#   [u'early', u'large', u'financial'],
#   [u'more-pronounced', u'larger', u'european', u'financial'],
#   [u'large',
#    u'european',
#    u'difficult',
#    u'recent',
#    u'unsecured',
#    u'short',
#    u'financial'],
#   [u'secured',
#    u'available',
#    u'domestic',
#    u'european',
#    u'financial',
#    u'repurchase',
#    u'backed'],
#   [u'emerged', u'late', u'intermeeting', u'backed', u'nontraditional'],
#   [u'one-week', u'announced', u'three-month', u'seven-day'],
#   [u'volatile', u'sharp'],
#   [u'gross',
#    u'nonfinancial',
#    u'recent',
#    u'large',
#    u'planned',
#    u'initial',
#    u'shelved',
#    u'heightened'],
#   [u'speculative-grade',
#    u'corporate',
#    u'intermeeting',
#    u'late',
#    u'average',
#    u'secondary',
#    u'syndicated',
#    u'leveraged'],
#   [u'additional', u'hospitable', u'lower-rated', u'nonfinancial'],
#   [u'speculative-grade', u'new', u'leveraged', u'institutional'],
#   [u'net',
#    u'investment-grade',
#    u'robust',
#    u'wider',
#    u'nonfinancial',
#    u'commercial',
#    u'outstanding'],
#   [u'small', u'major', u'past'],
#   [u'financial', u'hedge'],
#   [u'true', u'hedge'],
#   [u'commercial', u'real', u'weak'],
#   [u'commercial', u'mortgage-backed', u'greater'],
#   [u'commercial', u'depressed', u'slight', u'second'],
#   [u'elevated', u'commercial', u'real', u'second'],
#   [u'residential', u'intermeeting', u'low', u'long-term'],
#   [u'low', u'little', u'tight', u'low'],
#   [u'second'],
#   [u'moderate', u'high', u'prime', u'recent'],
#   [u'solid', u'sizable', u'nonrevolving', u'funded', u'revolving'],
#   [u'asset-backed', u'low'],
#   [u'recent'],
#   [u'commercial', u'commercial', u'industrial', u'real'],
#   [u'c&i', u'tepid', u'real'],
#   [u'large', u'domestic', u'foreign', u'smaller', u'core', u'recent'],
#   [u'relative'],
#   [u'institutional',
#    u'european',
#    u'financial',
#    u'prime',
#    u'sizable',
#    u'large'],
#   [u'retail', u'placed', u'mutual', u'retail'],
#   [u'foreign', u'intermeeting', u'benchmark', u'sovereign'],
#   [u'two-year', u'sovereign', u'sovereign'],
#   [u'euro', u'intermeeting', u'sharp', u'early'],
#   [u'secondary', u'sovereign', u'euro-area'],
#   [u'italian', u'spanish', u'early', u'higher', u'intermeeting'],
#   [u'monetary', u'accommodative', u'euro'],
#   [u'swiss',
#    u'monetary',
#    u'foreign',
#    u'unlimited',
#    u'foreign',
#    u'swiss',
#    u'foreign',
#    u'swiss'],
#   [u'global', u'economic', u'central'],
#   [u'monetary', u'wider', u'off-balance-sheet'],
#   [u'economic', u'real', u'second'],
#   [u'incoming', u'near-term', u'economic', u'weaker', u'anticipated'],
#   [u'financial', u'previous', u'riskier'],
#   [u'economic', u'second'],
#   [u'projected', u'real', u'accommodative', u'monetary', u'current', u'low'],
#   [u'real', u'sufficient', u'jobless'],
#   [u'little'],
#   [u'upward', u'temporary', u'low'],
#   [u'stable', u'long-run', u'considerable', u'forecast'],
#   [u'current', u'economic', u'intermeeting', u'economic', u'slow'],
#   [u'temporary', u'slower', u'final'],
#   [u'global',
#    u'financial',
#    u'sluggish',
#    u'real',
#    u'heightened',
#    u'economic',
#    u'economic'],
#   [u'recent', u'overall', u'elevated'],
#   [u'global',
#    u'financial',
#    u'significant',
#    u'slow',
#    u'vulnerable',
#    u'negative'],
#   [u'longer-term', u'stable', u'past', u'likely', u'consistent', u'dual'],
#   [u'uncertain', u'usual'],
#   [u'modest', u'recent', u'new', u'popular'],
#   [u'pessimistic', u'future', u'low'],
#   [u'heightened', u'uncertain', u'economic', u'likely'],
#   [u'depressed', u'financial', u'likely'],
#   [u'debt-service'],
#   [u'business', u'weaker', u'economic', u'increased', u'global'],
#   [u'subsequent'],
#   [u'commodity-related', u'strong'],
#   [u'bright'],
#   [u'business', u'recent', u'expressed'],
#   [u'depressed', u'low', u'likely', u'new', u'foreclosed'],
#   [u'low', u'wide'],
#   [u'unable', u'recent', u'unable', u'higher-rate'],
#   [u'nonresidential',
#    u'weak',
#    u'extractive',
#    u'forward-looking',
#    u'nonresidential'],
#   [u'overall', u'recent', u'elevated'],
#   [u'reported', u'weak'],
#   [u'average'],
#   [u'slower', u'depressed', u'economic', u'regulatory'],
#   [u'sluggish',
#    u'elevated',
#    u'weak',
#    u'unemployed',
#    u'available',
#    u'relative'],
#   [u'weak', u'structural', u'geographic', u'key'],
#   [u'large', u'low-skilled', u'skilled'],
#   [u'high',
#    u'long-duration',
#    u'permanent',
#    u'negative',
#    u'affected',
#    u'longer-run',
#    u'productive'],
#   [u'financial',
#    u'volatile',
#    u'intermeeting',
#    u'financial',
#    u'incoming',
#    u'economic',
#    u'european',
#    u'fiscal',
#    u'financial'],
#   [u'broader',
#    u'financial',
#    u'accommodative',
#    u'intermeeting',
#    u'likely',
#    u'reduced',
#    u'weaker',
#    u'greater',
#    u'economic'],
#   [u'positive', u'financial', u'financial', u'adverse', u'heightened'],
#   [u'willing', u'weak'],
#   [u'european', u'recent'],
#   [u'large'],
#   [u'european', u'european', u'sovereign'],
#   [u'ample', u'european', u'substantial', u'additional', u'necessary'],
#   [u'recent', u'substantial'],
#   [u'longer-term'],
#   [u'stable', u'significant', u'slow', u'little', u'likely'],
#   [u'slowing', u'new', u'unlikely'],
#   [u'higher', u'lower', u'potential', u'lower'],
#   [u'core',
#    u'low',
#    u'accommodative',
#    u'monetary',
#    u'large-scale',
#    u'successful'],
#   [u'tilted',
#    u'persistent',
#    u'accommodative',
#    u'monetary',
#    u'upward',
#    u'core'],
#   [u'little'],
#   [u'low', u'second', u'inflation-protected', u'second', u'large-scale'],
#   [u'considerable', u'gradual', u'economic'],
#   [u'cyclical',
#    u'economic',
#    u'weaker',
#    u'past',
#    u'unclear',
#    u'greater',
#    u'economic'],
#   [u'normal', u'monetary', u'real'],
#   [u'significant', u'downside', u'economic'],
#   [u'economic', u'vulnerable', u'adverse'],
#   [u'pronounced',
#    u'protracted',
#    u'larger-than-expected',
#    u'near-term',
#    u'fiscal',
#    u'potential',
#    u'financial'],
#   [u'monetary'],
#   [u'monetary',
#    u'economic',
#    u'additional',
#    u'monetary',
#    u'stronger',
#    u'consistent',
#    u'dual'],
#   [u'monetary', u'additional', u'better', u'dual', u'maximum'],
#   [u'greater', u'appropriate', u'average', u'substantial'],
#   [u'equal'],
#   [u'downward', u'longer-term', u'broader', u'financial', u'accommodative'],
#   [u'appropriate', u'economic'],
#   [u'current', u'stronger', u'additional', u'future'],
#   [u'additional', u'appropriate'],
#   [u'monthly'],
#   [u'greater', u'likely', u'greater', u'unexpected', u'economic'],
#   [u'appropriate'],
#   [u'longer-term'],
#   [u'constant', u'previous', u'ongoing'],
#   [u'mortgage-backed', u'contribute'],
#   [u'outstanding', u'longer-term'],
#   [u'benefit'],
#   [u'federal', u'economic', u'low', u'subdued', u'likely', u'low', u'federal'],
#   [u'forward', u'greater', u'economic', u'likely', u'low', u'federal'],
#   [u'important', u'economic', u'slow', u'overall'],
#   [u'recent', u'longer-term'],
#   [u'economic',
#    u'significant',
#    u'downside',
#    u'economic',
#    u'global',
#    u'financial'],
#   [u'consistent', u'past'],
#   [u'following', u'domestic'],
#   [u'monetary', u'financial', u'sustainable'],
#   [u'long-run', u'consistent', u'federal'],
#   [u'total', u'total'],
#   [u'new',
#    u'principal',
#    u'mortgage-backed',
#    u'mortgage-backed',
#    u'total',
#    u'domestic'],
#   [u'necessary'],
#   [u'ongoing', u'maximum'],
#   [u'economic', u'slow'],
#   [u'recent', u'overall', u'elevated'],
#   [u'modest', u'recent', u'supply-chain'],
#   [u'nonresidential', u'weak', u'depressed'],
#   [u'longer-term'],
#   [u'consistent', u'statutory', u'maximum'],
#   [u'consistent', u'dual'],
#   [u'significant', u'downside', u'economic', u'global', u'financial'],
#   [u'consistent', u'dual', u'past'],
#   [u'close'],
#   [u'stronger', u'economic', u'consistent', u'dual', u'average'],
#   [u'equal'],
#   [u'downward', u'longer-term', u'broader', u'financial', u'accommodative'],
#   [u'appropriate'],
#   [u'principal', u'mortgage-backed', u'mortgage-backed'],
#   [u'federal', u'economic', u'low', u'subdued', u'likely', u'low', u'federal'],
#   [u'available', u'stronger', u'economic'],
#   [u'economic', u'incoming', u'appropriate'],
#   [u'support', u'additional'],
#   [u'economic', u'timely'],
#   [u'long-term', u'counterproductive'],
#   [u'monetary', u'vital', u'small'],
#   [u'one-year-ahead', u'one-year-ahead'],
#   [u'monetary', u'appropriate', u'current'],
#   [u'little', u'near-term', u'ongoing', u'structural', u'fiscal'],
#   [u'earlier',
#    u'unwanted',
#    u'inflationary',
#    u'eventual',
#    u'accommodative',
#    u'monetary'],
#   [u'nominal', u'small'],
#   [u'larger', u'longer', u'previous'],
#   [u'competitive'],
#   [u'mbs', u'competitive'],
#   [u'following', u'previous'],
#   [u'unanimous', u'domestic']])
