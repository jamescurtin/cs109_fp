# %% [markdown]
# # Sentiment Analysis

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json
from pyquery import PyQuery as pq

# %% [markdown]
# ### Natural Language Processing
#
# We begin by parsing the text and pre-processing it to prepare it for Latent Dirichlet Analysis. This step is meant to remove stopwords and identify nouns and adjectives.

# %%
from pattern.en import parse
from pattern.en import pprint
from pattern.vector import stem, PORTER, LEMMA
punctuation = list('.,;:!?()[]{}`''\"@#$^&*+-|=~_')

# %%
from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS

# %% [markdown]
# The FOMC statements are full of phrases like "growth is expected to continue--given the current data--at a moderate pace". The two hyphens should be treated as a space.

# %%
import re
regex1=re.compile(r"\-{2,}")

# %% [markdown]
# We now define a function to find the nouns and adjectives of the text. The function returns a tuple where the first element is a list of lists, where each list includes the nouns from a sentence. The second element is a list of lists, where each list includes the adjectives from a sentence.

# %%
def modified_get_parts(thetext):
    thetext=re.sub(regex1, ', ', thetext)
    nouns=[]
    descriptives=[]
    for i,sentence in enumerate(parse(thetext, tokenize=True, lemmata=True).split()):
        
        # Skip the first three sentences that include the HTML
        nouns.append([])
        descriptives.append([])
#         if i in range(1,4):
#             continue
            
        for token in sentence:
            #print token
            if len(token[4]) >0:
                if token[1] in ['JJ', 'JJR', 'JJS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
            
                    descriptives[i].append(token[4])
                elif token[1] in ['NN', 'NNS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    nouns[i].append(token[4])
    out=zip(nouns, descriptives)
    nouns2=[]
    descriptives2=[]
    for n,d in out:
        if len(n)!=0 and len(d)!=0:
            nouns2.append(n)
            descriptives2.append(d)
    return nouns2[1:], descriptives2[1:]

# %% [markdown]
# We load in the fomc_mins_all dictionary that we created in the Scraping.ipynb iPython Notebook.

# %%
with open("fomc_mins_all.json", "rb") as infile:
    fomc_mins = json.load(infile)
    
len(fomc_mins.keys())
# Out:
# 182

# %% [markdown]
# We can now check how our modified_get_parts function would deal with a sample FOMC statement, printing out the first two noun lists.

# %%
modified_get_parts(pq(fomc_mins['20140730']).text())[0][:2]
# Out:
# [[u'buildmenu',
#   u'policy',
#   u'minute',
#   u'meeting',
#   u'office',
#   u'governor',
#   u'present',
#   u'member',
#   u'president',
#   u'economist',
#   u'dev'],
#  [u'governor',
#   u'governor',
#   u'adviser',
#   u'governor',
#   u'governor',
#   u'governor',
#   u'merten',
#   u'interval',
#   u'meeting',
#   u'subcommittee',
#   u'communication',
#   u'issue']]

# %% [markdown]
# We run modified_get_parts on each fomc statement and create a new dictionary fomc_parts. We strip each statement of the html at its start before passing it to modified_get_parts.

# %%
# %%time
fomc_parts = {}
for key in fomc_mins.keys():
    fomc_parts[key] = modified_get_parts(pq(fomc_mins[key]).text())
# Out:
# Wall time: 1min 42s

# %%
"""
fomc_parts_file = open("fomc_parts.json", "wb")
json.dump(fomc_parts, fomc_parts_file)
fomc_parts_file.close()
"""

# %%
# Out:
# ([[u'member'],
#   [u'division'],
#   [u'agenda',
#    u'meeting',
#    u'advice',
#    u'election',
#    u'member',
#    u'member',
#    u'period',
#    u'individual',
#    u'oath',
#    u'office'],
#   [u'member',
#    u'member',
#    u'vacancy',
#    u'position',
#    u'member',
#    u'meeting',
#    u'board',
#    u'director',
#    u'position'],
#   [u'director', u'member'],
#   [u'oath', u'office', u'member', u'period'],
#   [u'vote',
#    u'officer',
#    u'election',
#    u'successor',
#    u'meeting',
#    u'event',
#    u'discontinuance',
#    u'connection',
#    u'connection',
#    u'economist',
#    u'economist',
#    u'vote',
#    u'transaction',
#    u'adjournment',
#    u'meeting'],
#   [u'vote', u'pleasure', u'selection'],
#   [u'vote', u'addition', u'change', u'transmission', u'information'],
#   [u'vote', u'form'],
#   [u'authorization'],
#   [u'extent',
#    u'policy',
#    u'directive',
#    u'meeting',
#    u'government',
#    u'security',
#    u'security',
#    u'security',
#    u'obligation',
#    u'agency',
#    u'market',
#    u'security',
#    u'dealer',
#    u'account',
#    u'cash',
#    u'delivery',
#    u'basis',
#    u'market',
#    u'price',
#    u'exchange',
#    u'agency',
#    u'security',
#    u'agency',
#    u'replacement',
#    u'agency',
#    u'security',
#    u'commitment',
#    u'close',
#    u'business',
#    u'day',
#    u'meeting',
#    u'action',
#    u'respect',
#    u'policy',
#    u'directive',
#    u'period',
#    u'opening',
#    u'business',
#    u'day',
#    u'meeting',
#    u'close',
#    u'business',
#    u'day',
#    u'meeting',
#    u'government',
#    u'security',
#    u'obligation',
#    u'obligation',
#    u'agency',
#    u'dealer',
#    u'account',
#    u'agreement',
#    u'repurchase',
#    u'security',
#    u'obligation',
#    u'business',
#    u'day',
#    u'rate',
#    u'bidding',
#    u'limitation',
#    u'volume',
#    u'agreement',
#    u'dealer',
#    u'event',
#    u'government',
#    u'security',
#    u'agency',
#    u'issue',
#    u'agreement',
#    u'dealer',
#    u'agreement',
#    u'renewal',
#    u'market'],
#   [u'government',
#    u'security',
#    u'obligation',
#    u'obligation',
#    u'agency',
#    u'dealer',
#    u'agreement',
#    u'resale',
#    u'dealer',
#    u'security',
#    u'obligation',
#    u'business',
#    u'day',
#    u'rate',
#    u'bidding',
#    u'limitation',
#    u'volume',
#    u'agreement',
#    u'dealer'],
#   [u'order',
#    u'conduct',
#    u'market',
#    u'operation',
#    u'basis',
#    u'government',
#    u'security',
#    u'dealer',
#    u'rate',
#    u'bidding'],
#   [u'minimum',
#    u'fee',
#    u'objective',
#    u'program',
#    u'limitation',
#    u'issue',
#    u'security',
#    u'dealer'],
#   [u'bid', u'dealer', u'ability', u'issue'],
#   [u'order',
#    u'conduct',
#    u'market',
#    u'operation',
#    u'provision',
#    u'investment',
#    u'account',
#    u'account',
#    u'agent',
#    u'government',
#    u'security',
#    u'account',
#    u'basis',
#    u'paragraph',
#    u'l(a',
#    u'agreement',
#    u'resale',
#    u'account',
#    u'security',
#    u'business',
#    u'day',
#    u'term',
#    u'transaction',
#    u'market',
#    u'account',
#    u'dealer',
#    u'subject',
#    u'condition',
#    u'purchase',
#    u'sale',
#    u'security',
#    u'paragraph',
#    u'l(b',
#    u'repurchase',
#    u'agreement',
#    u'agency',
#    u'security',
#    u'sale',
#    u'repurchase',
#    u'agreement',
#    u'account',
#    u'agency',
#    u'account'],
#   [u'transaction', u'account', u'provision', u'paragraph', u'service', u'fee'],
#   [u'execution',
#    u'decision',
#    u'policy',
#    u'period',
#    u'instruction',
#    u'circumstance',
#    u'degree',
#    u'pressure',
#    u'reserve',
#    u'position',
#    u'fund',
#    u'rate'],
#   [u'adjustment',
#    u'context',
#    u'discussion',
#    u'decision',
#    u'meeting',
#    u'objective',
#    u'price',
#    u'stability',
#    u'growth',
#    u'development',
#    u'period'],
#   [u'practice', u'adjustment'],
#   [u'amendment',
#    u'authorization',
#    u'market',
#    u'operation',
#    u'addition',
#    u'reference',
#    u'paragraph',
#    u'account',
#    u'agency',
#    u'instruction'],
#   [u'account',
#    u'paragraph',
#    u'behalf',
#    u'account',
#    u'participation',
#    u'investment',
#    u'facility',
#    u'pool'],
#   [u'vote', u'form'],
#   [u'extent',
#    u'currency',
#    u'directive',
#    u'authorization',
#    u'conformity',
#    u'instruction',
#    u'time',
#    u'time',
#    u'currency',
#    u'form',
#    u'cable',
#    u'transfer',
#    u'spot',
#    u'transaction',
#    u'market',
#    u'home',
#    u'transaction',
#    u'authority',
#    u'institution',
#    u'dollar',
#    u'kroner',
#    u'pound',
#    u'yen',
#    u'peso',
#    u'kroner',
#    u'kronor',
#    u'franc',
#    u'balance',
#    u'forward',
#    u'contract',
#    u'currency',
#    u'paragraph'],
#   [u'currency',
#    u'bank',
#    u'dollar',
#    u'currency',
#    u'arrangement',
#    u'paragraph',
#    u'drawing',
#    u'party',
#    u'arrangement',
#    u'month',
#    u'time',
#    u'circumstance',
#    u'delay'],
#   [u'position', u'currency'],
#   [u'purpose',
#    u'position',
#    u'currency',
#    u'sum',
#    u'sign',
#    u'position',
#    u'currency'],
#   [u'net',
#    u'position',
#    u'currency',
#    u'holding',
#    u'balance',
#    u'currency',
#    u'contract',
#    u'receipt',
#    u'contract',
#    u'delivery',
#    u'currency',
#    u'sum',
#    u'element',
#    u'regard'],
#   [u'currency',
#    u'arrangement',
#    u'swap',
#    u'arrangement',
#    u'period',
#    u'maximum',
#    u'month',
#    u'bank',
#    u'governor',
#    u'regulation',
#    u'relation',
#    u'approval',
#    u'arrangement',
#    u'maturity',
#    u'bank',
#    u'arrangement',
#    u'million',
#    u'dollar',
#    u'change',
#    u'term',
#    u'swap',
#    u'arrangement',
#    u'term',
#    u'arrangement',
#    u'review',
#    u'approval'],
#   [u'transaction', u'currency', u'paragraph'],
#   [u'purpose',
#    u'investment',
#    u'return',
#    u'holding',
#    u'currency',
#    u'purpose',
#    u'rate',
#    u'connection',
#    u'swap',
#    u'drawing',
#    u'transaction',
#    u'bank',
#    u'non-market',
#    u'exchange',
#    u'rate'],
#   [u'practice', u'bank', u'coordination', u'currency', u'transaction'],
#   [u'arrangement', u'bank', u'holding', u'currency', u'balance'],
#   [u'agreement',
#    u'understanding',
#    u'administration',
#    u'account',
#    u'bank',
#    u'governor',
#    u'regulation',
#    u'review',
#    u'approval'],
#   [u'currency',
#    u'holding',
#    u'liquidity',
#    u'need',
#    u'currency',
#    u'portfolio',
#    u'duration',
#    u'month',
#    u'duration'],
#   [u'connection',
#    u'arrangement',
#    u'investment',
#    u'facility',
#    u'currency',
#    u'holding',
#    u'government',
#    u'security',
#    u'bank',
#    u'agreement',
#    u'repurchase',
#    u'security',
#    u'calendar',
#    u'day'],
#   [u'operation', u'paragraph'],
#   [u'governor', u'member', u'absence', u'member', u'member', u'absence'],
#   [u'meeting',
#    u'request',
#    u'member',
#    u'request',
#    u'purpose',
#    u'operation',
#    u'matter',
#    u'responsibility'],
#   [u'approval',
#    u'agreement',
#    u'division',
#    u'responsibility',
#    u'currency',
#    u'operation',
#    u'currency',
#    u'operation',
#    u'policy',
#    u'matter',
#    u'currency',
#    u'operation',
#    u'time',
#    u'time',
#    u'report',
#    u'information',
#    u'policy'],
#   [u'staff',
#    u'officer',
#    u'information',
#    u'currency',
#    u'operation',
#    u'official'],
#   [u'currency',
#    u'operation',
#    u'accordance',
#    u'paragraph',
#    u'statement',
#    u'procedure',
#    u'respect'],
#   [u'vote', u'form'],
#   [u'operation',
#    u'currency',
#    u'market',
#    u'condition',
#    u'market',
#    u'exchange',
#    u'rate',
#    u'dollar',
#    u'reflect',
#    u'action',
#    u'behavior'],
#   [u'end', u'spot', u'purchase', u'sale', u'exchange'],
#   [u'currency', u'swap', u'arrangement', u'bank'],
#   [u'respect', u'bank', u'country', u'institution'],
#   [u'transaction', u'balance', u'light', u'future', u'currency'],
#   [u'mean', u'meeting', u'commitment', u'currency', u'operation'],
#   [u'currency',
#    u'operation',
#    u'consultation',
#    u'cooperation',
#    u'cooperation',
#    u'authority',
#    u'manner',
#    u'obligation',
#    u'exchange',
#    u'arrangement'],
#   [u'vote', u'instruction', u'respect', u'form'],
#   [u'instruction',
#    u'operation',
#    u'authorization',
#    u'direction',
#    u'set',
#    u'understanding',
#    u'respect',
#    u'consultation',
#    u'clearance'],
#   [u'operation', u'clearance'],
#   [u'consultation',
#    u'time',
#    u'operation',
#    u'change',
#    u'position',
#    u'currency',
#    u'day',
#    u'meeting'],
#   [u'operation',
#    u'change',
#    u'day',
#    u'net',
#    u'position',
#    u'currency',
#    u'operation',
#    u'repayment',
#    u'swap',
#    u'drawing'],
#   [u'operation',
#    u'volume',
#    u'trading',
#    u'currency',
#    u'change',
#    u'net',
#    u'position',
#    u'currency',
#    u'limit'],
#   [u'swap', u'bank', u'ii', u'percent', u'size', u'swap', u'arrangement'],
#   [u'consultation',
#    u'time',
#    u'consultation',
#    u'time',
#    u'operation',
#    u'change',
#    u'position',
#    u'currency',
#    u'meeting'],
#   [u'swap', u'bank', u'ii', u'percent', u'size', u'swap', u'arrangement'],
#   [u'swap', u'drawing', u'operation', u'character'],
#   [u'report', u'feasibility', u'cost', u'security', u'government', u'agency'],
#   [u'advantage',
#    u'transaction',
#    u'obligation',
#    u'use',
#    u'supplement',
#    u'purchase',
#    u'security',
#    u'period',
#    u'surpluse',
#    u'market',
#    u'supply',
#    u'debt'],
#   [u'resumption',
#    u'deficit',
#    u'increase',
#    u'market',
#    u'supply',
#    u'obligation',
#    u'member',
#    u'vehicle',
#    u'need',
#    u'addition'],
#   [u'report',
#    u'transaction',
#    u'gnma',
#    u'security',
#    u'start-up',
#    u'cost',
#    u'conduct',
#    u'market',
#    u'operation'],
#   [u'background', u'transaction', u'obligation'],
#   [u'obligation', u'collateral', u'repurchase', u'agreement'],
#   [u'vote', u'minute', u'meeting'],
#   [u'development', u'exchange', u'market'],
#   [u'market', u'operation', u'currency', u'period', u'meeting'],
#   [u'development',
#    u'market',
#    u'market',
#    u'transaction',
#    u'government',
#    u'security',
#    u'agency',
#    u'obligation',
#    u'period'],
#   [u'vote', u'transaction'],
#   [u'portion', u'discussion', u'report', u'group', u'announcement'],
#   [u'course',
#    u'discussion',
#    u'member',
#    u'importance',
#    u'information',
#    u'reason',
#    u'policy',
#    u'decision',
#    u'decision',
#    u'objective'],
#   [u'support',
#    u'use',
#    u'standard',
#    u'wording',
#    u'appraisal',
#    u'outlook',
#    u'view',
#    u'balance',
#    u'risk'],
#   [u'time',
#    u'member',
#    u'approach',
#    u'wording',
#    u'announcement',
#    u'assessment',
#    u'balance',
#    u'risk',
#    u'time',
#    u'condition'],
#   [u'discussion', u'member', u'value', u'drawback', u'publication', u'minute'],
#   [u'benefit',
#    u'provision',
#    u'information',
#    u'meeting',
#    u'consideration',
#    u'stance',
#    u'policy'],
#   [u'member', u'concern', u'release', u'minute', u'deliberation', u'minute'],
#   [u'member',
#    u'importance',
#    u'time',
#    u'minute',
#    u'difference',
#    u'opinion',
#    u'member',
#    u'committee'],
#   [u'member',
#    u'advantage',
#    u'change',
#    u'content',
#    u'time',
#    u'horizon',
#    u'frequency',
#    u'forecast',
#    u'policy',
#    u'report'],
#   [u'member', u'practice', u'way', u'change'],
#   [u'need',
#    u'decision',
#    u'change',
#    u'time',
#    u'staff',
#    u'degree',
#    u'member',
#    u'adjustment',
#    u'procedure'],
#   [u'discussion', u'outlook', u'conduct', u'policy', u'period'],
#   [u'economy', u'pace', u'quarter', u'pace', u'quarter'],
#   [u'spending', u'rate', u'month', u'year', u'activity', u'sector', u'level'],
#   [u'business',
#    u'outlay',
#    u'equipment',
#    u'software',
#    u'gain',
#    u'quarter',
#    u'firm',
#    u'inventory',
#    u'time',
#    u'quarters'],
#   [u'pace',
#    u'activity',
#    u'labor',
#    u'market',
#    u'payroll',
#    u'acceleration',
#    u'quarter'],
#   [u'consumer',
#    u'price',
#    u'inflation',
#    u'inflation',
#    u'expectation',
#    u'month'],
#   [u'payroll', u'month', u'level'],
#   [u'increase',
#    u'employment',
#    u'quarter',
#    u'recovery',
#    u'labor',
#    u'market',
#    u'improvement',
#    u'loss',
#    u'half',
#    u'year'],
#   [u'payroll', u'pace', u'month', u'hiring', u'trade'],
#   [u'sector',
#    u'job',
#    u'gain',
#    u'construction',
#    u'education',
#    u'health',
#    u'service',
#    u'business',
#    u'service'],
#   [u'hour', u'production', u'worker', u'gain', u'month'],
#   [u'hour', u'employee', u'quarter', u'increase'],
#   [u'payroll',
#    u'datum',
#    u'unemployment',
#    u'rate',
#    u'household',
#    u'survey',
#    u'percent',
#    u'decline',
#    u'labor',
#    u'force',
#    u'participation',
#    u'rate'],
#   [u'claim',
#    u'unemployment',
#    u'insurance',
#    u'week',
#    u'reference',
#    u'week',
#    u'employment',
#    u'report',
#    u'job',
#    u'growth'],
#   [u'pace', u'expansion', u'sector', u'quarter'],
#   [u'production',
#    u'rate',
#    u'quarter',
#    u'manufacturing',
#    u'production',
#    u'gain'],
#   [u'industry',
#    u'semiconductor',
#    u'computer',
#    u'communication',
#    u'equipment',
#    u'one-third',
#    u'increase',
#    u'production',
#    u'quarter'],
#   [u'quarter',
#    u'production',
#    u'motor',
#    u'vehicle',
#    u'quarter',
#    u'rate',
#    u'manufacturing'],
#   [u'manufacturing',
#    u'sector',
#    u'output',
#    u'quarter',
#    u'output',
#    u'utility',
#    u'advance',
#    u'electricity',
#    u'generation',
#    u'strengthening',
#    u'manufacturing',
#    u'sector'],
#   [u'capacity', u'utilization', u'average'],
#   [u'sale',
#    u'vehicle',
#    u'average',
#    u'third-quarter',
#    u'pace',
#    u'half',
#    u'year'],
#   [u'datum',
#    u'sale',
#    u'auto',
#    u'increase',
#    u'consumption',
#    u'expenditure',
#    u'quarter'],
#   [u'income'],
#   [u'spending',
#    u'stock',
#    u'market',
#    u'gain',
#    u'consumer',
#    u'confidence',
#    u'index',
#    u'consumer',
#    u'sentiment',
#    u'index',
#    u'consumer',
#    u'confidence',
#    u'reading'],
#   [u'activity', u'housing', u'market'],
#   [u'start', u'bit', u'rate', u'level', u'year'],
#   [u'home', u'sale', u'month', u'high', u'year'],
#   [u'existing', u'home', u'sale', u'high', u'level', u'sale', u'half'],
#   [u'datum',
#    u'business',
#    u'purchase',
#    u'transportation',
#    u'equipment',
#    u'quarter',
#    u'spending',
#    u'capital',
#    u'good',
#    u'pace'],
#   [u'expenditure',
#    u'aircraft',
#    u'quarter',
#    u'level',
#    u'level',
#    u'downturn',
#    u'terrorist',
#    u'attack'],
#   [u'fleet', u'sale', u'vehicle', u'truck', u'sale'],
#   [u'sector',
#    u'outlay',
#    u'equipment',
#    u'software',
#    u'increase',
#    u'quarter',
#    u'spending',
#    u'communication',
#    u'equipment',
#    u'quarters',
#    u'growth'],
#   [u'transportation',
#    u'tech',
#    u'shipment',
#    u'quarter',
#    u'trend',
#    u'order',
#    u'year',
#    u'gain',
#    u'spending'],
#   [u'balance', u'half', u'spending', u'construction', u'quarters'],
#   [u'sector', u'manufacturing', u'sector', u'outlay', u'quarter'],
#   [u'book',
#    u'value',
#    u'manufacturing',
#    u'trade',
#    u'inventory',
#    u'motor',
#    u'vehicle',
#    u'increase'],
#   [u'stock',
#    u'manufacturer',
#    u'average',
#    u'wholesaler',
#    u'retailer',
#    u'inventory',
#    u'pace'],
#   [u'increase', u'sale', u'book-value', u'ratio', u'lows'],
#   [u'trade', u'deficit', u'level', u'year'],
#   [u'data', u'pickup', u'activity', u'country', u'quarter'],
#   [u'export', u'machinery', u'order', u'production'],
#   [u'manufacturing', u'strength'],
#   [u'indicator', u'business', u'sale', u'expansion'],
#   [u'employment',
#    u'sale',
#    u'datum',
#    u'quarter',
#    u'housing',
#    u'sector',
#    u'contribution',
#    u'growth'],
#   [u'consumer',
#    u'price',
#    u'balance',
#    u'month',
#    u'increase',
#    u'price',
#    u'rise',
#    u'food',
#    u'price',
#    u'drop',
#    u'energy',
#    u'price'],
#   [u'year', u'consumer', u'price', u'index', u'increase', u'year'],
#   [u'producer', u'price', u'good', u'year', u'advance', u'year'],
#   [u'rise',
#    u'year',
#    u'increase',
#    u'food',
#    u'energy',
#    u'price',
#    u'producer',
#    u'price'],
#   [u'regard',
#    u'labor',
#    u'cost',
#    u'earning',
#    u'production',
#    u'worker',
#    u'payroll',
#    u'month',
#    u'increase'],
#   [u'meeting',
#    u'directive',
#    u'condition',
#    u'reserve',
#    u'market',
#    u'fund',
#    u'rate',
#    u'percent'],
#   [u'decision',
#    u'member',
#    u'upside',
#    u'risk',
#    u'attainment',
#    u'growth',
#    u'quarters'],
#   [u'probability', u'fall', u'inflation', u'month', u'rise', u'inflation'],
#   [u'inflation',
#    u'resource',
#    u'slack',
#    u'policy',
#    u'accommodation',
#    u'period'],
#   [u'decision',
#    u'meeting',
#    u'target',
#    u'fund',
#    u'rate',
#    u'percent',
#    u'market',
#    u'rate',
#    u'future',
#    u'half',
#    u'announcement'],
#   [u'future',
#    u'rate',
#    u'half',
#    u'year',
#    u'basis',
#    u'point',
#    u'response',
#    u'assessment',
#    u'probability',
#    u'decline',
#    u'inflation',
#    u'month',
#    u'level',
#    u'rise',
#    u'inflation'],
#   [u'release',
#    u'minute',
#    u'meeting',
#    u'time',
#    u'possibility',
#    u'slack',
#    u'productivity',
#    u'growth',
#    u'publication',
#    u'growth',
#    u'employment',
#    u'market',
#    u'participant',
#    u'date',
#    u'onset',
#    u'tightening',
#    u'month',
#    u'time',
#    u'fall'],
#   [u'change', u'policy', u'expectation', u'yield', u'period'],
#   [u'yield',
#    u'debt',
#    u'drop',
#    u'yield',
#    u'rate',
#    u'inflation',
#    u'compensation'],
#   [u'yield', u'security', u'yield'],
#   [u'equity',
#    u'index',
#    u'response',
#    u'decline',
#    u'yield',
#    u'news',
#    u'outlook',
#    u'profit'],
#   [u'exchange', u'value', u'dollar', u'currency', u'index', u'net', u'period'],
#   [u'investor',
#    u'concern',
#    u'ability',
#    u'account',
#    u'deficit',
#    u'factor',
#    u'pressure',
#    u'dollar'],
#   [u'decline'],
#   [u'decline', u'quarter', u'record', u'start', u'data', u'collection'],
#   [u'weakness',
#    u'deposit',
#    u'extent',
#    u'money',
#    u'market',
#    u'fund',
#    u'unwinding',
#    u'buildup',
#    u'deposit',
#    u'mortgage',
#    u'refinancing',
#    u'activity',
#    u'portfolio',
#    u'shift',
#    u'household',
#    u'equity'],
#   [u'staff',
#    u'forecast',
#    u'meeting',
#    u'momentum',
#    u'activity',
#    u'half',
#    u'half',
#    u'year',
#    u'gain',
#    u'spending',
#    u'production',
#    u'improvement',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'stimulus', u'policy', u'demand', u'uptrend'],
#   [u'addition',
#    u'labor',
#    u'market',
#    u'condition',
#    u'effect',
#    u'productivity',
#    u'growth',
#    u'income',
#    u'household',
#    u'spending',
#    u'business',
#    u'investment',
#    u'spending',
#    u'strengthening',
#    u'response',
#    u'acceleration',
#    u'business',
#    u'output',
#    u'profit',
#    u'financing',
#    u'condition'],
#   [u'pressure',
#    u'consumer',
#    u'price',
#    u'inflation',
#    u'forecast',
#    u'slack',
#    u'labor',
#    u'product',
#    u'market'],
#   [u'discussion',
#    u'development',
#    u'member',
#    u'information',
#    u'meeting',
#    u'assessment',
#    u'expansion',
#    u'growth',
#    u'way',
#    u'year'],
#   [u'business',
#    u'expenditure',
#    u'upward',
#    u'trajectory',
#    u'report',
#    u'business',
#    u'sentiment'],
#   [u'business',
#    u'expenditure',
#    u'source',
#    u'strength',
#    u'expansion',
#    u'household',
#    u'government',
#    u'spending'],
#   [u'factor',
#    u'outlook',
#    u'activity',
#    u'policy',
#    u'condition',
#    u'market',
#    u'effect',
#    u'uptrend',
#    u'productivity',
#    u'business',
#    u'investment',
#    u'incentive',
#    u'lag',
#    u'household',
#    u'income'],
#   [u'member',
#    u'disappointment',
#    u'acceleration',
#    u'activity',
#    u'strengthening',
#    u'employment',
#    u'number',
#    u'sign',
#    u'labor',
#    u'market'],
#   [u'expectation', u'growth', u'demand', u'worker', u'prospect'],
#   [u'outlook',
#    u'inflation',
#    u'member',
#    u'margin',
#    u'slack',
#    u'labor',
#    u'product',
#    u'market',
#    u'wage',
#    u'price',
#    u'strength',
#    u'productivity'],
#   [u'consumer',
#    u'inflation',
#    u'number',
#    u'member',
#    u'possibility',
#    u'decline',
#    u'inflation',
#    u'level'],
#   [u'year', u'member', u'net', u'change', u'consumer', u'price', u'inflation'],
#   [u'practice',
#    u'meeting',
#    u'report',
#    u'economy',
#    u'policy',
#    u'member',
#    u'president',
#    u'projection',
#    u'growth',
#    u'rate',
#    u'unemployment',
#    u'consumer',
#    u'price',
#    u'inflation',
#    u'year'],
#   [u'forecast',
#    u'continuation',
#    u'growth',
#    u'activity',
#    u'decline',
#    u'unemployment',
#    u'rate',
#    u'inflation'],
#   [u'forecast',
#    u'expansion',
#    u'quarter',
#    u'quarter',
#    u'tendency',
#    u'percent',
#    u'range',
#    u'percent'],
#   [u'projection', u'unemployment', u'rate', u'quarter', u'range', u'percent'],
#   [u'discussion',
#    u'development',
#    u'nation',
#    u'member',
#    u'indication',
#    u'business',
#    u'confidence',
#    u'softness',
#    u'number',
#    u'industry',
#    u'sign',
#    u'business',
#    u'spending',
#    u'equipment',
#    u'software',
#    u'inventory'],
#   [u'member',
#    u'variety',
#    u'factor',
#    u'pickup',
#    u'business',
#    u'capital',
#    u'expenditure',
#    u'year',
#    u'strength',
#    u'order',
#    u'shipment',
#    u'profit',
#    u'cash',
#    u'flow',
#    u'condition',
#    u'business',
#    u'firm',
#    u'availability',
#    u'financing',
#    u'term',
#    u'tax',
#    u'incentive',
#    u'expenditure',
#    u'equipment'],
#   [u'report',
#    u'business',
#    u'contact',
#    u'capital',
#    u'spending',
#    u'plan',
#    u'acceleration',
#    u'business',
#    u'expenditure',
#    u'widening',
#    u'range',
#    u'capital',
#    u'good'],
#   [u'contact',
#    u'replacement',
#    u'demand',
#    u'opportunity',
#    u'equipment',
#    u'factor',
#    u'investment',
#    u'decision',
#    u'report',
#    u'investment',
#    u'spending',
#    u'capacity'],
#   [u'member',
#    u'business',
#    u'inventory',
#    u'investment',
#    u'support',
#    u'expansion',
#    u'year'],
#   [u'inventory',
#    u'level',
#    u'relation',
#    u'sale',
#    u'growth',
#    u'demand',
#    u'line',
#    u'forecast',
#    u'year',
#    u'business',
#    u'firm',
#    u'addition',
#    u'inventory'],
#   [u'inventory', u'quarter', u'balance', u'business', u'increase', u'sale'],
#   [u'business', u'expenditure', u'employer', u'degree', u'caution', u'worker'],
#   [u'employment',
#    u'mid-2003',
#    u'period',
#    u'job',
#    u'loss',
#    u'gain',
#    u'stage',
#    u'business',
#    u'cycle'],
#   [u'factor',
#    u'hiring',
#    u'ability',
#    u'business',
#    u'firm',
#    u'demand',
#    u'productivity',
#    u'workforce',
#    u'worker'],
#   [u'background', u'labor', u'market', u'area', u'sign', u'improvement'],
#   [u'regard',
#    u'member',
#    u'development',
#    u'decline',
#    u'claim',
#    u'rise',
#    u'aggregate',
#    u'hour',
#    u'quarter'],
#   [u'member',
#    u'growth',
#    u'employment',
#    u'prospect',
#    u'context',
#    u'strengthening',
#    u'demand',
#    u'expectation',
#    u'slowing',
#    u'growth',
#    u'productivity',
#    u'pace',
#    u'quarters'],
#   [u'emphasized',
#    u'timing',
#    u'extent',
#    u'improvement',
#    u'employment',
#    u'uncertainty'],
#   [u'household', u'sector', u'impetus', u'expansion'],
#   [u'spending',
#    u'policy',
#    u'wealth',
#    u'effect',
#    u'estate',
#    u'equity',
#    u'price',
#    u'consumer',
#    u'confidence',
#    u'outlook'],
#   [u'member', u'retailer', u'country', u'sale', u'holiday', u'period'],
#   [u'respect',
#    u'outlook',
#    u'consumer',
#    u'spending',
#    u'growth',
#    u'productivity',
#    u'income',
#    u'time',
#    u'consumption',
#    u'stimulus',
#    u'tax',
#    u'cut'],
#   [u'construction', u'activity', u'level', u'decline', u'mortgage', u'rate'],
#   [u'housing', u'industry', u'level', u'construction', u'activity'],
#   [u'policy',
#    u'stimulus',
#    u'economy',
#    u'year',
#    u'tax',
#    u'refund',
#    u'result',
#    u'overwithholding'],
#   [u'term', u'stimulus', u'legislation'],
#   [u'regard', u'member', u'expansion', u'impulse'],
#   [u'member',
#    u'concern',
#    u'prospect',
#    u'deficit',
#    u'implication',
#    u'performance',
#    u'economy'],
#   [u'comment',
#    u'economy',
#    u'member',
#    u'strengthening',
#    u'activity',
#    u'decline',
#    u'exchange',
#    u'value',
#    u'dollar',
#    u'export'],
#   [u'strength',
#    u'import',
#    u'widening',
#    u'trade',
#    u'deficit',
#    u'export',
#    u'arithmetic',
#    u'activity',
#    u'year'],
#   [u'member',
#    u'implication',
#    u'nation',
#    u'debt',
#    u'market',
#    u'economy',
#    u'time'],
#   [u'discussion',
#    u'outlook',
#    u'inflation',
#    u'member',
#    u'consumer',
#    u'price',
#    u'year',
#    u'strength',
#    u'expansion',
#    u'output',
#    u'gap',
#    u'gain',
#    u'productivity',
#    u'pressure',
#    u'cost',
#    u'price'],
#   [u'member',
#    u'relationship',
#    u'output',
#    u'gap',
#    u'inflation',
#    u'outlook',
#    u'productivity'],
#   [u'member',
#    u'change',
#    u'consumer',
#    u'price',
#    u'inflation',
#    u'divergence',
#    u'opinion',
#    u'direction'],
#   [u'view', u'disinflation', u'prospect'],
#   [u'member', u'disinflation', u'growth', u'productivity', u'non-threatening'],
#   [u'strength', u'demand', u'extent', u'disinflation', u'time'],
#   [u'member',
#    u'view',
#    u'consumer',
#    u'price',
#    u'course',
#    u'year',
#    u'light',
#    u'stimulus',
#    u'policy',
#    u'possibility',
#    u'pickup',
#    u'activity',
#    u'employment',
#    u'forecast',
#    u'growth',
#    u'productivity'],
#   [u'evidence',
#    u'possibility',
#    u'uptick',
#    u'inflation',
#    u'member',
#    u'addition',
#    u'advance',
#    u'price',
#    u'commodity',
#    u'oil',
#    u'report',
#    u'business',
#    u'contact',
#    u'firm',
#    u'selling',
#    u'price',
#    u'level',
#    u'effort',
#    u'increase',
#    u'cost'],
#   [u'pricing', u'power', u'business', u'firm'],
#   [u'discussion',
#    u'policy',
#    u'period',
#    u'member',
#    u'policy',
#    u'stance',
#    u'reserve',
#    u'condition',
#    u'target',
#    u'fund',
#    u'rate',
#    u'percent'],
#   [u'member',
#    u'expansion',
#    u'point',
#    u'policy',
#    u'stance',
#    u'adjustment',
#    u'circumstance'],
#   [u'regard',
#    u'labor',
#    u'resource',
#    u'inflation',
#    u'level',
#    u'inflation',
#    u'direction',
#    u'year'],
#   [u'member',
#    u'risk',
#    u'policy',
#    u'stance',
#    u'risk',
#    u'elimination',
#    u'slack'],
#   [u'regard',
#    u'wording',
#    u'statement',
#    u'meeting',
#    u'member',
#    u'length',
#    u'desirability',
#    u'reference',
#    u'statement',
#    u'prospect',
#    u'policy',
#    u'period'],
#   [u'existing',
#    u'language',
#    u'meeting',
#    u'inflation',
#    u'slack',
#    u'resource',
#    u'use',
#    u'notion',
#    u'degree',
#    u'policy',
#    u'accommodation',
#    u'condition',
#    u'passage',
#    u'time'],
#   [u'member',
#    u'change',
#    u'wording',
#    u'policy',
#    u'tightening',
#    u'term',
#    u'flexibility',
#    u'action',
#    u'decision',
#    u'basis',
#    u'condition'],
#   [u'difference',
#    u'opinion',
#    u'regard',
#    u'proposal',
#    u'consideration',
#    u'reference',
#    u'period',
#    u'patience'],
#   [u'proposal',
#    u'wording',
#    u'information',
#    u'strategy',
#    u'environment',
#    u'price',
#    u'stability',
#    u'slack',
#    u'circumstance',
#    u'effect',
#    u'market'],
#   [u'number',
#    u'member',
#    u'expectation',
#    u'policy',
#    u'accommodation',
#    u'valuation',
#    u'market',
#    u'room',
#    u'risk',
#    u'change',
#    u'wording',
#    u'market',
#    u'circumstance',
#    u'future'],
#   [u'member',
#    u'agreement',
#    u'respect',
#    u'merit',
#    u'language',
#    u'change',
#    u'reference',
#    u'period',
#    u'reference',
#    u'ability'],
#   [u'view',
#    u'replacement',
#    u'language',
#    u'expectation',
#    u'way',
#    u'conduct',
#    u'policy',
#    u'economy',
#    u'uptrend',
#    u'language'],
#   [u'conclusion',
#    u'meeting',
#    u'transaction',
#    u'accordance',
#    u'policy',
#    u'directive',
#    u'condition',
#    u'price',
#    u'stability',
#    u'growth',
#    u'output'],
#   [u'objective',
#    u'future',
#    u'condition',
#    u'reserve',
#    u'market',
#    u'fund',
#    u'rate',
#    u'average',
#    u'percent'],
#   [u'vote',
#    u'approval',
#    u'paragraph',
#    u'inclusion',
#    u'press',
#    u'statement',
#    u'meeting',
#    u'upside',
#    u'risk',
#    u'attainment',
#    u'growth',
#    u'quarters'],
#   [u'probability', u'fall', u'inflation', u'month', u'rise', u'inflation'],
#   [u'inflation', u'resource', u'slack', u'policy', u'accommodation'],
#   [u'portion', u'meeting', u'review', u'outlook'],
#   [u'note', u'selection', u'board', u'director']],
#  [[u'alternate'],
#   [u'special'],
#   [u'alternate'],
#   [u'elected',
#    u'alternate',
#    u'alternate',
#    u'alternate',
#    u'alternate',
#    u'alternate',
#    u'alternate',
#    u'effective'],
#   [u'alternate'],
#   [u'alternate', u'effective'],
#   [u'unanimous', u'official', u'official', u'unanimous'],
#   [u'unanimous', u'subject', u'satisfactory'],
#   [u'unanimous', u'small', u'electronic', u'confidential'],
#   [u'unanimous'],
#   [u'open'],
#   [u'necessary',
#    u'recent',
#    u'domestic',
#    u'direct',
#    u'open',
#    u'foreign',
#    u'international',
#    u'regular',
#    u'individual',
#    u'aggregate',
#    u'forward',
#    u'domestic',
#    u'direct',
#    u'competitive',
#    u'reasonable',
#    u'individual',
#    u'pursuant'],
#   [u'direct', u'competitive', u'reasonable', u'individual'],
#   [u'effective', u'open', u'overnight', u'competitive'],
#   [u'lending', u'consistent', u'reasonable', u'total', u'specific'],
#   [u'single'],
#   [u'effective',
#    u'open',
#    u'short-term',
#    u'foreign',
#    u'international',
#    u'fiscal',
#    u'pursuant',
#    u'comparable',
#    u'available',
#    u'appropriate',
#    u'corresponding',
#    u'foreign',
#    u'international',
#    u'fiscal'],
#   [u'appropriate'],
#   [u'intermeeting', u'exceptional', u'intended', u'federal'],
#   [u'recent',
#    u'long-run',
#    u'sustainable',
#    u'economic',
#    u'economic',
#    u'financial',
#    u'monetary',
#    u'intermeeting'],
#   [u'consistent', u'feasible'],
#   [u'domestic', u'open', u'pursuant', u'fiscal'],
#   [u'official',
#    u'foreign',
#    u'international',
#    u'eligible',
#    u'short-term',
#    u'so-called',
#    u'repo'],
#   [u'unanimous', u'foreign'],
#   [u'necessary',
#    u'foreign',
#    u'express',
#    u'pursuant',
#    u'procedural',
#    u'following',
#    u'foreign',
#    u'forward',
#    u'open',
#    u'foreign',
#    u'monetary',
#    u'international',
#    u'financial',
#    u'canadian',
#    u'danish',
#    u'sterling',
#    u'japanese',
#    u'mexican',
#    u'norwegian',
#    u'swedish',
#    u'swiss',
#    u'outstanding',
#    u'foreign'],
#   [u'foreign', u'foreign', u'reciprocal', u'outstanding', u'exceptional'],
#   [u'overall', u'open', u'foreign'],
#   [u'overall', u'open', u'foreign', u'defined', u'net', u'individual'],
#   [u'single',
#    u'foreign',
#    u'defined',
#    u'outstanding',
#    u'future',
#    u'outstanding',
#    u'future'],
#   [u'reciprocal',
#    u'following',
#    u'foreign',
#    u'foreign',
#    u'equivalent',
#    u'proposed',
#    u'new'],
#   [u'foreign'],
#   [u'foreign', u'foreign', u'central'],
#   [u'normal', u'foreign', u'central', u'foreign'],
#   [u'foreign', u'central', u'foreign', u'specific'],
#   [u'foreign'],
#   [u'foreign', u'adequate', u'average', u'calculated'],
#   [u'appropriate', u'foreign', u'foreign', u'central'],
#   [u'pursuant', u'foreign'],
#   [u'foreign', u'alternate'],
#   [u'manager', u'recent', u'contemplated', u'manager'],
#   [u'foreign', u'foreign', u'foreign', u'appropriate'],
#   [u'pertinent', u'foreign', u'appropriate'],
#   [u'foreign'],
#   [u'unanimous', u'foreign'],
#   [u'foreign', u'disorderly', u'consistent'],
#   [u'forward', u'foreign'],
#   [u'reciprocal', u'selected', u'foreign', u'central'],
#   [u'central', u'international', u'monetary'],
#   [u'adjust', u'probable'],
#   [u'particular', u'facilitate'],
#   [u'foreign',
#    u'continuous',
#    u'appropriate',
#    u'foreign',
#    u'monetary',
#    u'consistent'],
#   [u'unanimous', u'procedural', u'foreign'],
#   [u'procedural',
#    u'pursuant',
#    u'foreign',
#    u'foreign',
#    u'manager',
#    u'following',
#    u'procedural',
#    u'foreign'],
#   [u'pursuant'],
#   [u'feasible',
#    u'available',
#    u'overall',
#    u'open',
#    u'foreign',
#    u'recent',
#    u'regular'],
#   [u'single', u'foreign'],
#   [u'substantial', u'particular'],
#   [u'foreign', u'larger'],
#   [u'feasible',
#    u'available',
#    u'feasible',
#    u'available',
#    u'overall',
#    u'open',
#    u'foreign',
#    u'recent',
#    u'regular'],
#   [u'foreign', u'larger'],
#   [u'routine'],
#   [u'mortgage-backed', u'federal'],
#   [u'potential', u'direct', u'large', u'federal', u'reduced'],
#   [u'large', u'federal', u'sizable', u'preferred', u'permanent'],
#   [u'outright', u'mortgage-backed', u'feasible', u'sizeable', u'open'],
#   [u'outright', u'mortgage-backed'],
#   [u'eligible'],
#   [u'unanimous'],
#   [u'recent', u'foreign'],
#   [u'open', u'foreign', u'previous'],
#   [u'domestic', u'financial', u'open', u'federal'],
#   [u'unanimous'],
#   [u'working'],
#   [u'public', u'related', u'longer-term'],
#   [u'limited', u'particular', u'economic'],
#   [u'flexible', u'economic'],
#   [u'potential'],
#   [u'possible', u'complete', u'current'],
#   [u'expressed', u'accelerated', u'potential'],
#   [u'sufficient', u'large'],
#   [u'possible', u'individual', u'semi-annual'],
#   [u'general', u'little', u'current', u'significant', u'minor'],
#   [u'possible', u'minor', u'current'],
#   [u'economic', u'monetary', u'intermeeting'],
#   [u'robust', u'fourth', u'exceptional'],
#   [u'solid', u'final', u'residential', u'high'],
#   [u'likely', u'posted', u'moderate', u'fourth'],
#   [u'strong', u'economic', u'private', u'small', u'fourth'],
#   [u'closing'],
#   [u'private', u'nonfarm'],
#   [u'average',
#    u'monthly',
#    u'fourth',
#    u'indicative',
#    u'weak',
#    u'clear',
#    u'average',
#    u'monthly'],
#   [u'previous', u'holiday-related', u'retail', u'average'],
#   [u'professional'],
#   [u'average', u'weekly', u'nonsupervisory', u'previous'],
#   [u'aggregate', u'nonfarm', u'fourth', u'quarterly'],
#   [u'weak'],
#   [u'initial', u'improved'],
#   [u'industrial', u'fourth'],
#   [u'total', u'industrial', u'fastest', u'second', u'solid', u'widespread'],
#   [u'high-tech', u'total', u'industrial', u'fourth'],
#   [u'fourth', u'overall'],
#   [u'solid'],
#   [u'unchanged', u'long-term'],
#   [u'light', u'fourth-quarter', u'torrid'],
#   [u'retail', u'consistent', u'solid', u'real', u'personal', u'fourth'],
#   [u'real', u'disposable', u'personal'],
#   [u'recent', u'greater', u'average'],
#   [u'robust'],
#   [u'exceptional', u'highest'],
#   [u'consecutive', u'record'],
#   [u'higher', u'average', u'monthly'],
#   [u'available', u'fourth', u'moderate'],
#   [u'fourth'],
#   [u'light'],
#   [u'high-tech', u'real', u'sizable', u'fourth', u'little', u'double-digit'],
#   [u'outside',
#    u'high',
#    u'nominal',
#    u'unchanged',
#    u'fourth',
#    u'upward',
#    u'consistent'],
#   [u'steady', u'real', u'private', u'nonresidential', u'fourth'],
#   [u'commercial',
#    u'health-care',
#    u'average',
#    u'nominal',
#    u'unchanged',
#    u'previous'],
#   [u'consecutive', u'significant', u'monthly'],
#   [u'little', u'non-auto', u'brisk'],
#   [u'strong', u'recent'],
#   [u'international', u'lowest'],
#   [u'recent', u'economic', u'major', u'foreign', u'industrial', u'fourth'],
#   [u'japanese', u'industrial'],
#   [u'euro-area'],
#   [u'retail', u'maintained'],
#   [u'canadian', u'strong', u'fourth', u'significant'],
#   [u'overall', u'flat', u'past', u'small', u'core', u'large', u'sizable'],
#   [u'moderate', u'previous'],
#   [u'finished', u'previous'],
#   [u'substantial', u'core', u'little'],
#   [u'average', u'hourly', u'nonsupervisory', u'private', u'nonfarm'],
#   [u'consistent', u'federal'],
#   [u'downside', u'sustainable', u'equal'],
#   [u'unwelcome', u'recent', u'equal'],
#   [u'low', u'considerable'],
#   [u'federal', u'financial', u'unchanged'],
#   [u'second', u'unwelcome', u'recent', u'equal'],
#   [u'persistent', u'rapid', u'modest', u'expected'],
#   [u'intermediate', u'longer-term', u'nominal', u'intermeeting'],
#   [u'inflation-indexed', u'nominal', u'real', u'reduced'],
#   [u'investment-grade', u'speculative-grade'],
#   [u'major', u'positive'],
#   [u'major', u'intermeeting'],
#   [u'ongoing', u'current', u'primary'],
#   [u'fourth', u'consecutive', u'monthly'],
#   [u'fourth', u'largest', u'consistent'],
#   [u'liquid',
#    u'lesser',
#    u'retail',
#    u'mutual',
#    u'large',
#    u'previous',
#    u'heavy'],
#   [u'economic', u'second', u'current', u'ongoing', u'visible'],
#   [u'considerable', u'fiscal', u'monetary', u'aggregate', u'solid'],
#   [u'strong', u'permanent', u'favorable'],
#   [u'slight', u'downward', u'core', u'ongoing'],
#   [u'current',
#    u'prospective',
#    u'economic',
#    u'available',
#    u'earlier',
#    u'robust',
#    u'economic',
#    u'mid',
#    u'likely'],
#   [u'solid', u'widespread', u'improved'],
#   [u'significant'],
#   [u'favorable',
#    u'economic',
#    u'stimulative',
#    u'fiscal',
#    u'monetary',
#    u'accommodative',
#    u'financial',
#    u'positive',
#    u'strong'],
#   [u'expressed', u'economic', u'significant', u'positive'],
#   [u'above-trend', u'economic', u'likely'],
#   [u'wide', u'concurrent'],
#   [u'modest', u'current', u'subdued'],
#   [u'little'],
#   [u'semi-annual', u'monetary', u'individual'],
#   [u'vigorous', u'economic', u'low'],
#   [u'real', u'fourth', u'fourth', u'central'],
#   [u'civilian', u'fourth'],
#   [u'widespread'],
#   [u'new',
#    u'improved',
#    u'financial',
#    u'general',
#    u'favorable',
#    u'temporary',
#    u'new'],
#   [u'anecdotal', u'indicative', u'appreciable'],
#   [u'cost-saving', u'productive', u'new', u'driving'],
#   [u'likely', u'economic'],
#   [u'business', u'low', u'brisk', u'current', u'commensurate'],
#   [u'fourth', u'confident'],
#   [u'high', u'new'],
#   [u'protracted', u'weaker', u'typical', u'similar', u'earlier'],
#   [u'key', u'new'],
#   [u'soft', u'modest'],
#   [u'positive', u'initial', u'fourth'],
#   [u'faster', u'likely', u'aggregate', u'extraordinary', u'recent'],
#   [u'subject', u'considerable'],
#   [u'major'],
#   [u'stimulative', u'fiscal', u'monetary', u'real', u'increased', u'economic'],
#   [u'solid'],
#   [u'overall', u'elevated', u'earlier'],
#   [u'high', u'recent'],
#   [u'high', u'robust'],
#   [u'fiscal', u'considerable', u'large'],
#   [u'nearer', u'fiscal'],
#   [u'robust', u'fiscal'],
#   [u'expressed', u'longer-run', u'large', u'federal', u'future'],
#   [u'international', u'economic', u'foreign'],
#   [u'ongoing', u'net', u'small', u'domestic', u'economic'],
#   [u'external', u'domestic', u'financial'],
#   [u'core', u'likely', u'ongoing', u'current', u'anticipated', u'downward'],
#   [u'loose', u'uncertain'],
#   [u'core', u'likely', u'probable'],
#   [u'modest', u'likely'],
#   [u'rapid'],
#   [u'expected', u'aggregate'],
#   [u'core',
#    u'considerable',
#    u'current',
#    u'monetary',
#    u'fiscal',
#    u'economic',
#    u'high',
#    u'current',
#    u'slower'],
#   [u'sizable', u'able', u'higher'],
#   [u'overall', u'limited'],
#   [u'intermeeting', u'unchanged', u'consistent', u'federal'],
#   [u'vigorous', u'economic', u'likely', u'neutral', u'current'],
#   [u'unused', u'substantial', u'low'],
#   [u'accommodative', u'desirable', u'rapid', u'economic'],
#   [u'press', u'earlier', u'accommodative', u'considerable'],
#   [u'low', u'current', u'economic'],
#   [u'desirable', u'near', u'desirable', u'economic'],
#   [u'specific', u'considerable'],
#   [u'new', u'important', u'economic', u'unlikely', u'outsized', u'financial'],
#   [u'sustained', u'financial', u'left', u'little', u'downside', u'economic'],
#   [u'considerable', u'patient'],
#   [u'strong', u'special'],
#   [u'following', u'domestic', u'monetary', u'financial', u'sustainable'],
#   [u'long-run', u'immediate', u'consistent', u'federal'],
#   [u'downside', u'sustainable', u'equal'],
#   [u'unwelcome', u'recent', u'equal'],
#   [u'low', u'patient'],
#   [u'economic'],
#   [u'satisfactory']])

# %%
with open("fomc_parts.json", "rb") as infile:
    fomc_parts = json.load(infile)
fomc_parts
# Out:
# {}

# %% [markdown]
# We can now create two lists, a list of nouns for each sentence, and a flattened list of all the nouns which we will create to produce a dictionary (needed as an argument for the LDA function).

# %%
nvocab = []
for key in fomc_mins.keys():
    nouns = fomc_parts[key][0]
    for nounlist in nouns:
        nvocab.append(nounlist)

flattenednvocab = []
for key in fomc_mins.keys():
    nouns = fomc_parts[key][0]
    for nounlist in nouns:
        for n in nounlist:
            flattenednvocab.append(n)

# %%
from collections import Counter
frequency = Counter(flattenednvocab)

# %%
id2word = {}; vocab = {}
for i,word in enumerate(frequency.keys()):
    vocab[word] = i 
    id2word[i] = word

# %%
len(vocab.keys())
# Out:
# 2759

# %%
from collections import defaultdict
def sentencelist(sentence):
    d = defaultdict(int); group = []
    for word in sentence:
        word_id = vocab[word] 
        d[word_id] += 1 
    group = [(a, d[a]) for a in d.keys()]
    return group
corpus = [sentencelist(sentence) for sentence in nvocab]

# %% [markdown]
# ## Topic Extraction

# %%
import gensim

# %%
lda2 = gensim.models.ldamodel.LdaModel(corpus, num_topics=2, id2word = id2word, update_every=1, chunksize=300)

# %%
lda2.print_topics()
# Out:
# [u'0.043*inflation + 0.037*policy + 0.035*market + 0.035*rate + 0.023*member + 0.022*participant + 0.019*meeting + 0.019*period + 0.018*condition + 0.018*fund',
#  u'0.039*price + 0.022*quarter + 0.021*labor + 0.021*increase + 0.019*growth + 0.019*consumer + 0.019*month + 0.017*business + 0.016*spending + 0.016*activity']

# %% [markdown]
# ## Naive Bayes Approach

# %% [markdown]
# ### First Approach: Training a Naive Bayes Classifier

# %% [markdown]
# We create the vocabulary of adjectives that we will use.

# %%
flattened_adj_vocab = []
for key in fomc_mins.keys():
    nouns = fomc_parts[key][1]
    for nounlist in nouns:
        for n in nounlist:
            flattened_adj_vocab.append(n)

frequency2 = Counter(flattened_adj_vocab)
id2adj = {}; adjvocab = {}
for i,word in enumerate(frequency2.keys()):
    adjvocab[word] = i 
    id2adj[i] = word

# %% [markdown]
# We combine the adjectives in each statement into a single list and thereby have a list of adjectives for each review.

# %%
adjvocab = []
for key in fomc_mins.keys():
    nouns = fomc_parts[key][1]
    for nounlist in nouns:
        adjvocab.append(nounlist)
X = adjvocab

# %% [markdown]
# ### Our Response Array

# %%
with open("actions_05-15.json", "rb") as infile:
    decisions = json.load(infile)
len(decisions.keys())
# Out:
# 52

# %%
decisions_work = decisions.copy()
new_decisions = {}
for key in fomc_mins:
    if key in decisions_work.keys():
        new_decisions[key] = decisions_work[key][-1]
        del decisions_work[key]
        
len(new_decisions)
# Out:
# 47

# %%
"""
George Cell
"""

specialdates = list(set(decisions.keys()).intersection(set(decisions_work.keys())))

# %%
action_dates = [int(d) for d in decisions.keys()]
action_dates.sort(reverse=True)

mint_dates = [int(m) for m in fomc_mins.keys() if int(m) > min(action_dates) - 100]
mint_dates.sort(reverse=True)

acts_mins_dates = {}

action_dates[0]

len(mint_dates)
min(mint_dates)
# Out:
# 20021210

# %%
while mint_dates:
    mdate = mint_dates[-1]
    
    if not action_dates:
        break;
    
    adate = action_dates[-1]
    if mdate <= adate:
        mtuple = (mdate, fomc_mins[str(mdate)])
        try:
            acts_mins_dates[adate].append(mtuple)
        except KeyError, e:
            acts_mins_dates[adate] = [mtuple]
        if mdate == adate:
            action_dates.pop()
        mint_dates.pop()
    else:
        action_dates.pop()

# %%
x = 0
for k in acts_mins_dates.keys():
    #print k, len(acts_mins_dates[k])
    x += len(acts_mins_dates[k])
x
# Out:
# 68

# %%
len(fomc_mins.keys())
len('http://www.federalreserve.gov/newsevents/press/monetary/20081008a.htm')
# Out:
# 69

# %%
import requests
import time
from requests.exceptions import ConnectionError

specialurls = ['http://www.federalreserve.gov/boarddocs/press/monetary/2003/20030106/default.htm',
 'http://www.federalreserve.gov/newsevents/press/monetary/20070817a.htm',
 'http://www.federalreserve.gov/newsevents/press/monetary/20080122b.htm',
 'http://www.federalreserve.gov/newsevents/press/monetary/20080316a.htm',
 'http://www.federalreserve.gov/newsevents/press/monetary/20081008b.htm',
 'http://www.federalreserve.gov/newsevents/press/monetary/20081008a.htm']


for url in specialurls:
    try:
        page = requests.get(url)
        if len(url) > 69:
            date = url[-20:-12]
        else:
            date = url[-13:-5]
        print date
        fomc_mins[date] = page.text
    except ConnectionError as e:
        print "Error ==> ", e, "for", date
    time.sleep(1)
# Out:
# 20030106
# 20070817
# 20080122
# 20080316
# 20081008
# 20081008

# %%
with open("fomc_mins_all.json", "wb") as outfile:
    json.dump(fomc_mins, outfile)
    outfile.close()

# %% [markdown]
# We have 182 statements and 52 decisions. Of the 52 decisions, 47 are found in the 182 statements, 5 are not.
#
# TODO:
# - Assign the 5 that are not to the fomc statement immediately preceding them
# - Work out how we will deal with the mismatch in dimensions -> 182 x 52. Will we collapse  the 182 into groups? But that would reduce the data points available to us given that they are already few. Maybe find more points for the 130 points that remain?

# %%
from sklearn.cross_validation import train_test_split
itrain, itest = train_test_split(xrange(len(X)), train_size=0.7)
mask=np.ones(len(X), dtype='int')
mask[itrain]=1
mask[itest]=0
mask = (mask==1)

# %%
def make_xy(X_col, y_col, vectorizer):
    X = vectorizer.fit_transform(X_col)
    y = y_col
    return X, y

# %%
"""
Function
--------
log_likelihood

Compute the log likelihood of a dataset according to 
a Naive Bayes classifier. 
The Log Likelihood is defined by

L = Sum_positive(logP(positive)) + Sum_negative(logP(negative))

Where Sum_positive indicates a sum over all positive reviews, 
and Sum_negative indicates a sum over negative reviews
    
Parameters
----------
clf : Naive Bayes classifier
x : (nexample, nfeature) array
    The input data
y : (nexample) integer array
    Whether each review is Fresh
"""
def log_likelihood(clf, x, y):
    prob = clf.predict_log_proba(x)
    rotten = y == 0
    fresh = ~rotten
    return prob[rotten,0].sum() + prob[fresh,1].sum()

# %%
from sklearn.cross_validation import KFold

def cv_score(clf, x, y, score_func, nfold=5):
    """
    Uses 5-fold cross validation to estimate a score of a classifier
    
    Inputs
    ------
    clf : Classifier object
    x : Input feature vector
    y : Input class labels
    score_func : Function like log_likelihood, that takes (clf, x, y) as input,
                 and returns a score
                 
    Returns
    -------
    The average score obtained by splitting (x, y) into 5 folds of training and 
    test sets, fitting on the training set, and evaluating score_func on the test set
    
    Examples
    cv_score(clf, x, y, log_likelihood)
    """
    result = 0
    for train, test in KFold(y.size, nfold): # split data into train/test groups, 5 times
        clf.fit(x[train], y[train]) # fit
        result += score_func(clf, x[test], y[test]) # evaluate score function on held-out data
    return result / nfold # average

# %%
def calibration_plot(clf, xtest, ytest):
    prob = clf.predict_proba(xtest)[:, 1]
    outcome = ytest
    data = pd.DataFrame(dict(prob=prob, outcome=outcome))

    #group outcomes into bins of similar probability
    bins = np.linspace(0, 1, 20)
    cuts = pd.cut(prob, bins)
    binwidth = bins[1] - bins[0]
    
    #freshness ratio and number of examples in each bin
    cal = data.groupby(cuts).outcome.agg(['mean', 'count'])
    cal['pmid'] = (bins[:-1] + bins[1:]) / 2
    cal['sig'] = np.sqrt(cal.pmid * (1 - cal.pmid) / cal['count'])
        
    #the calibration plot
    ax = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
    p = plt.errorbar(cal.pmid, cal['mean'], cal['sig'])
    plt.plot(cal.pmid, cal.pmid, linestyle='--', lw=1, color='k')
    plt.ylabel("Empirical P(+)")
    
    #the distribution of P(+)
    ax = plt.subplot2grid((3, 1), (2, 0), sharex=ax)
    
    plt.bar(left=cal.pmid - binwidth / 2, height=cal['count'],
            width=.95 * (bins[1] - bins[0]),
            fc=p[0].get_color())
    
    plt.xlabel("Predicted P(+)")
    plt.ylabel("Number")

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
print "alpha: %f" % best_alpha
print "min_df: %f" % best_min_df

# %%
vectorizer = CountVectorizer(vocabulary=adjvocab, min_df=best_min_df)
Xnew, ynew = make_xy(X, y, vectorizer)
xtrain=Xnew[mask]
ytrain=ynew[mask]
xtest=Xnew[~mask]
ytest=ynew[~mask]

clf = MultinomialNB(alpha=best_alpha).fit(xtrain, ytrain)

training_accuracy = clf.score(xtrain, ytrain)
test_accuracy = clf.score(xtest, ytest)

print "Accuracy on training data: %0.4f" % (training_accuracy)
print "Accuracy on test data:     %0.4f" % (test_accuracy)

calibration_plot(clf, xtest, np.ravel(ytest))

# %% [markdown]
# ### Second Approach: Using the Loughran-McDonald Financial Dictionary

# %% [markdown]
# Our first approach assigned probabilities to words based on the training set of FOMC statements we have. However, the success of this is limited by the number of FOMC statements (182) that we have access to. We can improve this analysis by using more accurate probabilities given by a dictionary that focuses on finance. The **Loughran-McDonald 2014 Master Dictionary** is a great tool for our purposes as it includes words that often appear in 10-K documents and other financial statements. The dictionary includes 9 sentiment categories, including "negative", "positive", "uncertainty", "litigious", "modal", and "constraining", among others. The probabilities given by this dictionary are more useful to us because of the sheer size of the data set used to calculate the probabilities.

# %% [markdown]
# We read in the dictionary. Below is an example of the data encapsulated in $lmdf$.

# %%
lmdf = pd.read_csv("shortMcDonaldDictionary.csv")
lmdf.head()
# Out:
#           Word  Sequence Number  Word Count  Word Proportion  \
# 0     ENCUMBER            24454       87222     6.130000e-06
# 1   ENCUMBERED            24455       86996     6.110000e-06
# 2  ENCUMBERING            24456       51445     3.610000e-06
# 3    ENCUMBERS            24457        4835     3.400000e-07
# 4  ENCUMBRANCE            24458      223181     1.570000e-05
#
#    Average Proportion   Std Dev  Doc Count  Negative  Positive  Uncertainty  \
# 0        2.570000e-06  0.000017      44863      2009         0            0
# 1        3.480000e-06  0.000028      44409      2009         0            0
# 2        3.660000e-06  0.000050      19907      2009         0            0
# 3        1.380000e-07  0.000004       3258      2009         0            0
# 4        6.260000e-06  0.000036      72129      2009         0            0
#
#    Litigious  Constraining  Superfluous  Interesting  Modal  Irr_Verb  \
# 0       2009          2009            0            0      0         0
# 1       2009          2009            0            0      0         0
# 2       2009          2009            0            0      0         0
# 3       2009          2009            0            0      0         0
# 4       2009          2009            0            0      0         0
#
#    Harvard_IV  Syllables     Source
# 0           0          3  12of12inf
# 1           0          3  12of12inf
# 2           0          4  12of12inf
# 3           0          3  12of12inf
# 4           0          3  12of12inf

# %%
lmdf = lmdf[["Word","Negative","Positive","Uncertainty","Litigious","Constraining"]]

# %%
lmdf.head()
# Out:
#           Word  Negative  Positive  Uncertainty  Litigious  Constraining
# 0     ENCUMBER      2009         0            0       2009          2009
# 1   ENCUMBERED      2009         0            0       2009          2009
# 2  ENCUMBERING      2009         0            0       2009          2009
# 3    ENCUMBERS      2009         0            0       2009          2009
# 4  ENCUMBRANCE      2009         0            0       2009          2009

# %% [markdown]
# The dictionary includes 9 sentiment categories (e.g. "negative", "positive", "uncertainty", "litigious", "modal", and "constraining"). We reduce the dimensionality of this data down to just three categories: "negative", "positive", and "uncertain". A $word$ that is "uncertain" is assigned the probabilities $$P(word_u\,|\,-)=P(word_u\,|\,+)=\frac{1}{2}$$.
# We set words in the "positive" and "negative" parts to have 90% probabilities of being in the group they are assigned to (based on the average probability given by Loughran and McDonald).
# $$P(word_p\,|\,+) = 0.9, P(word_p\,|\,-) = 0.1$$
# $$P(word_n\,|\,-) = 0.1, P(word_n\,|\,-) = 0.9$$

# %% [markdown]
# We adjust $lmdf$ to reflect these decisions.

# %%
lmdf_adjusted = lmdf.copy(deep=True)
N = 0; P = 0
new_values = [0 for i in range(len(lmdf_adjusted.values))]
for i, r in enumerate(lmdf_adjusted.values):
    if r[1] > 0 or r[4] > 0 or r[5] > 0:
        N = 0.9; P = 0.1
    elif r[2] > 0:
        N = 0.1; P = 0.9
    elif r[3] > 0:
        N = 0.5; P = 0.5
    new_values[i] = [r[0], P, N]

final_lmdf = pd.DataFrame(new_values, index=lmdf_adjusted.index, columns = ["Word", "Positive Prob", "Negative Prob"])
final_lmdf.head()
# Out:
#           Word  Positive Prob  Negative Prob
# 0     ENCUMBER            0.1            0.9
# 1   ENCUMBERED            0.1            0.9
# 2  ENCUMBERING            0.1            0.9
# 3    ENCUMBERS            0.1            0.9
# 4  ENCUMBRANCE            0.1            0.9

# %% [markdown]
# We define a function to calculate the probability of a sentence being positive.

# %%
dict_probs = {}
for row in final_lmdf.values:
    dict_probs[row[0]] = [row[1], row[2]]

# %%
"""
We modify calc_pplus to incorporate our new found knowledge. We now check if a word is in the financial dictionary first.
If it is then we use that probabilty, otherwise we use the probability from our earlier Naive Bayes classifier.

We also multiply the probabilities from the financial dictionary by a factor to emphasize their importance (based on the
fact that we are more confident in their values).
"""

def modified_calc_pplus(adjlist, dict_probs, lp, ln, pp, pn):
    FACTOR = 1
    
    prob_p = 0; prob_n = 0
    for adj in adjlist:
        # Check if the adjective is in the financial dictionary
        # If it is take, probability from there
        if adj in dict_probs.keys():
            prob_p += FACTOR * dict_probs[adj][0]
            prob_n += FACTOR * dict_probs[adj][1]
        else:    
            prob_p += lp[adj]
            prob_n += ln[adj]
    prob_pos = prob_p * pp
    prob_neg = prob_n * pn
    prob = float(prob_pos)/(prob_pos + prob_neg)
    return prob
