# %% [markdown]
# # Sentiment Analysis

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json

# %% [markdown]
# ### Natural Language Processing
#
# We begin by parsing the text and pre-processing it to prepare it for Latent Dirichlet Analysis. This step is meant to remove stopwords and identify nouns and adjectives.

# %%
from pattern.en import parse
from pattern.en import pprint
from pattern.vector import stem, PORTER, LEMMA
punctuation = list('.,;:!?()[]{}`''\"@#$^&*+-|=~_')

# %%
from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS

# %% [markdown]
# The FOMC statements are full of phrases like "growth is expected to continue--given the current data--at a moderate pace". The two hyphens should be treated as a space.

# %%
import re
regex1=re.compile(r"\-{2,}")

# %% [markdown]
# We now define a function to find the nouns and adjectives of the text. The function returns a tuple where the first element is a list of lists, where each list includes the nouns from a sentence. The second element is a list of lists, where each list includes the adjectives from a sentence.

# %%
def modified_get_parts(thetext):
    thetext=re.sub(regex1, ', ', thetext)
    nouns=[]
    descriptives=[]
    for i,sentence in enumerate(parse(thetext, tokenize=True, lemmata=True).split()):
        
        # Skip the first three sentences that include the HTML
        nouns.append([])
        descriptives.append([])
#         if i in range(1,4):
#             continue
            
        for token in sentence:
            #print token
            if len(token[4]) >0:
                if token[1] in ['JJ', 'JJR', 'JJS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
            
                    descriptives[i].append(token[4])
                elif token[1] in ['NN', 'NNS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    nouns[i].append(token[4])
    out=zip(nouns, descriptives)
    nouns2=[]
    descriptives2=[]
    for n,d in out:
        if len(n)!=0 and len(d)!=0:
            nouns2.append(n)
            descriptives2.append(d)
    return nouns2[1:], descriptives2[1:]

# %% [markdown]
# We load in the fomc_mins_all dictionary that we created in the Scraping.ipynb iPython Notebook.

# %%
with open("fomc_mins_all.json", "rb") as infile:
    fomc_mins = json.load(infile)

# %% [markdown]
# We can now check how our modified_get_parts function would deal with a sample FOMC statement.

# %%
modified_get_parts(pq(fomc_mins['20140730']).text())
# Out:
# ([[u'buildmenu',
#    u'policy',
#    u'minute',
#    u'meeting',
#    u'office',
#    u'governor',
#    u'present',
#    u'member',
#    u'president',
#    u'economist',
#    u'dev'],
#   [u'governor',
#    u'governor',
#    u'adviser',
#    u'governor',
#    u'governor',
#    u'governor',
#    u'merten',
#    u'interval',
#    u'meeting',
#    u'subcommittee',
#    u'communication',
#    u'issue'],
#   [u'subcommittee',
#    u'work',
#    u'subcommittee',
#    u'frame',
#    u'discussion',
#    u'range',
#    u'communication',
#    u'issue'],
#   [u'development',
#    u'session',
#    u'governor',
#    u'manager',
#    u'development',
#    u'market'],
#   [u'manager',
#    u'market',
#    u'operation',
#    u'period',
#    u'outcome',
#    u'test',
#    u'operation',
#    u'result',
#    u'agreement',
#    u'exercise',
#    u'effect',
#    u'bank',
#    u'policy',
#    u'action',
#    u'yield',
#    u'portion',
#    u'portfolio'],
#   [u'addition',
#    u'manager',
#    u'plan',
#    u'pilot',
#    u'program',
#    u'number',
#    u'counterparty',
#    u'agency',
#    u'security',
#    u'operation',
#    u'firm',
#    u'dealer'],
#   [u'vote', u'transaction', u'period'],
#   [u'intervention', u'operation', u'currency', u'account', u'period'],
#   [u'participant',
#    u'discussion',
#    u'issue',
#    u'normalization',
#    u'stance',
#    u'policy',
#    u'intention',
#    u'information',
#    u'public',
#    u'year',
#    u'participant',
#    u'step',
#    u'policy',
#    u'accommodation'],
#   [u'staff', u'approach', u'policy', u'stance', u'policy'],
#   [u'approach',
#    u'discussion',
#    u'normalization',
#    u'strategy',
#    u'policy',
#    u'tool',
#    u'meeting'],
#   [u'participant',
#    u'general',
#    u'support',
#    u'normalization',
#    u'approach',
#    u'staff',
#    u'reservation',
#    u'feature'],
#   [u'participant',
#    u'fund',
#    u'rate',
#    u'policy',
#    u'rate',
#    u'range',
#    u'basis',
#    u'point',
#    u'rate',
#    u'time',
#    u'liftoff',
#    u'time'],
#   [u'participant',
#    u'range',
#    u'fund',
#    u'rate',
#    u'communication',
#    u'tool',
#    u'target',
#    u'policy',
#    u'communication',
#    u'normalization',
#    u'period',
#    u'rate',
#    u'reserve',
#    u'rate',
#    u'addition',
#    u'fund',
#    u'rate'],
#   [u'participant',
#    u'adjustment',
#    u'rate',
#    u'tool',
#    u'fund',
#    u'rate',
#    u'target',
#    u'range',
#    u'influence',
#    u'money',
#    u'market',
#    u'rate'],
#   [u'addition',
#    u'use',
#    u'facility',
#    u'floor',
#    u'money',
#    u'market',
#    u'rate',
#    u'normalization'],
#   [u'participant',
#    u'rate',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'rate',
#    u'fund',
#    u'target',
#    u'range'],
#   [u'participant',
#    u'rate',
#    u'fund',
#    u'target',
#    u'range',
#    u'normalization',
#    u'process',
#    u'reliance',
#    u'facility',
#    u'role'],
#   [u'participant',
#    u'strategy',
#    u'control',
#    u'money',
#    u'market',
#    u'rate',
#    u'liftoff',
#    u'confusion',
#    u'path',
#    u'policy',
#    u'question',
#    u'ability',
#    u'policy'],
#   [u'participant', u'facility', u'policy', u'implementation', u'purpose'],
#   [u'participant',
#    u'desire',
#    u'feature',
#    u'facility',
#    u'design',
#    u'role',
#    u'intermediation',
#    u'risk',
#    u'facility',
#    u'strain',
#    u'market',
#    u'period',
#    u'stress'],
#   [u'option', u'concern', u'method', u'program', u'size'],
#   [u'participant',
#    u'testing',
#    u'information',
#    u'feature',
#    u'temper',
#    u'risk',
#    u'facility'],
#   [u'participant', u'approach', u'size', u'composition', u'balance', u'sheet'],
#   [u'size', u'balance', u'sheet'],
#   [u'addition',
#    u'balance',
#    u'sheet',
#    u'level',
#    u'implementation',
#    u'policy',
#    u'security',
#    u'order',
#    u'effect',
#    u'portfolio',
#    u'allocation',
#    u'credit',
#    u'sector',
#    u'economy'],
#   [u'participant',
#    u'size',
#    u'balance',
#    u'sheet',
#    u'decision',
#    u'framework',
#    u'policy'],
#   [u'participant',
#    u'investment',
#    u'increase',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate'],
#   [u'reinvestment',
#    u'liftoff',
#    u'approach',
#    u'reduction',
#    u'size',
#    u'portfolio'],
#   [u'participant', u'holding'],
#   [u'couple',
#    u'participant',
#    u'order',
#    u'effect',
#    u'holding',
#    u'mortgage',
#    u'rate',
#    u'rate',
#    u'result',
#    u'repayment',
#    u'principal'],
#   [u'uncertainty',
#    u'normalization',
#    u'process',
#    u'outlook',
#    u'economy',
#    u'market',
#    u'option',
#    u'asset'],
#   [u'participant',
#    u'information',
#    u'public',
#    u'normalization',
#    u'participant',
#    u'step',
#    u'policy',
#    u'accommodation'],
#   [u'importance',
#    u'plan',
#    u'time',
#    u'importance',
#    u'flexibility',
#    u'adjustment',
#    u'normalization',
#    u'approach',
#    u'situation',
#    u'light',
#    u'experience'],
#   [u'participant',
#    u'analysis',
#    u'staff',
#    u'issue',
#    u'normalization',
#    u'background',
#    u'discussion',
#    u'meeting'],
#   [u'participant',
#    u'information',
#    u'public',
#    u'effect',
#    u'facility',
#    u'feedback',
#    u'response',
#    u'communication',
#    u'normalization'],
#   [u'information',
#    u'meeting',
#    u'product',
#    u'quarter',
#    u'decline',
#    u'pace',
#    u'balance',
#    u'half',
#    u'year'],
#   [u'price',
#    u'inflation',
#    u'quarter',
#    u'future',
#    u'price',
#    u'energy',
#    u'commodity',
#    u'couple',
#    u'year',
#    u'measure',
#    u'inflation',
#    u'expectation',
#    u'stable'],
#   [u'advance', u'estimate', u'data', u'period', u'day', u'meeting'],
#   [u'staff',
#    u'assessment',
#    u'activity',
#    u'inflation',
#    u'half',
#    u'information',
#    u'meeting',
#    u'information'],
#   [u'measure', u'labor', u'market', u'condition', u'period'],
#   [u'payroll', u'employment', u'gain', u'quarter', u'quarter'],
#   [u'unemployment',
#    u'rate',
#    u'percent',
#    u'labor',
#    u'force',
#    u'participation',
#    u'rate',
#    u'ratio'],
#   [u'rate',
#    u'unemployment',
#    u'share',
#    u'worker',
#    u'time',
#    u'reason',
#    u'measure',
#    u'standard'],
#   [u'claim', u'unemployment', u'insurance', u'week'],
#   [u'rate', u'job', u'opening', u'rate', u'hiring', u'level'],
#   [u'production',
#    u'quarter',
#    u'output',
#    u'manufacturer',
#    u'decline',
#    u'output',
#    u'gas',
#    u'utility'],
#   [u'capacity', u'utilization', u'quarter'],
#   [u'automaker',
#    u'production',
#    u'schedule',
#    u'motor',
#    u'vehicle',
#    u'assembly',
#    u'quarter',
#    u'reading',
#    u'order',
#    u'manufacturing',
#    u'survey',
#    u'gain',
#    u'factory',
#    u'output',
#    u'term'],
#   [u'consumption',
#    u'expenditure',
#    u'quarter',
#    u'purchase',
#    u'motor',
#    u'vehicle'],
#   [u'factor', u'household', u'spending', u'month'],
#   [u'gain',
#    u'equity',
#    u'value',
#    u'home',
#    u'price',
#    u'household',
#    u'net',
#    u'income',
#    u'quarter'],
#   [u'sentiment', u'survey', u'consumer', u'average', u'half', u'year'],
#   [u'expenditure', u'investment', u'quarter', u'quarters'],
#   [u'single-family',
#    u'house',
#    u'quarter',
#    u'level',
#    u'permit',
#    u'issuance',
#    u'increase',
#    u'start',
#    u'month'],
#   [u'sector', u'permit', u'net', u'quarter'],
#   [u'existing', u'home', u'sale', u'quarter', u'level', u'home', u'sale'],
#   [u'home', u'price', u'rate', u'increase', u'year'],
#   [u'expenditure',
#    u'business',
#    u'equipment',
#    u'property',
#    u'product',
#    u'quarter'],
#   [u'order',
#    u'capital',
#    u'good',
#    u'net',
#    u'level',
#    u'order',
#    u'shipment',
#    u'increase',
#    u'shipment',
#    u'month'],
#   [u'indicator',
#    u'survey',
#    u'business',
#    u'condition',
#    u'increase',
#    u'business',
#    u'equipment',
#    u'spending',
#    u'term'],
#   [u'business', u'expenditure', u'construction', u'quarter'],
#   [u'business',
#    u'inventory',
#    u'sale',
#    u'energy',
#    u'sector',
#    u'inventory',
#    u'level'],
#   [u'government',
#    u'purchase',
#    u'half',
#    u'year',
#    u'consolidation',
#    u'decline',
#    u'defense',
#    u'spending'],
#   [u'contrast',
#    u'state',
#    u'government',
#    u'purchase',
#    u'quarter',
#    u'payroll',
#    u'pace',
#    u'quarter',
#    u'outlay',
#    u'construction'],
#   [u'trade', u'deficit', u'import', u'export'],
#   [u'rise', u'export', u'petroleum', u'product'],
#   [u'quarter',
#    u'net',
#    u'export',
#    u'drag',
#    u'change',
#    u'contribution',
#    u'quarter'],
#   [u'consumer',
#    u'price',
#    u'price',
#    u'index',
#    u'pace',
#    u'quarter',
#    u'percent',
#    u'year'],
#   [u'energy',
#    u'price',
#    u'inflation',
#    u'quarter',
#    u'gasoline',
#    u'price',
#    u'basis',
#    u'week'],
#   [u'food',
#    u'price',
#    u'inflation',
#    u'quarter',
#    u'effect',
#    u'drought',
#    u'disease',
#    u'crop',
#    u'livestock',
#    u'production',
#    u'spot',
#    u'price',
#    u'crop',
#    u'week',
#    u'future',
#    u'price',
#    u'price',
#    u'livestock',
#    u'year'],
#   [u'price',
#    u'index',
#    u'item',
#    u'food',
#    u'energy',
#    u'quarter',
#    u'percent',
#    u'year'],
#   [u'inflation', u'expectation', u'survey', u'net', u'expectation'],
#   [u'measure',
#    u'labor',
#    u'compensation',
#    u'gain',
#    u'wage',
#    u'employee',
#    u'benefit'],
#   [u'indicator', u'activity', u'quarter', u'datum', u'pickup'],
#   [u'growth', u'data', u'area', u'improvement', u'quarter'],
#   [u'economy',
#    u'inflation',
#    u'quarter',
#    u'rate',
#    u'inflation',
#    u'area',
#    u'objective'],
#   [u'condition',
#    u'balance',
#    u'meeting',
#    u'risk',
#    u'investor',
#    u'sentiment',
#    u'time'],
#   [u'net',
#    u'yield',
#    u'security',
#    u'equity',
#    u'price',
#    u'exchange',
#    u'value',
#    u'dollar'],
#   [u'market',
#    u'participant',
#    u'policy',
#    u'communication',
#    u'period',
#    u'policy',
#    u'stance'],
#   [u'path', u'fund', u'rate', u'statement', u'press', u'conference'],
#   [u'market',
#    u'participant',
#    u'note',
#    u'discussion',
#    u'policy',
#    u'normalization',
#    u'minute',
#    u'discussion',
#    u'spread',
#    u'rate',
#    u'rate'],
#   [u'result',
#    u'meeting',
#    u'market',
#    u'participant',
#    u'expectation',
#    u'timing',
#    u'increase',
#    u'fund',
#    u'rate',
#    u'policy',
#    u'path',
#    u'survey',
#    u'meeting'],
#   [u'dealer',
#    u'quarter',
#    u'time',
#    u'liftoff',
#    u'fund',
#    u'rate',
#    u'survey',
#    u'distribution',
#    u'time',
#    u'liftoff',
#    u'quarter'],
#   [u'balance', u'yield', u'basis', u'point', u'period'],
#   [u'concern', u'tension', u'release', u'minute', u'decline', u'yield'],
#   [u'decline',
#    u'yield',
#    u'end',
#    u'curve',
#    u'continuation',
#    u'pattern',
#    u'year',
#    u'market',
#    u'participant',
#    u'reduction',
#    u'investor',
#    u'expectation',
#    u'growth',
#    u'term',
#    u'premium'],
#   [u'measure', u'inflation', u'compensation'],
#   [u'condition', u'dollar', u'market', u'stable', u'period'],
#   [u'result',
#    u'market',
#    u'rate',
#    u'repurchase',
#    u'agreement',
#    u'period',
#    u'participation',
#    u'exercise',
#    u'high',
#    u'quarter-end'],
#   [u'testing', u'increase', u'offer', u'rate', u'award', u'participation'],
#   [u'index',
#    u'percent',
#    u'period',
#    u'earning',
#    u'report',
#    u'range',
#    u'company',
#    u'profit',
#    u'quarter',
#    u'quarter'],
#   [u'index', u'volatility', u'return', u'index', u'level', u'period'],
#   [u'corporation', u'quarter'],
#   [u'issuance', u'investment', u'bond'],
#   [u'loan',
#    u'bank',
#    u'balance',
#    u'sheet',
#    u'pace',
#    u'report',
#    u'lending',
#    u'practice',
#    u'lending',
#    u'standard',
#    u'term',
#    u'loan',
#    u'demand',
#    u'firm',
#    u'size'],
#   [u'issuance', u'loan', u'investor'],
#   [u'condition', u'market', u'estate', u'quarter'],
#   [u'bank', u'standard', u'demand', u'loan', u'quarter', u'balance'],
#   [u'loan', u'bank', u'book', u'issuance', u'security'],
#   [u'condition', u'mortgage', u'market', u'period'],
#   [u'rate', u'percent', u'origination', u'volume'],
#   [u'underwriting',
#    u'standard',
#    u'home-purchase',
#    u'loan',
#    u'bank',
#    u'quarter',
#    u'net',
#    u'standard',
#    u'type',
#    u'estate',
#    u'loan',
#    u'midpoint',
#    u'respondent',
#    u'bank',
#    u'longer-term'],
#   [u'bank', u'demand', u'auto', u'loan', u'quarter'],
#   [u'addition',
#    u'demand',
#    u'credit',
#    u'card',
#    u'loan',
#    u'bank',
#    u'policy',
#    u'loan'],
#   [u'yield',
#    u'bond',
#    u'economy',
#    u'trend',
#    u'start',
#    u'year',
#    u'tension',
#    u'period',
#    u'pressure'],
#   [u'concern',
#    u'bank',
#    u'litigation',
#    u'risk',
#    u'bank',
#    u'market',
#    u'yield',
#    u'spread',
#    u'bond',
#    u'area',
#    u'equity',
#    u'price',
#    u'index',
#    u'bank'],
#   [u'intermeeting',
#    u'data',
#    u'production',
#    u'market',
#    u'expectation',
#    u'headline',
#    u'equity',
#    u'market',
#    u'region'],
#   [u'news',
#    u'market',
#    u'economy',
#    u'growth',
#    u'concern',
#    u'debt',
#    u'payment',
#    u'market',
#    u'effect'],
#   [u'change',
#    u'market',
#    u'equity',
#    u'index',
#    u'period',
#    u'market',
#    u'bond',
#    u'yield'],
#   [u'dollar', u'net', u'period'],
#   [u'staff',
#    u'report',
#    u'risk',
#    u'stability',
#    u'capital',
#    u'position',
#    u'bank',
#    u'use',
#    u'maturity',
#    u'transformation',
#    u'leverage',
#    u'sector',
#    u'level',
#    u'leverage',
#    u'sector',
#    u'factor',
#    u'stability'],
#   [u'staff',
#    u'report',
#    u'risk',
#    u'premium',
#    u'level',
#    u'market',
#    u'volatility',
#    u'loosening',
#    u'underwriting',
#    u'standard',
#    u'number',
#    u'market',
#    u'risk',
#    u'correction',
#    u'asset',
#    u'valuation'],
#   [u'outlook',
#    u'datum',
#    u'staff',
#    u'forecast',
#    u'meeting',
#    u'growth',
#    u'half',
#    u'year'],
#   [u'staff',
#    u'forecast',
#    u'growth',
#    u'half',
#    u'year',
#    u'indicator',
#    u'activity',
#    u'relation',
#    u'half',
#    u'year'],
#   [u'payroll',
#    u'employment',
#    u'pace',
#    u'unemployment',
#    u'rate',
#    u'production',
#    u'gain',
#    u'reading',
#    u'business',
#    u'survey'],
#   [u'staff', u'forecast', u'growth'],
#   [u'staff', u'project', u'pace', u'half', u'year', u'year'],
#   [u'forecast',
#    u'restraint',
#    u'spending',
#    u'growth',
#    u'change',
#    u'policy',
#    u'improvement',
#    u'credit',
#    u'availability',
#    u'increase',
#    u'consumer',
#    u'business',
#    u'confidence',
#    u'pickup',
#    u'growth'],
#   [u'response',
#    u'surprise',
#    u'unemployment',
#    u'rate',
#    u'staff',
#    u'forecast',
#    u'unemployment',
#    u'rate',
#    u'projection',
#    u'period'],
#   [u'revision',
#    u'growth',
#    u'half',
#    u'year',
#    u'unemployment',
#    u'rate',
#    u'staff',
#    u'estimate',
#    u'rate',
#    u'staff',
#    u'pace',
#    u'output',
#    u'growth',
#    u'year',
#    u'growth'],
#   [u'result',
#    u'resource',
#    u'slack',
#    u'projection',
#    u'year',
#    u'forecast',
#    u'projection',
#    u'period'],
#   [u'staff', u'forecast', u'inflation', u'data', u'increase'],
#   [u'resource', u'slack', u'projection', u'forecast', u'inflation'],
#   [u'projection',
#    u'inflation',
#    u'half',
#    u'year',
#    u'objective',
#    u'percent',
#    u'year'],
#   [u'inflation',
#    u'expectation',
#    u'change',
#    u'commodity',
#    u'import',
#    u'price',
#    u'slack',
#    u'labor',
#    u'product',
#    u'market',
#    u'inflation',
#    u'objective'],
#   [u'staff',
#    u'uncertainty',
#    u'projection',
#    u'growth',
#    u'inflation',
#    u'unemployment',
#    u'rate',
#    u'line',
#    u'average',
#    u'year'],
#   [u'risk',
#    u'growth',
#    u'downside',
#    u'policy',
#    u'policy',
#    u'economy',
#    u'shock',
#    u'risk',
#    u'projection'],
#   [u'participant',
#    u'view',
#    u'condition',
#    u'outlook',
#    u'discussion',
#    u'situation',
#    u'outlook',
#    u'meeting',
#    u'participant',
#    u'rebound',
#    u'quarter',
#    u'improvement',
#    u'labor',
#    u'market',
#    u'condition',
#    u'expectation',
#    u'expansion',
#    u'labor',
#    u'market',
#    u'indicator',
#    u'inflation',
#    u'level',
#    u'judge',
#    u'mandate'],
#   [u'participant',
#    u'risk',
#    u'outlook',
#    u'activity',
#    u'labor',
#    u'market',
#    u'source',
#    u'risk',
#    u'weakness',
#    u'housing',
#    u'sector',
#    u'rise',
#    u'household',
#    u'income',
#    u'spillover',
#    u'development'],
#   [u'participant',
#    u'inflation',
#    u'percent',
#    u'objective',
#    u'risk',
#    u'inflation',
#    u'objective'],
#   [u'spending', u'growth', u'half', u'year', u'half'],
#   [u'contact',
#    u'district',
#    u'pickup',
#    u'consumer',
#    u'spending',
#    u'weakness',
#    u'quarter'],
#   [u'participant',
#    u'concern',
#    u'household',
#    u'saving',
#    u'rate',
#    u'rise',
#    u'wage',
#    u'income',
#    u'consumer',
#    u'spending'],
#   [u'mortgage',
#    u'rate',
#    u'housing',
#    u'factor',
#    u'demand',
#    u'income',
#    u'level',
#    u'student',
#    u'debt',
#    u'difficulty',
#    u'mortgage',
#    u'credit',
#    u'homebuyer'],
#   [u'weakness',
#    u'homebuilding',
#    u'rise',
#    u'house',
#    u'price',
#    u'supply',
#    u'constraint',
#    u'construction',
#    u'activity'],
#   [u'demand',
#    u'rental',
#    u'investor',
#    u'home',
#    u'market',
#    u'support',
#    u'construction'],
#   [u'participant',
#    u'concern',
#    u'number',
#    u'factor',
#    u'construction',
#    u'housing',
#    u'recovery',
#    u'time'],
#   [u'participant',
#    u'improvement',
#    u'sentiment',
#    u'business',
#    u'contact',
#    u'reading',
#    u'survey',
#    u'manufacturing',
#    u'activity'],
#   [u'participant',
#    u'strength',
#    u'airline',
#    u'railroad',
#    u'trucking',
#    u'firm',
#    u'business',
#    u'motor',
#    u'vehicle',
#    u'industry',
#    u'sector'],
#   [u'addition',
#    u'energy',
#    u'price',
#    u'support',
#    u'activity',
#    u'energy',
#    u'sector'],
#   [u'agriculture',
#    u'sector',
#    u'condition',
#    u'crop',
#    u'price',
#    u'profitability',
#    u'livestock',
#    u'producer'],
#   [u'report',
#    u'business',
#    u'contact',
#    u'support',
#    u'participant',
#    u'expectation',
#    u'growth',
#    u'half',
#    u'year'],
#   [u'case',
#    u'information',
#    u'business',
#    u'increase',
#    u'spending',
#    u'capital',
#    u'equipment',
#    u'pickup',
#    u'investment',
#    u'construction',
#    u'transportation'],
#   [u'number',
#    u'area',
#    u'credit',
#    u'report',
#    u'participant',
#    u'business',
#    u'contact',
#    u'strengthening',
#    u'demand',
#    u'bank',
#    u'credit'],
#   [u'participant',
#    u'business',
#    u'outlook',
#    u'capital',
#    u'spending',
#    u'hiring'],
#   [u'restraint', u'business', u'activity', u'area', u'spending'],
#   [u'labor',
#    u'market',
#    u'condition',
#    u'month',
#    u'participant',
#    u'report',
#    u'development',
#    u'district',
#    u'range',
#    u'indicator'],
#   [u'improvement',
#    u'pickup',
#    u'payroll',
#    u'employment',
#    u'gain',
#    u'decline',
#    u'unemployment',
#    u'rate',
#    u'reduction',
#    u'measure',
#    u'underutilization',
#    u'duration',
#    u'joblessness',
#    u'number',
#    u'worker',
#    u'job',
#    u'employment'],
#   [u'labor',
#    u'force',
#    u'participation',
#    u'rate',
#    u'couple',
#    u'participant',
#    u'transition',
#    u'rate',
#    u'unemployment',
#    u'employment'],
#   [u'participant',
#    u'sign',
#    u'hiring',
#    u'turnover',
#    u'labor',
#    u'market',
#    u'increase',
#    u'job',
#    u'opening',
#    u'plan',
#    u'quit',
#    u'rate',
#    u'improvement',
#    u'worker',
#    u'job'],
#   [u'participant',
#    u'improvement',
#    u'labor',
#    u'market',
#    u'condition',
#    u'progress',
#    u'year',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'unemployment',
#    u'rate',
#    u'summary',
#    u'statistic',
#    u'state',
#    u'labor',
#    u'market',
#    u'thought',
#    u'focus',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'participant',
#    u'gap',
#    u'labor',
#    u'market',
#    u'condition',
#    u'assessment',
#    u'level',
#    u'labor',
#    u'utilization',
#    u'difference',
#    u'unemployment',
#    u'rate',
#    u'estimate',
#    u'level'],
#   [u'participant',
#    u'example',
#    u'level',
#    u'unemployment',
#    u'worker',
#    u'time',
#    u'reason',
#    u'labor',
#    u'force',
#    u'participation'],
#   [u'participant',
#    u'drop',
#    u'unemployment',
#    u'rate',
#    u'progress',
#    u'job',
#    u'work',
#    u'slack',
#    u'employment',
#    u'opportunity'],
#   [u'participant',
#    u'rise',
#    u'wage',
#    u'slack',
#    u'labor',
#    u'market',
#    u'level',
#    u'worker',
#    u'wage',
#    u'increase'],
#   [u'participant',
#    u'report',
#    u'wage',
#    u'pressure',
#    u'region',
#    u'occupation',
#    u'labor',
#    u'shortage',
#    u'unemployment'],
#   [u'couple',
#    u'participant',
#    u'labor',
#    u'cost',
#    u'mid-1980',
#    u'wage',
#    u'pressure',
#    u'indicator',
#    u'inflation'],
#   [u'inflation', u'month', u'participant', u'percent', u'objective'],
#   [u'inflation',
#    u'medium',
#    u'term',
#    u'resource',
#    u'inflation',
#    u'expectation',
#    u'stable'],
#   [u'support',
#    u'assessment',
#    u'result',
#    u'model',
#    u'inflation',
#    u'inflation',
#    u'expectation'],
#   [u'risk',
#    u'inflation',
#    u'participant',
#    u'inflation',
#    u'objective',
#    u'medium',
#    u'term'],
#   [u'risk'],
#   [u'tightening',
#    u'labor',
#    u'market',
#    u'risk',
#    u'inflation',
#    u'inflation',
#    u'expectation',
#    u'environment',
#    u'expansion'],
#   [u'discussion',
#    u'stability',
#    u'issue',
#    u'participant',
#    u'evidence',
#    u'valuation',
#    u'pressure',
#    u'asset',
#    u'market',
#    u'pressure',
#    u'measure',
#    u'vulnerability',
#    u'level'],
#   [u'result', u'vulnerability'],
#   [u'participant', u'stability', u'risk', u'discussion', u'risk'],
#   [u'stability', u'concern', u'tool', u'policy', u'response'],
#   [u'respect',
#    u'policy',
#    u'medium',
#    u'run',
#    u'participant',
#    u'labor',
#    u'market',
#    u'condition',
#    u'inflation',
#    u'objective',
#    u'month',
#    u'progress',
#    u'goal'],
#   [u'participant', u'convergence', u'objective', u'policy', u'accommodation'],
#   [u'participant',
#    u'progress',
#    u'goal',
#    u'policy',
#    u'accommodation',
#    u'unemployment',
#    u'inflation',
#    u'objective',
#    u'medium',
#    u'term'],
#   [u'participant', u'guidance'],
#   [u'view',
#    u'guidance',
#    u'increase',
#    u'target',
#    u'fund',
#    u'rate',
#    u'future',
#    u'level',
#    u'fund',
#    u'rate'],
#   [u'guidance', u'evolution', u'datum'],
#   [u'participant',
#    u'change',
#    u'expectation',
#    u'timing',
#    u'increase',
#    u'fund',
#    u'rate',
#    u'information',
#    u'trajectory',
#    u'activity',
#    u'labor',
#    u'market',
#    u'inflation'],
#   [u'participant',
#    u'drop',
#    u'quarter',
#    u'uncertainty',
#    u'outlook',
#    u'datum',
#    u'production',
#    u'spending',
#    u'labor',
#    u'market',
#    u'development',
#    u'light',
#    u'pace',
#    u'growth'],
#   [u'inflation',
#    u'development',
#    u'participant',
#    u'inflation',
#    u'objective',
#    u'continuation',
#    u'policy',
#    u'inflation',
#    u'percent',
#    u'inflation',
#    u'expectation'],
#   [u'discussion',
#    u'policy',
#    u'period',
#    u'member',
#    u'information',
#    u'activity',
#    u'quarter'],
#   [u'policy', u'growth', u'extent', u'restraint'],
#   [u'policy',
#    u'accommodation',
#    u'activity',
#    u'pace',
#    u'labor',
#    u'market',
#    u'indicator',
#    u'inflation',
#    u'level',
#    u'judge',
#    u'mandate'],
#   [u'information',
#    u'expectation',
#    u'improvement',
#    u'labor',
#    u'market',
#    u'condition',
#    u'inflation',
#    u'percent',
#    u'objective',
#    u'member',
#    u'reduction',
#    u'pace',
#    u'asset',
#    u'purchase',
#    u'meeting'],
#   [u'datum',
#    u'expectation',
#    u'labor',
#    u'market',
#    u'indicator',
#    u'inflation',
#    u'mandate-consistent',
#    u'level',
#    u'pace',
#    u'asset',
#    u'purchase',
#    u'step',
#    u'meeting'],
#   [u'asset',
#    u'purchase',
#    u'course',
#    u'decision',
#    u'contingent',
#    u'outlook',
#    u'labor',
#    u'market',
#    u'inflation',
#    u'assessment',
#    u'efficacy',
#    u'cost',
#    u'purchase'],
#   [u'member',
#    u'assessment',
#    u'progress',
#    u'objective',
#    u'employment',
#    u'percent',
#    u'inflation',
#    u'enhancement',
#    u'statement',
#    u'language',
#    u'view',
#    u'progress'],
#   [u'labor',
#    u'market',
#    u'member',
#    u'range',
#    u'indicator',
#    u'labor',
#    u'market',
#    u'condition',
#    u'unemployment',
#    u'rate',
#    u'number',
#    u'measure',
#    u'labor',
#    u'utilization',
#    u'month'],
#   [u'description',
#    u'labor',
#    u'market',
#    u'condition',
#    u'unemployment',
#    u'rate',
#    u'description',
#    u'assessment',
#    u'underutilization',
#    u'labor',
#    u'resource',
#    u'evaluation',
#    u'range',
#    u'labor',
#    u'market',
#    u'indicator'],
#   [u'discussion',
#    u'member',
#    u'reservation',
#    u'extent',
#    u'underutilization',
#    u'labor',
#    u'resource'],
#   [u'degree',
#    u'labor',
#    u'market',
#    u'slack',
#    u'statement',
#    u'language',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'improvement',
#    u'labor',
#    u'market',
#    u'condition',
#    u'language',
#    u'concern',
#    u'underutilization',
#    u'labor',
#    u'resource'],
#   [u'conclusion',
#    u'discussion',
#    u'state',
#    u'labor',
#    u'market',
#    u'condition',
#    u'unemployment',
#    u'rate',
#    u'range',
#    u'labor',
#    u'market',
#    u'indicator',
#    u'underutilization',
#    u'labor',
#    u'resource'],
#   [u'member',
#    u'characterization',
#    u'labor',
#    u'market',
#    u'underutilization',
#    u'progress',
#    u'labor',
#    u'market'],
#   [u'inflation',
#    u'member',
#    u'language',
#    u'statement',
#    u'inflation',
#    u'objective',
#    u'judgment',
#    u'likelihood',
#    u'inflation',
#    u'percent'],
#   [u'discussion',
#    u'member',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'guidance',
#    u'timing',
#    u'increase',
#    u'target',
#    u'rate',
#    u'behavior',
#    u'fund',
#    u'rate'],
#   [u'member',
#    u'guidance',
#    u'range',
#    u'fund',
#    u'rate',
#    u'time',
#    u'asset',
#    u'purchase',
#    u'program',
#    u'end',
#    u'time',
#    u'implication',
#    u'policy',
#    u'progress',
#    u'goal'],
#   [u'conclusion',
#    u'discussion',
#    u'transaction',
#    u'accordance',
#    u'policy',
#    u'directive',
#    u'mandate',
#    u'condition',
#    u'employment',
#    u'price',
#    u'stability'],
#   [u'condition',
#    u'reserve',
#    u'market',
#    u'fund',
#    u'trading',
#    u'range',
#    u'percent'],
#   [u'market', u'operation', u'condition'],
#   [u'security', u'pace', u'month', u'agency', u'security', u'pace', u'month'],
#   [u'dollar',
#    u'roll',
#    u'coupon',
#    u'swap',
#    u'transaction',
#    u'settlement',
#    u'agency',
#    u'security',
#    u'transaction'],
#   [u'policy',
#    u'security',
#    u'issue',
#    u'policy',
#    u'payment',
#    u'agency',
#    u'debt',
#    u'agency',
#    u'security',
#    u'agency',
#    u'security'],
#   [u'manager',
#    u'secretary',
#    u'development',
#    u'balance',
#    u'sheet',
#    u'attainment',
#    u'time',
#    u'objective',
#    u'employment',
#    u'price',
#    u'stability'],
#   [u'vote',
#    u'approval',
#    u'statement',
#    u'information',
#    u'growth',
#    u'activity',
#    u'quarter'],
#   [u'range',
#    u'labor',
#    u'market',
#    u'indicator',
#    u'underutilization',
#    u'labor',
#    u'resource'],
#   [u'spending',
#    u'business',
#    u'investment',
#    u'recovery',
#    u'housing',
#    u'sector'],
#   [u'policy', u'growth', u'extent', u'restraint'],
#   [u'inflation', u'objective'],
#   [u'inflation', u'expectation', u'stable'],
#   [u'mandate', u'employment', u'price', u'stability'],
#   [u'policy',
#    u'accommodation',
#    u'activity',
#    u'pace',
#    u'labor',
#    u'market',
#    u'indicator',
#    u'inflation',
#    u'level',
#    u'judge',
#    u'mandate'],
#   [u'risk',
#    u'outlook',
#    u'activity',
#    u'labor',
#    u'market',
#    u'judge',
#    u'likelihood',
#    u'inflation',
#    u'percent'],
#   [u'judge',
#    u'strength',
#    u'economy',
#    u'improvement',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'light',
#    u'progress',
#    u'employment',
#    u'improvement',
#    u'outlook',
#    u'labor',
#    u'market',
#    u'condition',
#    u'inception',
#    u'asset',
#    u'purchase',
#    u'program',
#    u'reduction',
#    u'pace',
#    u'asset',
#    u'purchase'],
#   [u'holding',
#    u'agency',
#    u'security',
#    u'pace',
#    u'month',
#    u'month',
#    u'holding',
#    u'security',
#    u'pace',
#    u'month',
#    u'month'],
#   [u'existing',
#    u'policy',
#    u'payment',
#    u'holding',
#    u'agency',
#    u'debt',
#    u'agency',
#    u'security',
#    u'agency',
#    u'security',
#    u'security',
#    u'auction'],
#   [u'still-increasing',
#    u'holding',
#    u'security',
#    u'pressure',
#    u'rate',
#    u'support',
#    u'mortgage',
#    u'market',
#    u'condition',
#    u'turn',
#    u'recovery',
#    u'inflation',
#    u'time',
#    u'rate',
#    u'mandate'],
#   [u'information',
#    u'development',
#    u'month',
#    u'purchase',
#    u'agency',
#    u'security',
#    u'policy',
#    u'tool',
#    u'outlook',
#    u'labor',
#    u'market',
#    u'context',
#    u'price',
#    u'stability'],
#   [u'information',
#    u'expectation',
#    u'improvement',
#    u'labor',
#    u'market',
#    u'condition',
#    u'inflation',
#    u'objective',
#    u'pace',
#    u'asset',
#    u'purchase',
#    u'step',
#    u'meeting'],
#   [u'asset',
#    u'purchase',
#    u'course',
#    u'decision',
#    u'pace',
#    u'contingent',
#    u'outlook',
#    u'labor',
#    u'market',
#    u'inflation',
#    u'assessment',
#    u'efficacy',
#    u'cost',
#    u'purchase'],
#   [u'progress',
#    u'employment',
#    u'price',
#    u'stability',
#    u'today',
#    u'view',
#    u'stance',
#    u'policy'],
#   [u'percent',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'progress',
#    u'objective',
#    u'employment',
#    u'percent',
#    u'inflation'],
#   [u'assessment',
#    u'account',
#    u'range',
#    u'information',
#    u'measure',
#    u'labor',
#    u'market',
#    u'condition',
#    u'indicator',
#    u'inflation',
#    u'pressure',
#    u'inflation',
#    u'expectation',
#    u'reading',
#    u'development'],
#   [u'assessment',
#    u'factor',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'time',
#    u'asset',
#    u'purchase',
#    u'program',
#    u'end',
#    u'inflation',
#    u'percent',
#    u'goal',
#    u'inflation',
#    u'expectation'],
#   [u'policy',
#    u'accommodation',
#    u'approach',
#    u'goal',
#    u'employment',
#    u'inflation',
#    u'percent'],
#   [u'employment',
#    u'inflation',
#    u'level',
#    u'condition',
#    u'time',
#    u'target',
#    u'fund',
#    u'rate',
#    u'level',
#    u'view'],
#   [u'statement',
#    u'guidance',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'time',
#    u'asset',
#    u'purchase',
#    u'program'],
#   [u'view',
#    u'reference',
#    u'calendar',
#    u'time',
#    u'language',
#    u'policy',
#    u'datum'],
#   [u'statement',
#    u'progress',
#    u'goal',
#    u'risk',
#    u'volatility',
#    u'market',
#    u'economy',
#    u'accommodation',
#    u'market'],
#   [u'session'],
#   [u'portion', u'meeting', u'session'],
#   [u'staff',
#    u'forecast',
#    u'meeting',
#    u'release',
#    u'advance',
#    u'estimate',
#    u'quarter',
#    u'revision',
#    u'period']],
#  [[u'alternate'],
#   [u'special', u'special'],
#   [u'previous', u'broad'],
#   [u'joint', u'domestic', u'foreign', u'financial'],
#   [u'open',
#    u'recent',
#    u'term',
#    u'fixed-rate',
#    u'repurchase',
#    u'operational',
#    u'ongoing',
#    u'recent',
#    u'foreign',
#    u'central',
#    u'international'],
#   [u'mortgage-backed', u'small', u'primary'],
#   [u'unanimous', u'domestic', u'intermeeting'],
#   [u'foreign', u'intermeeting'],
#   [u'eventual', u'monetary', u'consistent', u'additional', u'appropriate'],
#   [u'possible', u'monetary'],
#   [u'previous'],
#   [u'expressed', u'noted'],
#   [u'appropriate', u'federal', u'key'],
#   [u'federal', u'hard', u'excess', u'federal'],
#   [u'ioer', u'primary', u'federal'],
#   [u'temporary', u'limited-scale', u'firmer'],
#   [u'ioer', u'federal', u'federal'],
#   [u'federal', u'possible', u'minimal', u'necessary'],
#   [u'insufficient', u'likely', u'monetary', u'raise'],
#   [u'large', u'effective', u'monetary'],
#   [u'financial', u'short-term', u'financial'],
#   [u'discussed'],
#   [u'additional', u'appropriate'],
#   [u'discussed'],
#   [u'general'],
#   [u'smallest', u'consistent', u'efficient', u'monetary'],
#   [u'appropriate', u'future', u'monetary'],
#   [u'federal'],
#   [u'better', u'earlier'],
#   [u'residual'],
#   [u'relative'],
#   [u'financial', u'helpful'],
#   [u'additional', u'appropriate'],
#   [u'clear'],
#   [u'additional'],
#   [u'additional', u'possible', u'ongoing'],
#   [u'29-30',
#    u'real',
#    u'gross',
#    u'domestic',
#    u'second',
#    u'first-quarter',
#    u'modest'],
#   [u'second', u'agricultural', u'longer-run'],
#   [u'second-quarter', u'real', u'revised', u'earlier', u'second'],
#   [u'economic', u'available', u'consistent', u'new'],
#   [u'intermeeting'],
#   [u'total', u'nonfarm', u'average', u'monthly', u'second', u'largest'],
#   [u'unchanged', u'employment-to-population'],
#   [u'long-duration', u'economic', u'elevated', u'historical'],
#   [u'initial', u'recent'],
#   [u'unchanged', u'modest'],
#   [u'second', u'higher', u'electric', u'natural'],
#   [u'second'],
#   [u'light',
#    u'new',
#    u'national',
#    u'regional',
#    u'consistent',
#    u'moderate',
#    u'near'],
#   [u'real', u'personal', u'second', u'higher', u'light'],
#   [u'positive', u'recent'],
#   [u'particular', u'real', u'disposable', u'personal', u'second'],
#   [u'early'],
#   [u'real', u'residential', u'second', u'consecutive'],
#   [u'new', u'consistent', u'subsequent'],
#   [u'multifamily', u'second'],
#   [u'second', u'year-earlier', u'new'],
#   [u'rapid'],
#   [u'real', u'private', u'intellectual', u'second'],
#   [u'nominal', u'new', u'nondefense', u'subsequent'],
#   [u'forward-looking', u'national', u'regional', u'moderate', u'near'],
#   [u'real', u'nonresidential', u'second'],
#   [u'year-earlier'],
#   [u'real', u'federal', u'ongoing', u'fiscal', u'continued'],
#   [u'real', u'local', u'second', u'faster'],
#   [u'international'],
#   [u'automotive'],
#   [u'second', u'overall', u'moderate', u'real', u'substantial', u'negative'],
#   [u'pce', u'faster', u'second', u'higher'],
#   [u'second', u'retail', u'adjusted', u'fourth'],
#   [u'second', u'recent', u'lower'],
#   [u'pce', u'second', u'higher'],
#   [u'near-term', u'early', u'longer-term'],
#   [u'nominal', u'modest'],
#   [u'recent', u'foreign', u'economic', u'second', u'mexican'],
#   [u'real', u'strong', u'euro', u'relative'],
#   [u'advanced', u'foreign', u'second', u'low', u'second-quarter', u'euro'],
#   [u'geopolitical'],
#   [u'longer-term', u'foreign', u'little'],
#   [u'monetary', u'intermeeting', u'accommodative'],
#   [u'anticipated', u'federal'],
#   [u'monetary', u'likely', u'ioer'],
#   [u'primary', u'federal', u'subsequent', u'unchanged'],
#   [u'median',
#    u'likely',
#    u'federal',
#    u'effective',
#    u'relative',
#    u'modal',
#    u'concentrated'],
#   [u'30-year', u'nominal', u'intermeeting'],
#   [u'longer-term'],
#   [u'long', u'longer-run', u'economic'],
#   [u'longer-horizon', u'unchanged'],
#   [u'unsecured', u'short-term', u'intermeeting'],
#   [u'higher',
#    u'take-up',
#    u'average',
#    u'little',
#    u'lower',
#    u'intermeeting',
#    u'record'],
#   [u'mid-may', u'early', u'gradual', u'maximum', u'individual', u'higher'],
#   [u'intermeeting', u'second', u'relative'],
#   [u'option-implied', u'one-month', u'low', u'intermeeting'],
#   [u'nonfinancial', u'strong', u'second'],
#   [u'gross', u'speculative-grade', u'brisk'],
#   [u'industrial', u'robust', u'consistent', u'easier', u'stronger'],
#   [u'leveraged', u'institutional', u'solid'],
#   [u'commercial', u'real', u'second'],
#   [u'stronger', u'second'],
#   [u'cre', u'commercial', u'mortgage-backed', u'solid'],
#   [u'residential', u'intermeeting'],
#   [u'mortgage', u'steady', u'low'],
#   [u'prime', u'second', u'residential', u'real', u'tighter'],
#   [u'second'],
#   [u'large'],
#   [u'benchmark',
#    u'long-term',
#    u'sovereign',
#    u'advanced',
#    u'foreign',
#    u'downward',
#    u'intermeeting',
#    u'downward'],
#   [u'largest',
#    u'european',
#    u'european',
#    u'financial',
#    u'peripheral',
#    u'sovereign',
#    u'euro',
#    u'european'],
#   [u'euro-area', u'industrial'],
#   [u'scheduled', u'modest'],
#   [u'mixed'],
#   [u'broad', u'trade-weighted', u'little', u'intermeeting'],
#   [u'periodic',
#    u'potential',
#    u'financial',
#    u'strong',
#    u'subdued',
#    u'broader',
#    u'financial',
#    u'low',
#    u'aggregate',
#    u'nonfinancial',
#    u'important',
#    u'overall',
#    u'financial'],
#   [u'low', u'low', u'eventual'],
#   [u'real', u'weaker'],
#   [u'real', u'second', u'unrevised', u'economic', u'strong', u'real'],
#   [u'particular', u'solid', u'industrial', u'steady', u'strong'],
#   [u'medium-term', u'real'],
#   [u'real', u'faster', u'second'],
#   [u'fiscal', u'foreign', u'economic'],
#   [u'downward'],
#   [u'downward',
#    u'real',
#    u'closer',
#    u'longer-run',
#    u'natural',
#    u'assumed',
#    u'potential'],
#   [u'narrower', u'previous'],
#   [u'near-term',
#    u'little',
#    u'recent',
#    u'faster-than-anticipated',
#    u'transitory'],
#   [u'little', u'medium-term'],
#   [u'second', u'longer-run'],
#   [u'longer-run', u'stable', u'forecast'],
#   [u'real', u'past'],
#   [u'little', u'monetary', u'fiscal', u'adverse', u'previous'],
#   [u'current',
#    u'economic',
#    u'real',
#    u'second',
#    u'ongoing',
#    u'continued',
#    u'moderate',
#    u'economic',
#    u'consistent',
#    u'dual'],
#   [u'economic',
#    u'pointed',
#    u'possible',
#    u'downside',
#    u'persistent',
#    u'continued',
#    u'slow'],
#   [u'closer', u'longer-run'],
#   [u'stronger', u'economic', u'second'],
#   [u'business'],
#   [u'cautious', u'personal', u'slow', u'insufficient', u'stronger'],
#   [u'low',
#    u'affordable',
#    u'various',
#    u'low',
#    u'high',
#    u'younger',
#    u'first-time'],
#   [u'continued'],
#   [u'satisfied', u'rental', u'multifamily'],
#   [u'residential'],
#   [u'continued',
#    u'noted',
#    u'positive',
#    u'recent',
#    u'regional',
#    u'national',
#    u'service-sector'],
#   [u'particular', u'cited', u'aerospace', u'high-tech'],
#   [u'higher'],
#   [u'favorable'],
#   [u'stronger', u'economic', u'second'],
#   [u'suggested', u'commercial', u'industrial'],
#   [u'available', u'financial'],
#   [u'uncertain', u'economic', u'cautious'],
#   [u'fiscal', u'dependent', u'federal'],
#   [u'recent', u'national'],
#   [u'noticeable', u'overall', u'broader', u'long', u'part-time', u'full-time'],
#   [u'stable', u'long-duration'],
#   [u'positive', u'increased', u'higher', u'apparent'],
#   [u'recent',
#    u'cumulative',
#    u'past',
#    u'greater',
#    u'anticipated',
#    u'closer',
#    u'normal'],
#   [u'reliable', u'overall', u'principal'],
#   [u'larger',
#    u'current',
#    u'consistent',
#    u'normal',
#    u'indicated',
#    u'longer-run',
#    u'normal'],
#   [u'still-elevated', u'long-term', u'economic', u'low'],
#   [u'recent', u'long-term', u'unemployed', u'part-time'],
#   [u'subdued', u'elevated', u'low-paid', u'part-time', u'overall'],
#   [u'low'],
#   [u'pass-through', u'attenuated', u'reliable', u'higher'],
#   [u'recent'],
#   [u'likely', u'diminished'],
#   [u'various', u'statistical'],
#   [u'downside', u'likely'],
#   [u'upside'],
#   [u'recent', u'upside', u'economic'],
#   [u'financial',
#    u'noted',
#    u'particular',
#    u'widespread',
#    u'financial',
#    u'low',
#    u'moderate'],
#   [u'financial'],
#   [u'financial', u'macroeconomic'],
#   [u'various',
#    u'financial',
#    u'monetary',
#    u'regulatory',
#    u'timely',
#    u'effective'],
#   [u'monetary', u'longer-run', u'recent', u'anticipated'],
#   [u'appropriate', u'monetary'],
#   [u'actual', u'sufficient', u'prompt'],
#   [u'uncomfortable', u'forward'],
#   [u'later', u'initial', u'federal', u'lower', u'likely', u'appropriate'],
#   [u'policy-setting', u'economic'],
#   [u'appropriate', u'federal', u'economic'],
#   [u'particular',
#    u'real',
#    u'transitory',
#    u'additional',
#    u'underlying',
#    u'economic'],
#   [u'recent', u'likely', u'accommodative', u'projected', u'longer-term'],
#   [u'monetary', u'economic', u'second'],
#   [u'fiscal', u'economic'],
#   [u'appropriate', u'economic', u'moderate', u'consistent', u'dual'],
#   [u'incoming', u'ongoing', u'appropriate'],
#   [u'incoming', u'measured', u'future'],
#   [u'preset', u'likely'],
#   [u'maximum'],
#   [u'recent'],
#   [u'appropriate', u'recent', u'mentioned'],
#   [u'expressed'],
#   [u'particular', u'difficult', u'difficult'],
#   [u'new', u'increased'],
#   [u'significant'],
#   [u'long', u'faster', u'anticipated'],
#   [u'closer', u'longer-run'],
#   [u'federal', u'forward', u'appropriate', u'anticipated', u'federal'],
#   [u'appropriate',
#    u'current',
#    u'federal',
#    u'considerable',
#    u'dependent',
#    u'monetary',
#    u'considerable'],
#   [u'following',
#    u'domestic',
#    u'consistent',
#    u'statutory',
#    u'monetary',
#    u'financial',
#    u'maximum'],
#   [u'particular', u'consistent', u'federal'],
#   [u'open', u'necessary'],
#   [u'longer-term', u'mortgage-backed'],
#   [u'necessary', u'mortgage-backed'],
#   [u'new', u'principal', u'mortgage-backed', u'mortgage-backed'],
#   [u'ongoing', u'maximum'],
#   [u'economic', u'second'],
#   [u'significant'],
#   [u'slow'],
#   [u'fiscal', u'economic'],
#   [u'closer', u'longer-run'],
#   [u'longer-term'],
#   [u'consistent', u'statutory', u'maximum'],
#   [u'appropriate', u'economic', u'moderate', u'consistent', u'dual'],
#   [u'economic'],
#   [u'sufficient', u'underlying', u'broader', u'ongoing'],
#   [u'cumulative', u'maximum', u'current'],
#   [u'mortgage-backed', u'longer-term'],
#   [u'principal', u'mortgage-backed', u'mortgage-backed'],
#   [u'sizable',
#    u'longer-term',
#    u'downward',
#    u'longer-term',
#    u'broader',
#    u'financial',
#    u'accommodative',
#    u'stronger',
#    u'economic',
#    u'consistent',
#    u'dual'],
#   [u'monitor',
#    u'incoming',
#    u'economic',
#    u'financial',
#    u'mortgage-backed',
#    u'appropriate'],
#   [u'incoming', u'ongoing', u'longer-run', u'measured', u'future'],
#   [u'preset', u'likely'],
#   [u'continued', u'maximum', u'accommodative', u'monetary', u'appropriate'],
#   [u'long', u'current', u'federal', u'maximum'],
#   [u'wide', u'financial'],
#   [u'appropriate',
#    u'current',
#    u'federal',
#    u'considerable',
#    u'longer-run',
#    u'longer-term'],
#   [u'balanced', u'consistent', u'longer-run', u'maximum'],
#   [u'mandate-consistent', u'economic', u'federal', u'normal'],
#   [u'appropriate', u'current', u'federal', u'considerable'],
#   [u'monetary', u'incoming'],
#   [u'substantial',
#    u'economic',
#    u'unnecessary',
#    u'disruptive',
#    u'financial',
#    u'financial'],
#   [u'joint'],
#   [u'joint'],
#   [u'real', u'second', u'earlier']])

# %% [markdown]
# We run modified_get_parts on each fomc statement and create a new dictionary fomc_parts. We strip each statement of the html at its start before passing it to modified_get_parts.

# %%
# %%time
fomc_parts = {}
for key in fomc_mins.keys():
    fomc_parts[key] = modified_get_parts(pq(fomc_mins[key]).text())

# %%
fomc_parts_file = open("fomc_parts.json", "wb")
json.dump(fomc_parts, fomc_parts_file)
fomc_parts_file.close()

# %% [markdown]
# We can now create a flattened list of all the nouns.

# %%
nvocab = []
for key in fomc_mins.keys():
    nouns = fomc_parts[key][0]
    for nounlist in nouns:
        nvocab.append(nounlist)
nvocab
# Out:
# [[u'member'],
#  [u'adviser', u'governor'],
#  [u'governor'],
#  [u'subcommittee',
#   u'work',
#   u'subcommittee',
#   u'frame',
#   u'discussion',
#   u'range',
#   u'communication',
#   u'issue'],
#  [u'development',
#   u'session',
#   u'governor',
#   u'manager',
#   u'development',
#   u'market'],
#  [u'manager',
#   u'market',
#   u'operation',
#   u'period',
#   u'outcome',
#   u'test',
#   u'operation',
#   u'result',
#   u'agreement',
#   u'exercise',
#   u'effect',
#   u'bank',
#   u'policy',
#   u'action',
#   u'yield',
#   u'portion',
#   u'portfolio'],
#  [u'addition',
#   u'manager',
#   u'plan',
#   u'pilot',
#   u'program',
#   u'number',
#   u'counterparty',
#   u'agency',
#   u'security',
#   u'operation',
#   u'firm',
#   u'dealer'],
#  [u'vote', u'transaction', u'period'],
#  [u'intervention', u'operation', u'currency', u'account', u'period'],
#  [u'participant',
#   u'discussion',
#   u'issue',
#   u'normalization',
#   u'stance',
#   u'policy',
#   u'intention',
#   u'information',
#   u'public',
#   u'year',
#   u'participant',
#   u'step',
#   u'policy',
#   u'accommodation'],
#  [u'staff', u'approach', u'policy', u'stance', u'policy'],
#  [u'approach',
#   u'discussion',
#   u'normalization',
#   u'strategy',
#   u'policy',
#   u'tool',
#   u'meeting'],
#  [u'participant',
#   u'general',
#   u'support',
#   u'normalization',
#   u'approach',
#   u'staff',
#   u'reservation',
#   u'feature'],
#  [u'participant',
#   u'fund',
#   u'rate',
#   u'policy',
#   u'rate',
#   u'range',
#   u'basis',
#   u'point',
#   u'rate',
#   u'time',
#   u'liftoff',
#   u'time'],
#  [u'participant',
#   u'range',
#   u'fund',
#   u'rate',
#   u'communication',
#   u'tool',
#   u'target',
#   u'policy',
#   u'communication',
#   u'normalization',
#   u'period',
#   u'rate',
#   u'reserve',
#   u'rate',
#   u'addition',
#   u'fund',
#   u'rate'],
#  [u'participant',
#   u'adjustment',
#   u'rate',
#   u'tool',
#   u'fund',
#   u'rate',
#   u'target',
#   u'range',
#   u'influence',
#   u'money',
#   u'market',
#   u'rate'],
#  [u'addition',
#   u'use',
#   u'facility',
#   u'floor',
#   u'money',
#   u'market',
#   u'rate',
#   u'normalization'],
#  [u'participant',
#   u'rate',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'rate',
#   u'fund',
#   u'target',
#   u'range'],
#  [u'participant',
#   u'rate',
#   u'fund',
#   u'target',
#   u'range',
#   u'normalization',
#   u'process',
#   u'reliance',
#   u'facility',
#   u'role'],
#  [u'participant',
#   u'strategy',
#   u'control',
#   u'money',
#   u'market',
#   u'rate',
#   u'liftoff',
#   u'confusion',
#   u'path',
#   u'policy',
#   u'question',
#   u'ability',
#   u'policy'],
#  [u'participant', u'facility', u'policy', u'implementation', u'purpose'],
#  [u'participant',
#   u'desire',
#   u'feature',
#   u'facility',
#   u'design',
#   u'role',
#   u'intermediation',
#   u'risk',
#   u'facility',
#   u'strain',
#   u'market',
#   u'period',
#   u'stress'],
#  [u'option', u'concern', u'method', u'program', u'size'],
#  [u'participant',
#   u'testing',
#   u'information',
#   u'feature',
#   u'temper',
#   u'risk',
#   u'facility'],
#  [u'participant', u'approach', u'size', u'composition', u'balance', u'sheet'],
#  [u'size', u'balance', u'sheet'],
#  [u'addition',
#   u'balance',
#   u'sheet',
#   u'level',
#   u'implementation',
#   u'policy',
#   u'security',
#   u'order',
#   u'effect',
#   u'portfolio',
#   u'allocation',
#   u'credit',
#   u'sector',
#   u'economy'],
#  [u'participant',
#   u'size',
#   u'balance',
#   u'sheet',
#   u'decision',
#   u'framework',
#   u'policy'],
#  [u'participant',
#   u'investment',
#   u'increase',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate'],
#  [u'reinvestment',
#   u'liftoff',
#   u'approach',
#   u'reduction',
#   u'size',
#   u'portfolio'],
#  [u'participant', u'holding'],
#  [u'couple',
#   u'participant',
#   u'order',
#   u'effect',
#   u'holding',
#   u'mortgage',
#   u'rate',
#   u'rate',
#   u'result',
#   u'repayment',
#   u'principal'],
#  [u'uncertainty',
#   u'normalization',
#   u'process',
#   u'outlook',
#   u'economy',
#   u'market',
#   u'option',
#   u'asset'],
#  [u'participant',
#   u'information',
#   u'public',
#   u'normalization',
#   u'participant',
#   u'step',
#   u'policy',
#   u'accommodation'],
#  [u'importance',
#   u'plan',
#   u'time',
#   u'importance',
#   u'flexibility',
#   u'adjustment',
#   u'normalization',
#   u'approach',
#   u'situation',
#   u'light',
#   u'experience'],
#  [u'participant',
#   u'analysis',
#   u'staff',
#   u'issue',
#   u'normalization',
#   u'background',
#   u'discussion',
#   u'meeting'],
#  [u'participant',
#   u'information',
#   u'public',
#   u'effect',
#   u'facility',
#   u'feedback',
#   u'response',
#   u'communication',
#   u'normalization'],
#  [u'information',
#   u'meeting',
#   u'product',
#   u'quarter',
#   u'decline',
#   u'pace',
#   u'balance',
#   u'half',
#   u'year'],
#  [u'price',
#   u'inflation',
#   u'quarter',
#   u'future',
#   u'price',
#   u'energy',
#   u'commodity',
#   u'couple',
#   u'year',
#   u'measure',
#   u'inflation',
#   u'expectation',
#   u'stable'],
#  [u'advance', u'estimate', u'data', u'period', u'day', u'meeting'],
#  [u'staff',
#   u'assessment',
#   u'activity',
#   u'inflation',
#   u'half',
#   u'information',
#   u'meeting',
#   u'information'],
#  [u'measure', u'labor', u'market', u'condition', u'period'],
#  [u'payroll', u'employment', u'gain', u'quarter', u'quarter'],
#  [u'unemployment',
#   u'rate',
#   u'percent',
#   u'labor',
#   u'force',
#   u'participation',
#   u'rate',
#   u'ratio'],
#  [u'rate',
#   u'unemployment',
#   u'share',
#   u'worker',
#   u'time',
#   u'reason',
#   u'measure',
#   u'standard'],
#  [u'claim', u'unemployment', u'insurance', u'week'],
#  [u'rate', u'job', u'opening', u'rate', u'hiring', u'level'],
#  [u'production',
#   u'quarter',
#   u'output',
#   u'manufacturer',
#   u'decline',
#   u'output',
#   u'gas',
#   u'utility'],
#  [u'capacity', u'utilization', u'quarter'],
#  [u'automaker',
#   u'production',
#   u'schedule',
#   u'motor',
#   u'vehicle',
#   u'assembly',
#   u'quarter',
#   u'reading',
#   u'order',
#   u'manufacturing',
#   u'survey',
#   u'gain',
#   u'factory',
#   u'output',
#   u'term'],
#  [u'consumption',
#   u'expenditure',
#   u'quarter',
#   u'purchase',
#   u'motor',
#   u'vehicle'],
#  [u'factor', u'household', u'spending', u'month'],
#  [u'gain',
#   u'equity',
#   u'value',
#   u'home',
#   u'price',
#   u'household',
#   u'net',
#   u'income',
#   u'quarter'],
#  [u'sentiment', u'survey', u'consumer', u'average', u'half', u'year'],
#  [u'expenditure', u'investment', u'quarter', u'quarters'],
#  [u'single-family',
#   u'house',
#   u'quarter',
#   u'level',
#   u'permit',
#   u'issuance',
#   u'increase',
#   u'start',
#   u'month'],
#  [u'sector', u'permit', u'net', u'quarter'],
#  [u'existing', u'home', u'sale', u'quarter', u'level', u'home', u'sale'],
#  [u'home', u'price', u'rate', u'increase', u'year'],
#  [u'expenditure',
#   u'business',
#   u'equipment',
#   u'property',
#   u'product',
#   u'quarter'],
#  [u'order',
#   u'capital',
#   u'good',
#   u'net',
#   u'level',
#   u'order',
#   u'shipment',
#   u'increase',
#   u'shipment',
#   u'month'],
#  [u'indicator',
#   u'survey',
#   u'business',
#   u'condition',
#   u'increase',
#   u'business',
#   u'equipment',
#   u'spending',
#   u'term'],
#  [u'business', u'expenditure', u'construction', u'quarter'],
#  [u'business',
#   u'inventory',
#   u'sale',
#   u'energy',
#   u'sector',
#   u'inventory',
#   u'level'],
#  [u'government',
#   u'purchase',
#   u'half',
#   u'year',
#   u'consolidation',
#   u'decline',
#   u'defense',
#   u'spending'],
#  [u'contrast',
#   u'state',
#   u'government',
#   u'purchase',
#   u'quarter',
#   u'payroll',
#   u'pace',
#   u'quarter',
#   u'outlay',
#   u'construction'],
#  [u'trade', u'deficit', u'import', u'export'],
#  [u'rise', u'export', u'petroleum', u'product'],
#  [u'quarter',
#   u'net',
#   u'export',
#   u'drag',
#   u'change',
#   u'contribution',
#   u'quarter'],
#  [u'consumer',
#   u'price',
#   u'price',
#   u'index',
#   u'pace',
#   u'quarter',
#   u'percent',
#   u'year'],
#  [u'energy',
#   u'price',
#   u'inflation',
#   u'quarter',
#   u'gasoline',
#   u'price',
#   u'basis',
#   u'week'],
#  [u'food',
#   u'price',
#   u'inflation',
#   u'quarter',
#   u'effect',
#   u'drought',
#   u'disease',
#   u'crop',
#   u'livestock',
#   u'production',
#   u'spot',
#   u'price',
#   u'crop',
#   u'week',
#   u'future',
#   u'price',
#   u'price',
#   u'livestock',
#   u'year'],
#  [u'price',
#   u'index',
#   u'item',
#   u'food',
#   u'energy',
#   u'quarter',
#   u'percent',
#   u'year'],
#  [u'inflation', u'expectation', u'survey', u'net', u'expectation'],
#  [u'measure',
#   u'labor',
#   u'compensation',
#   u'gain',
#   u'wage',
#   u'employee',
#   u'benefit'],
#  [u'indicator', u'activity', u'quarter', u'datum', u'pickup'],
#  [u'growth', u'data', u'area', u'improvement', u'quarter'],
#  [u'economy',
#   u'inflation',
#   u'quarter',
#   u'rate',
#   u'inflation',
#   u'area',
#   u'objective'],
#  [u'condition',
#   u'balance',
#   u'meeting',
#   u'risk',
#   u'investor',
#   u'sentiment',
#   u'time'],
#  [u'net',
#   u'yield',
#   u'security',
#   u'equity',
#   u'price',
#   u'exchange',
#   u'value',
#   u'dollar'],
#  [u'market',
#   u'participant',
#   u'policy',
#   u'communication',
#   u'period',
#   u'policy',
#   u'stance'],
#  [u'path', u'fund', u'rate', u'statement', u'press', u'conference'],
#  [u'market',
#   u'participant',
#   u'note',
#   u'discussion',
#   u'policy',
#   u'normalization',
#   u'minute',
#   u'discussion',
#   u'spread',
#   u'rate',
#   u'rate'],
#  [u'result',
#   u'meeting',
#   u'market',
#   u'participant',
#   u'expectation',
#   u'timing',
#   u'increase',
#   u'fund',
#   u'rate',
#   u'policy',
#   u'path',
#   u'survey',
#   u'meeting'],
#  [u'dealer',
#   u'quarter',
#   u'time',
#   u'liftoff',
#   u'fund',
#   u'rate',
#   u'survey',
#   u'distribution',
#   u'time',
#   u'liftoff',
#   u'quarter'],
#  [u'balance', u'yield', u'basis', u'point', u'period'],
#  [u'concern', u'tension', u'release', u'minute', u'decline', u'yield'],
#  [u'decline',
#   u'yield',
#   u'end',
#   u'curve',
#   u'continuation',
#   u'pattern',
#   u'year',
#   u'market',
#   u'participant',
#   u'reduction',
#   u'investor',
#   u'expectation',
#   u'growth',
#   u'term',
#   u'premium'],
#  [u'measure', u'inflation', u'compensation'],
#  [u'condition', u'dollar', u'market', u'stable', u'period'],
#  [u'result',
#   u'market',
#   u'rate',
#   u'repurchase',
#   u'agreement',
#   u'period',
#   u'participation',
#   u'exercise',
#   u'high',
#   u'quarter-end'],
#  [u'testing', u'increase', u'offer', u'rate', u'award', u'participation'],
#  [u'index',
#   u'percent',
#   u'period',
#   u'earning',
#   u'report',
#   u'range',
#   u'company',
#   u'profit',
#   u'quarter',
#   u'quarter'],
#  [u'index', u'volatility', u'return', u'index', u'level', u'period'],
#  [u'corporation', u'quarter'],
#  [u'issuance', u'investment', u'bond'],
#  [u'loan',
#   u'bank',
#   u'balance',
#   u'sheet',
#   u'pace',
#   u'report',
#   u'lending',
#   u'practice',
#   u'lending',
#   u'standard',
#   u'term',
#   u'loan',
#   u'demand',
#   u'firm',
#   u'size'],
#  [u'issuance', u'loan', u'investor'],
#  [u'condition', u'market', u'estate', u'quarter'],
#  [u'bank', u'standard', u'demand', u'loan', u'quarter', u'balance'],
#  [u'loan', u'bank', u'book', u'issuance', u'security'],
#  [u'condition', u'mortgage', u'market', u'period'],
#  [u'rate', u'percent', u'origination', u'volume'],
#  [u'underwriting',
#   u'standard',
#   u'home-purchase',
#   u'loan',
#   u'bank',
#   u'quarter',
#   u'net',
#   u'standard',
#   u'type',
#   u'estate',
#   u'loan',
#   u'midpoint',
#   u'respondent',
#   u'bank',
#   u'longer-term'],
#  [u'bank', u'demand', u'auto', u'loan', u'quarter'],
#  [u'addition',
#   u'demand',
#   u'credit',
#   u'card',
#   u'loan',
#   u'bank',
#   u'policy',
#   u'loan'],
#  [u'yield',
#   u'bond',
#   u'economy',
#   u'trend',
#   u'start',
#   u'year',
#   u'tension',
#   u'period',
#   u'pressure'],
#  [u'concern',
#   u'bank',
#   u'litigation',
#   u'risk',
#   u'bank',
#   u'market',
#   u'yield',
#   u'spread',
#   u'bond',
#   u'area',
#   u'equity',
#   u'price',
#   u'index',
#   u'bank'],
#  [u'intermeeting',
#   u'data',
#   u'production',
#   u'market',
#   u'expectation',
#   u'headline',
#   u'equity',
#   u'market',
#   u'region'],
#  [u'news',
#   u'market',
#   u'economy',
#   u'growth',
#   u'concern',
#   u'debt',
#   u'payment',
#   u'market',
#   u'effect'],
#  [u'change',
#   u'market',
#   u'equity',
#   u'index',
#   u'period',
#   u'market',
#   u'bond',
#   u'yield'],
#  [u'dollar', u'net', u'period'],
#  [u'staff',
#   u'report',
#   u'risk',
#   u'stability',
#   u'capital',
#   u'position',
#   u'bank',
#   u'use',
#   u'maturity',
#   u'transformation',
#   u'leverage',
#   u'sector',
#   u'level',
#   u'leverage',
#   u'sector',
#   u'factor',
#   u'stability'],
#  [u'staff',
#   u'report',
#   u'risk',
#   u'premium',
#   u'level',
#   u'market',
#   u'volatility',
#   u'loosening',
#   u'underwriting',
#   u'standard',
#   u'number',
#   u'market',
#   u'risk',
#   u'correction',
#   u'asset',
#   u'valuation'],
#  [u'outlook',
#   u'datum',
#   u'staff',
#   u'forecast',
#   u'meeting',
#   u'growth',
#   u'half',
#   u'year',
#   u'staff',
#   u'forecast',
#   u'growth',
#   u'half',
#   u'year',
#   u'indicator',
#   u'activity',
#   u'relation',
#   u'half',
#   u'year'],
#  [u'payroll',
#   u'employment',
#   u'pace',
#   u'unemployment',
#   u'rate',
#   u'production',
#   u'gain',
#   u'reading',
#   u'business',
#   u'survey'],
#  [u'staff', u'forecast', u'growth'],
#  [u'staff', u'project', u'pace', u'half', u'year', u'year'],
#  [u'forecast',
#   u'restraint',
#   u'spending',
#   u'growth',
#   u'change',
#   u'policy',
#   u'improvement',
#   u'credit',
#   u'availability',
#   u'increase',
#   u'consumer',
#   u'business',
#   u'confidence',
#   u'pickup',
#   u'growth'],
#  [u'response',
#   u'surprise',
#   u'unemployment',
#   u'rate',
#   u'staff',
#   u'forecast',
#   u'unemployment',
#   u'rate',
#   u'projection',
#   u'period'],
#  [u'revision',
#   u'growth',
#   u'half',
#   u'year',
#   u'unemployment',
#   u'rate',
#   u'staff',
#   u'estimate',
#   u'rate',
#   u'staff',
#   u'pace',
#   u'output',
#   u'growth',
#   u'year',
#   u'growth'],
#  [u'result',
#   u'resource',
#   u'slack',
#   u'projection',
#   u'year',
#   u'forecast',
#   u'projection',
#   u'period'],
#  [u'staff', u'forecast', u'inflation', u'data', u'increase'],
#  [u'resource', u'slack', u'projection', u'forecast', u'inflation'],
#  [u'projection',
#   u'inflation',
#   u'half',
#   u'year',
#   u'objective',
#   u'percent',
#   u'year'],
#  [u'inflation',
#   u'expectation',
#   u'change',
#   u'commodity',
#   u'import',
#   u'price',
#   u'slack',
#   u'labor',
#   u'product',
#   u'market',
#   u'inflation',
#   u'objective'],
#  [u'staff',
#   u'uncertainty',
#   u'projection',
#   u'growth',
#   u'inflation',
#   u'unemployment',
#   u'rate',
#   u'line',
#   u'average',
#   u'year'],
#  [u'risk',
#   u'growth',
#   u'downside',
#   u'policy',
#   u'policy',
#   u'economy',
#   u'shock',
#   u'risk',
#   u'projection'],
#  [u'participant',
#   u'view',
#   u'condition',
#   u'outlook',
#   u'discussion',
#   u'situation',
#   u'outlook',
#   u'meeting',
#   u'participant',
#   u'rebound',
#   u'quarter',
#   u'improvement',
#   u'labor',
#   u'market',
#   u'condition',
#   u'expectation',
#   u'expansion',
#   u'labor',
#   u'market',
#   u'indicator',
#   u'inflation',
#   u'level',
#   u'judge',
#   u'mandate'],
#  [u'participant',
#   u'risk',
#   u'outlook',
#   u'activity',
#   u'labor',
#   u'market',
#   u'source',
#   u'risk',
#   u'weakness',
#   u'housing',
#   u'sector',
#   u'rise',
#   u'household',
#   u'income',
#   u'spillover',
#   u'development'],
#  [u'participant',
#   u'inflation',
#   u'percent',
#   u'objective',
#   u'risk',
#   u'inflation',
#   u'objective'],
#  [u'spending', u'growth', u'half', u'year', u'half'],
#  [u'contact',
#   u'district',
#   u'pickup',
#   u'consumer',
#   u'spending',
#   u'weakness',
#   u'quarter'],
#  [u'participant',
#   u'concern',
#   u'household',
#   u'saving',
#   u'rate',
#   u'rise',
#   u'wage',
#   u'income',
#   u'consumer',
#   u'spending'],
#  [u'mortgage',
#   u'rate',
#   u'housing',
#   u'factor',
#   u'demand',
#   u'income',
#   u'level',
#   u'student',
#   u'debt',
#   u'difficulty',
#   u'mortgage',
#   u'credit',
#   u'homebuyer'],
#  [u'weakness',
#   u'homebuilding',
#   u'rise',
#   u'house',
#   u'price',
#   u'supply',
#   u'constraint',
#   u'construction',
#   u'activity'],
#  [u'demand',
#   u'rental',
#   u'investor',
#   u'home',
#   u'market',
#   u'support',
#   u'construction'],
#  [u'participant',
#   u'concern',
#   u'number',
#   u'factor',
#   u'construction',
#   u'housing',
#   u'recovery',
#   u'time'],
#  [u'participant',
#   u'improvement',
#   u'sentiment',
#   u'business',
#   u'contact',
#   u'reading',
#   u'survey',
#   u'manufacturing',
#   u'activity'],
#  [u'participant',
#   u'strength',
#   u'airline',
#   u'railroad',
#   u'trucking',
#   u'firm',
#   u'business',
#   u'motor',
#   u'vehicle',
#   u'industry',
#   u'sector'],
#  [u'addition',
#   u'energy',
#   u'price',
#   u'support',
#   u'activity',
#   u'energy',
#   u'sector'],
#  [u'agriculture',
#   u'sector',
#   u'condition',
#   u'crop',
#   u'price',
#   u'profitability',
#   u'livestock',
#   u'producer'],
#  [u'report',
#   u'business',
#   u'contact',
#   u'support',
#   u'participant',
#   u'expectation',
#   u'growth',
#   u'half',
#   u'year'],
#  [u'case',
#   u'information',
#   u'business',
#   u'increase',
#   u'spending',
#   u'capital',
#   u'equipment',
#   u'pickup',
#   u'investment',
#   u'construction',
#   u'transportation'],
#  [u'number',
#   u'area',
#   u'credit',
#   u'report',
#   u'participant',
#   u'business',
#   u'contact',
#   u'strengthening',
#   u'demand',
#   u'bank',
#   u'credit'],
#  [u'participant', u'business', u'outlook', u'capital', u'spending', u'hiring'],
#  [u'restraint', u'business', u'activity', u'area', u'spending'],
#  [u'labor',
#   u'market',
#   u'condition',
#   u'month',
#   u'participant',
#   u'report',
#   u'development',
#   u'district',
#   u'range',
#   u'indicator'],
#  [u'improvement',
#   u'pickup',
#   u'payroll',
#   u'employment',
#   u'gain',
#   u'decline',
#   u'unemployment',
#   u'rate',
#   u'reduction',
#   u'measure',
#   u'underutilization',
#   u'duration',
#   u'joblessness',
#   u'number',
#   u'worker',
#   u'job',
#   u'employment'],
#  [u'labor',
#   u'force',
#   u'participation',
#   u'rate',
#   u'couple',
#   u'participant',
#   u'transition',
#   u'rate',
#   u'unemployment',
#   u'employment'],
#  [u'participant',
#   u'sign',
#   u'hiring',
#   u'turnover',
#   u'labor',
#   u'market',
#   u'increase',
#   u'job',
#   u'opening',
#   u'plan',
#   u'quit',
#   u'rate',
#   u'improvement',
#   u'worker',
#   u'job'],
#  [u'participant',
#   u'improvement',
#   u'labor',
#   u'market',
#   u'condition',
#   u'progress',
#   u'year',
#   u'labor',
#   u'market',
#   u'condition'],
#  [u'unemployment',
#   u'rate',
#   u'summary',
#   u'statistic',
#   u'state',
#   u'labor',
#   u'market',
#   u'thought',
#   u'focus',
#   u'labor',
#   u'market',
#   u'condition'],
#  [u'participant',
#   u'gap',
#   u'labor',
#   u'market',
#   u'condition',
#   u'assessment',
#   u'level',
#   u'labor',
#   u'utilization',
#   u'difference',
#   u'unemployment',
#   u'rate',
#   u'estimate',
#   u'level'],
#  [u'participant',
#   u'example',
#   u'level',
#   u'unemployment',
#   u'worker',
#   u'time',
#   u'reason',
#   u'labor',
#   u'force',
#   u'participation'],
#  [u'participant',
#   u'drop',
#   u'unemployment',
#   u'rate',
#   u'progress',
#   u'job',
#   u'work',
#   u'slack',
#   u'employment',
#   u'opportunity'],
#  [u'participant',
#   u'rise',
#   u'wage',
#   u'slack',
#   u'labor',
#   u'market',
#   u'level',
#   u'worker',
#   u'wage',
#   u'increase'],
#  [u'participant',
#   u'report',
#   u'wage',
#   u'pressure',
#   u'region',
#   u'occupation',
#   u'labor',
#   u'shortage',
#   u'unemployment'],
#  [u'couple',
#   u'participant',
#   u'labor',
#   u'cost',
#   u'mid-1980',
#   u'wage',
#   u'pressure',
#   u'indicator',
#   u'inflation'],
#  [u'inflation', u'month', u'participant', u'percent', u'objective'],
#  [u'inflation',
#   u'medium',
#   u'term',
#   u'resource',
#   u'inflation',
#   u'expectation',
#   u'stable'],
#  [u'support',
#   u'assessment',
#   u'result',
#   u'model',
#   u'inflation',
#   u'inflation',
#   u'expectation'],
#  [u'risk',
#   u'inflation',
#   u'participant',
#   u'inflation',
#   u'objective',
#   u'medium',
#   u'term'],
#  [u'risk'],
#  [u'tightening',
#   u'labor',
#   u'market',
#   u'risk',
#   u'inflation',
#   u'inflation',
#   u'expectation',
#   u'environment',
#   u'expansion'],
#  [u'discussion',
#   u'stability',
#   u'issue',
#   u'participant',
#   u'evidence',
#   u'valuation',
#   u'pressure',
#   u'asset',
#   u'market',
#   u'pressure',
#   u'measure',
#   u'vulnerability',
#   u'level'],
#  [u'result', u'vulnerability'],
#  [u'participant', u'stability', u'risk', u'discussion', u'risk'],
#  [u'stability', u'concern', u'tool', u'policy', u'response'],
#  [u'respect',
#   u'policy',
#   u'medium',
#   u'run',
#   u'participant',
#   u'labor',
#   u'market',
#   u'condition',
#   u'inflation',
#   u'objective',
#   u'month',
#   u'progress',
#   u'goal'],
#  [u'participant', u'convergence', u'objective', u'policy', u'accommodation'],
#  [u'participant',
#   u'progress',
#   u'goal',
#   u'policy',
#   u'accommodation',
#   u'unemployment',
#   u'inflation',
#   u'objective',
#   u'medium',
#   u'term'],
#  [u'participant', u'guidance'],
#  [u'view',
#   u'guidance',
#   u'increase',
#   u'target',
#   u'fund',
#   u'rate',
#   u'future',
#   u'level',
#   u'fund',
#   u'rate'],
#  [u'guidance', u'evolution', u'datum'],
#  [u'participant',
#   u'change',
#   u'expectation',
#   u'timing',
#   u'increase',
#   u'fund',
#   u'rate',
#   u'information',
#   u'trajectory',
#   u'activity',
#   u'labor',
#   u'market',
#   u'inflation'],
#  [u'participant',
#   u'drop',
#   u'quarter',
#   u'uncertainty',
#   u'outlook',
#   u'datum',
#   u'production',
#   u'spending',
#   u'labor',
#   u'market',
#   u'development',
#   u'light',
#   u'pace',
#   u'growth'],
#  [u'inflation',
#   u'development',
#   u'participant',
#   u'inflation',
#   u'objective',
#   u'continuation',
#   u'policy',
#   u'inflation',
#   u'percent',
#   u'inflation',
#   u'expectation'],
#  [u'discussion',
#   u'policy',
#   u'period',
#   u'member',
#   u'information',
#   u'activity',
#   u'quarter'],
#  [u'policy', u'growth', u'extent', u'restraint'],
#  [u'policy',
#   u'accommodation',
#   u'activity',
#   u'pace',
#   u'labor',
#   u'market',
#   u'indicator',
#   u'inflation',
#   u'level',
#   u'judge',
#   u'mandate'],
#  [u'information',
#   u'expectation',
#   u'improvement',
#   u'labor',
#   u'market',
#   u'condition',
#   u'inflation',
#   u'percent',
#   u'objective',
#   u'member',
#   u'reduction',
#   u'pace',
#   u'asset',
#   u'purchase',
#   u'meeting'],
#  [u'datum',
#   u'expectation',
#   u'labor',
#   u'market',
#   u'indicator',
#   u'inflation',
#   u'mandate-consistent',
#   u'level',
#   u'pace',
#   u'asset',
#   u'purchase',
#   u'step',
#   u'meeting'],
#  [u'asset',
#   u'purchase',
#   u'course',
#   u'decision',
#   u'contingent',
#   u'outlook',
#   u'labor',
#   u'market',
#   u'inflation',
#   u'assessment',
#   u'efficacy',
#   u'cost',
#   u'purchase'],
#  [u'member',
#   u'assessment',
#   u'progress',
#   u'objective',
#   u'employment',
#   u'percent',
#   u'inflation',
#   u'enhancement',
#   u'statement',
#   u'language',
#   u'view',
#   u'progress'],
#  [u'labor',
#   u'market',
#   u'member',
#   u'range',
#   u'indicator',
#   u'labor',
#   u'market',
#   u'condition',
#   u'unemployment',
#   u'rate',
#   u'number',
#   u'measure',
#   u'labor',
#   u'utilization',
#   u'month'],
#  [u'description',
#   u'labor',
#   u'market',
#   u'condition',
#   u'unemployment',
#   u'rate',
#   u'description',
#   u'assessment',
#   u'underutilization',
#   u'labor',
#   u'resource',
#   u'evaluation',
#   u'range',
#   u'labor',
#   u'market',
#   u'indicator'],
#  [u'discussion',
#   u'member',
#   u'reservation',
#   u'extent',
#   u'underutilization',
#   u'labor',
#   u'resource'],
#  [u'degree',
#   u'labor',
#   u'market',
#   u'slack',
#   u'statement',
#   u'language',
#   u'labor',
#   u'market',
#   u'condition'],
#  [u'improvement',
#   u'labor',
#   u'market',
#   u'condition',
#   u'language',
#   u'concern',
#   u'underutilization',
#   u'labor',
#   u'resource'],
#  [u'conclusion',
#   u'discussion',
#   u'state',
#   u'labor',
#   u'market',
#   u'condition',
#   u'unemployment',
#   u'rate',
#   u'range',
#   u'labor',
#   u'market',
#   u'indicator',
#   u'underutilization',
#   u'labor',
#   u'resource'],
#  [u'member',
#   u'characterization',
#   u'labor',
#   u'market',
#   u'underutilization',
#   u'progress',
#   u'labor',
#   u'market'],
#  [u'inflation',
#   u'member',
#   u'language',
#   u'statement',
#   u'inflation',
#   u'objective',
#   u'judgment',
#   u'likelihood',
#   u'inflation',
#   u'percent'],
#  [u'discussion',
#   u'member',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'guidance',
#   u'timing',
#   u'increase',
#   u'target',
#   u'rate',
#   u'behavior',
#   u'fund',
#   u'rate'],
#  [u'member',
#   u'guidance',
#   u'range',
#   u'fund',
#   u'rate',
#   u'time',
#   u'asset',
#   u'purchase',
#   u'program',
#   u'end',
#   u'time',
#   u'implication',
#   u'policy',
#   u'progress',
#   u'goal'],
#  [u'conclusion',
#   u'discussion',
#   u'transaction',
#   u'accordance',
#   u'policy',
#   u'directive'],
#  [u'mandate', u'condition', u'employment', u'price', u'stability'],
#  [u'condition',
#   u'reserve',
#   u'market',
#   u'fund',
#   u'trading',
#   u'range',
#   u'percent'],
#  [u'market', u'operation', u'condition'],
#  [u'security', u'pace', u'month', u'agency', u'security', u'pace', u'month'],
#  [u'dollar',
#   u'roll',
#   u'coupon',
#   u'swap',
#   u'transaction',
#   u'settlement',
#   u'agency',
#   u'security',
#   u'transaction'],
#  [u'policy',
#   u'security',
#   u'issue',
#   u'policy',
#   u'payment',
#   u'agency',
#   u'debt',
#   u'agency',
#   u'security',
#   u'agency',
#   u'security'],
#  [u'manager',
#   u'secretary',
#   u'development',
#   u'balance',
#   u'sheet',
#   u'attainment',
#   u'time',
#   u'objective',
#   u'employment',
#   u'price',
#   u'stability'],
#  [u'information', u'growth', u'activity', u'quarter'],
#  [u'range',
#   u'labor',
#   u'market',
#   u'indicator',
#   u'underutilization',
#   u'labor',
#   u'resource'],
#  [u'spending', u'business', u'investment', u'recovery', u'housing', u'sector'],
#  [u'policy', u'growth', u'extent', u'restraint'],
#  [u'inflation', u'objective'],
#  [u'inflation', u'expectation', u'stable'],
#  [u'mandate', u'employment', u'price', u'stability'],
#  [u'policy',
#   u'accommodation',
#   u'activity',
#   u'pace',
#   u'labor',
#   u'market',
#   u'indicator',
#   u'inflation',
#   u'level',
#   u'judge',
#   u'mandate'],
#  [u'risk',
#   u'outlook',
#   u'activity',
#   u'labor',
#   u'market',
#   u'judge',
#   u'likelihood',
#   u'inflation',
#   u'percent'],
#  [u'judge',
#   u'strength',
#   u'economy',
#   u'improvement',
#   u'labor',
#   u'market',
#   u'condition'],
#  [u'light',
#   u'progress',
#   u'employment',
#   u'improvement',
#   u'outlook',
#   u'labor',
#   u'market',
#   u'condition',
#   u'inception',
#   u'asset',
#   u'purchase',
#   u'program',
#   u'reduction',
#   u'pace',
#   u'asset',
#   u'purchase'],
#  [u'holding',
#   u'agency',
#   u'security',
#   u'pace',
#   u'month',
#   u'month',
#   u'holding',
#   u'security',
#   u'pace',
#   u'month',
#   u'month'],
#  [u'existing',
#   u'policy',
#   u'payment',
#   u'holding',
#   u'agency',
#   u'debt',
#   u'agency',
#   u'security',
#   u'agency',
#   u'security',
#   u'security',
#   u'auction'],
#  [u'still-increasing',
#   u'holding',
#   u'security',
#   u'pressure',
#   u'rate',
#   u'support',
#   u'mortgage',
#   u'market',
#   u'condition',
#   u'turn',
#   u'recovery',
#   u'inflation',
#   u'time',
#   u'rate',
#   u'mandate'],
#  [u'information',
#   u'development',
#   u'month',
#   u'purchase',
#   u'agency',
#   u'security',
#   u'policy',
#   u'tool',
#   u'outlook',
#   u'labor',
#   u'market',
#   u'context',
#   u'price',
#   u'stability'],
#  [u'information',
#   u'expectation',
#   u'improvement',
#   u'labor',
#   u'market',
#   u'condition',
#   u'inflation',
#   u'objective',
#   u'pace',
#   u'asset',
#   u'purchase',
#   u'step',
#   u'meeting'],
#  [u'asset',
#   u'purchase',
#   u'course',
#   u'decision',
#   u'pace',
#   u'contingent',
#   u'outlook',
#   u'labor',
#   u'market',
#   u'inflation',
#   u'assessment',
#   u'efficacy',
#   u'cost',
#   u'purchase'],
#  [u'progress',
#   u'employment',
#   u'price',
#   u'stability',
#   u'today',
#   u'view',
#   u'stance',
#   u'policy'],
#  [u'percent',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'progress',
#   u'objective',
#   u'employment',
#   u'percent',
#   u'inflation'],
#  [u'assessment',
#   u'account',
#   u'range',
#   u'information',
#   u'measure',
#   u'labor',
#   u'market',
#   u'condition',
#   u'indicator',
#   u'inflation',
#   u'pressure',
#   u'inflation',
#   u'expectation',
#   u'reading',
#   u'development'],
#  [u'assessment',
#   u'factor',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'time',
#   u'asset',
#   u'purchase',
#   u'program',
#   u'end',
#   u'inflation',
#   u'percent',
#   u'goal',
#   u'inflation',
#   u'expectation'],
#  [u'policy',
#   u'accommodation',
#   u'approach',
#   u'goal',
#   u'employment',
#   u'inflation',
#   u'percent'],
#  [u'employment',
#   u'inflation',
#   u'level',
#   u'condition',
#   u'time',
#   u'target',
#   u'fund',
#   u'rate',
#   u'level',
#   u'view'],
#  [u'statement',
#   u'guidance',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'time',
#   u'asset',
#   u'purchase',
#   u'program'],
#  [u'view',
#   u'reference',
#   u'calendar',
#   u'time',
#   u'language',
#   u'policy',
#   u'datum'],
#  [u'statement',
#   u'progress',
#   u'goal',
#   u'risk',
#   u'volatility',
#   u'market',
#   u'economy',
#   u'accommodation',
#   u'market'],
#  [u'session'],
#  [u'portion', u'meeting', u'session'],
#  [u'staff',
#   u'forecast',
#   u'meeting',
#   u'release',
#   u'advance',
#   u'estimate',
#   u'quarter',
#   u'revision',
#   u'period'],
#  [u'member'],
#  [u'governor'],
#  [u'governor'],
#  [u'governor'],
#  [u'session',
#   u'governor',
#   u'meeting',
#   u'participant',
#   u'issue',
#   u'normalization',
#   u'stance',
#   u'policy'],
#  [u'discussion', u'topic', u'planning', u'normalization'],
#  [u'staff',
#   u'presentation',
#   u'approach',
#   u'rate',
#   u'level',
#   u'rate',
#   u'period',
#   u'balance',
#   u'sheet'],
#  [u'addition',
#   u'rate',
#   u'reserve',
#   u'balance',
#   u'tool',
#   u'operation',
#   u'term',
#   u'reverse',
#   u'repurchase',
#   u'agreement'],
#  [u'staff',
#   u'presentation',
#   u'implication',
#   u'approach',
#   u'intermediation',
#   u'market',
#   u'fund',
#   u'market',
#   u'implication',
#   u'stability'],
#  [u'addition', u'staff', u'option', u'testing', u'policy', u'tool'],
#  [u'staff',
#   u'presentation',
#   u'meeting',
#   u'participant',
#   u'range',
#   u'topic',
#   u'policy',
#   u'normalization'],
#  [u'participant',
#   u'option',
#   u'normalization',
#   u'meeting',
#   u'decision',
#   u'approach',
#   u'policy',
#   u'normalization',
#   u'plan',
#   u'public',
#   u'step',
#   u'policy'],
#  [u'communication',
#   u'turn',
#   u'clarity',
#   u'credibility',
#   u'policy',
#   u'help',
#   u'achievement',
#   u'objective'],
#  [u'tool', u'policy', u'accommodation'],
#  [u'participant',
#   u'combination',
#   u'tool',
#   u'implication',
#   u'degree',
#   u'control',
#   u'rate',
#   u'balance',
#   u'sheet',
#   u'remittance',
#   u'functioning',
#   u'fund',
#   u'market',
#   u'stability',
#   u'time',
#   u'period',
#   u'stress'],
#  [u'stance',
#   u'policy',
#   u'balance',
#   u'sheet',
#   u'participant',
#   u'range',
#   u'option',
#   u'mix',
#   u'policy',
#   u'tool'],
#  [u'participant', u'testing', u'tool', u'readiness', u'effectiveness'],
#  [u'decision',
#   u'policy',
#   u'normalization',
#   u'participant',
#   u'analysis',
#   u'staff',
#   u'issue',
#   u'meeting'],
#  [u'development',
#   u'manager',
#   u'development',
#   u'market',
#   u'market',
#   u'operation',
#   u'period'],
#  [u'vote', u'transaction', u'period'],
#  [u'intervention', u'operation', u'currency', u'account', u'period'],
#  [u'vote', u'currency', u'arrangement', u'arrangement', u'participation'],
#  [u'addition',
#   u'vote',
#   u'dollar',
#   u'currency',
#   u'liquidity',
#   u'swap',
#   u'arrangement'],
#  [u'information',
#   u'meeting',
#   u'growth',
#   u'activity',
#   u'quarter',
#   u'activity',
#   u'quarter',
#   u'pattern',
#   u'effect',
#   u'weather',
#   u'quarter',
#   u'unwinding',
#   u'effect',
#   u'quarter'],
#  [u'payroll', u'employment', u'unemployment', u'rate'],
#  [u'price',
#   u'inflation',
#   u'objective',
#   u'measure',
#   u'inflation',
#   u'expectation',
#   u'stable'],
#  [u'rate',
#   u'unemployment',
#   u'share',
#   u'worker',
#   u'time',
#   u'reason',
#   u'measure',
#   u'pre-recession',
#   u'level'],
#  [u'claim', u'unemployment', u'insurance', u'period'],
#  [u'rate', u'job', u'opening', u'rate'],
#  [u'rebound',
#   u'production',
#   u'rate',
#   u'manufacturing',
#   u'capacity',
#   u'utilization'],
#  [u'automaker',
#   u'schedule',
#   u'pace',
#   u'motor',
#   u'vehicle',
#   u'assembly',
#   u'month',
#   u'level'],
#  [u'indicator',
#   u'manufacturing',
#   u'production',
#   u'order',
#   u'index',
#   u'manufacturing',
#   u'survey',
#   u'level',
#   u'increase',
#   u'factory',
#   u'output',
#   u'term'],
#  [u'consumption', u'expenditure', u'quarter', u'quarter'],
#  [u'net', u'component', u'sale', u'estimate', u'weather', u'norm'],
#  [u'information', u'factor', u'influence', u'household', u'spending'],
#  [u'income',
#   u'quarter',
#   u'gain',
#   u'house',
#   u'price',
#   u'household',
#   u'net',
#   u'consumer',
#   u'sentiment',
#   u'survey',
#   u'consumer',
#   u'balance'],
#  [u'pace',
#   u'activity',
#   u'housing',
#   u'sector',
#   u'expenditure',
#   u'investment',
#   u'quarter'],
#  [u'home'],
#  [u'permit',
#   u'home',
#   u'fluctuation',
#   u'weather',
#   u'indicator',
#   u'pace',
#   u'construction',
#   u'level',
#   u'improvement',
#   u'spring',
#   u'mortgage',
#   u'rate'],
#  [u'sale', u'home', u'year', u'home', u'sale'],
#  [u'expenditure',
#   u'business',
#   u'equipment',
#   u'property',
#   u'product',
#   u'quarter'],
#  [u'shipment',
#   u'capital',
#   u'good',
#   u'aircraft',
#   u'order',
#   u'level',
#   u'shipment',
#   u'gain',
#   u'shipment',
#   u'term'],
#  [u'indicator',
#   u'survey',
#   u'business',
#   u'condition',
#   u'capital',
#   u'spending',
#   u'plan',
#   u'outlay',
#   u'business',
#   u'equipment',
#   u'month'],
#  [u'spending',
#   u'construction',
#   u'quarter',
#   u'quarter',
#   u'inventory',
#   u'investment'],
#  [u'inventory', u'industry', u'sale', u'month'],
#  [u'government',
#   u'purchase',
#   u'quarter',
#   u'increase',
#   u'reversal',
#   u'government',
#   u'shutdown',
#   u'quarter',
#   u'downtrend',
#   u'purchase'],
#  [u'state',
#   u'government',
#   u'purchase',
#   u'quarter',
#   u'state',
#   u'construction',
#   u'expenditure'],
#  [u'trade', u'deficit', u'export', u'import'],
#  [u'import',
#   u'service',
#   u'product',
#   u'decline',
#   u'import',
#   u'oil',
#   u'capital',
#   u'good'],
#  [u'advance',
#   u'release',
#   u'income',
#   u'product',
#   u'account',
#   u'export',
#   u'product',
#   u'growth',
#   u'quarter'],
#  [u'consumer',
#   u'price',
#   u'price',
#   u'index',
#   u'rate',
#   u'quarter',
#   u'pace',
#   u'quarter',
#   u'percent',
#   u'year'],
#  [u'quarter',
#   u'consumer',
#   u'energy',
#   u'price',
#   u'quarter',
#   u'gas',
#   u'price',
#   u'decline',
#   u'inventory',
#   u'winter',
#   u'month'],
#  [u'price',
#   u'index',
#   u'item',
#   u'food',
#   u'energy',
#   u'rate',
#   u'quarter',
#   u'percent',
#   u'quarters'],
#  [u'inflation', u'expectation', u'survey'],
#  [u'month',
#   u'employment',
#   u'cost',
#   u'index',
#   u'worker',
#   u'earning',
#   u'employee',
#   u'consumer',
#   u'price',
#   u'inflation'],
#  [u'activity', u'expansion', u'quarter', u'rate', u'quarter'],
#  [u'growth', u'investment', u'growth', u'export'],
#  [u'export', u'activity', u'economy'],
#  [u'indicator', u'activity', u'improvement', u'quarter'],
#  [u'contrast', u'growth', u'fourth-quarter', u'pace', u'economy'],
#  [u'area',
#   u'production',
#   u'month',
#   u'year',
#   u'quarter',
#   u'production',
#   u'consumer',
#   u'demand',
#   u'anticipation',
#   u'increase',
#   u'consumption',
#   u'tax'],
#  [u'inflation', u'development'],
#  [u'inflation', u'area'],
#  [u'inflation', u'quarter', u'food', u'price'],
#  [u'policy', u'period', u'policy', u'inflation', u'pressure'],
#  [u'volatility', u'asset', u'price', u'condition', u'net', u'period'],
#  [u'price', u'response', u'data', u'balance', u'communication'],
#  [u'path', u'fund', u'rate', u'yield', u'bond', u'spread'],
#  [u'exchange', u'value', u'dollar'],
#  [u'communication',
#   u'attention',
#   u'market',
#   u'participant',
#   u'period',
#   u'net',
#   u'effect',
#   u'expectation',
#   u'policy'],
#  [u'communication', u'conclusion', u'meeting'],
#  [u'communication',
#   u'release',
#   u'minute',
#   u'meeting',
#   u'change',
#   u'expectation'],
#  [u'yield', u'security', u'balance', u'period'],
#  [u'contrast', u'yield', u'end', u'curve', u'trend', u'year'],
#  [u'market',
#   u'participant',
#   u'number',
#   u'factor',
#   u'drop',
#   u'yield',
#   u'year',
#   u'portfolio',
#   u'reallocation',
#   u'investor',
#   u'trading',
#   u'strategy',
#   u'investor',
#   u'flow'],
#  [u'market',
#   u'participant',
#   u'estimate',
#   u'fund',
#   u'rate',
#   u'term',
#   u'change',
#   u'assessment',
#   u'condition'],
#  [u'measure', u'inflation', u'compensation'],
#  [u'condition', u'market', u'period'],
#  [u'exercise',
#   u'spread',
#   u'market',
#   u'rate',
#   u'rate',
#   u'exercise',
#   u'day',
#   u'market',
#   u'rate',
#   u'repurchase',
#   u'agreement',
#   u'rate'],
#  [u'case',
#   u'exercise',
#   u'money',
#   u'market',
#   u'fund',
#   u'usage',
#   u'quarter-end',
#   u'level',
#   u'end'],
#  [u'increase',
#   u'usage',
#   u'end',
#   u'end',
#   u'counterparty',
#   u'allotment',
#   u'limit',
#   u'quarter'],
#  [u'allotment', u'limit', u'counterparty'],
#  [u'paydown',
#   u'debt',
#   u'tax',
#   u'date',
#   u'pickup',
#   u'participation',
#   u'operation',
#   u'repo',
#   u'rate',
#   u'rate',
#   u'basis',
#   u'point'],
#  [u'bit', u'net', u'period', u'stock', u'market', u'index'],
#  [u'price',
#   u'medium',
#   u'biotechnology',
#   u'stock',
#   u'market',
#   u'year',
#   u'period',
#   u'gain',
#   u'share',
#   u'line',
#   u'index',
#   u'month'],
#  [u'public', u'offering', u'hold', u'price', u'stock'],
#  [u'contrast',
#   u'stock',
#   u'dividend',
#   u'utility',
#   u'telecommunications',
#   u'company'],
#  [u'earning',
#   u'report',
#   u'banking',
#   u'organization',
#   u'stock',
#   u'price',
#   u'firm',
#   u'equity',
#   u'index'],
#  [u'corporation',
#   u'balance',
#   u'notwithstanding',
#   u'bond',
#   u'issuance',
#   u'constraint',
#   u'issuance',
#   u'period',
#   u'firm',
#   u'earning'],
#  [u'growth',
#   u'loan',
#   u'bank',
#   u'balance',
#   u'sheet',
#   u'increase',
#   u'loan',
#   u'demand',
#   u'firm',
#   u'lending',
#   u'practice'],
#  [u'issuance',
#   u'loan',
#   u'pace',
#   u'report',
#   u'easing',
#   u'credit',
#   u'term',
#   u'deal',
#   u'structure'],
#  [u'financing', u'condition', u'estate', u'sector'],
#  [u'quarter', u'mortgage', u'loan', u'bank', u'book'],
#  [u'bank',
#   u'standard',
#   u'loan',
#   u'quarter',
#   u'increase',
#   u'loan',
#   u'demand',
#   u'construction',
#   u'land',
#   u'development',
#   u'loan'],
#  [u'contrast', u'issuance', u'security', u'bit', u'year', u'pace'],
#  [u'credit',
#   u'condition',
#   u'period',
#   u'sign',
#   u'easing',
#   u'gain',
#   u'house',
#   u'price'],
#  [u'net',
#   u'bank',
#   u'credit',
#   u'standard',
#   u'home-purchase',
#   u'loan',
#   u'customer',
#   u'quarter'],
#  [u'rate',
#   u'spread',
#   u'yield',
#   u'period',
#   u'application',
#   u'refinancing',
#   u'purchase',
#   u'mortgage'],
#  [u'student',
#   u'auto',
#   u'loan',
#   u'pace',
#   u'credit',
#   u'card',
#   u'debt',
#   u'month'],
#  [u'financing',
#   u'condition',
#   u'consumer',
#   u'security',
#   u'market',
#   u'issuance'],
#  [u'equity',
#   u'index',
#   u'period',
#   u'selloff',
#   u'stock',
#   u'bond',
#   u'yield',
#   u'net'],
#  [u'yield', u'spread', u'debt', u'bond', u'maturity'],
#  [u'exchange',
#   u'rate',
#   u'index',
#   u'dollar',
#   u'dollar',
#   u'euro',
#   u'yen',
#   u'renminbi',
#   u'currency'],
#  [u'investor', u'sentiment', u'period', u'datum'],
#  [u'tension',
#   u'debt',
#   u'rating',
#   u'rise',
#   u'bond',
#   u'yield',
#   u'decline',
#   u'equity',
#   u'index'],
#  [u'region', u'building', u'tension', u'market'],
#  [u'staff',
#   u'report',
#   u'risk',
#   u'stability',
#   u'vulnerability',
#   u'shock',
#   u'level'],
#  [u'capital',
#   u'profile',
#   u'banking',
#   u'firm',
#   u'level',
#   u'leverage',
#   u'sector',
#   u'use',
#   u'funding',
#   u'sector',
#   u'factor',
#   u'stability'],
#  [u'staff',
#   u'report',
#   u'valuation',
#   u'pressure',
#   u'segment',
#   u'equity',
#   u'market',
#   u'demand',
#   u'debt',
#   u'instrument',
#   u'pressure',
#   u'underwriting',
#   u'standard',
#   u'liquidity',
#   u'risk',
#   u'fund'],
#  [u'outlook',
#   u'forecast',
#   u'staff',
#   u'meeting',
#   u'growth',
#   u'half',
#   u'year',
#   u'projection',
#   u'meeting'],
#  [u'reading',
#   u'net',
#   u'export',
#   u'extent',
#   u'investment',
#   u'spending',
#   u'growth',
#   u'quarter',
#   u'staff'],
#  [u'staff',
#   u'assessment',
#   u'weakness',
#   u'activity',
#   u'quarter',
#   u'revision',
#   u'projection',
#   u'second-quarter',
#   u'output',
#   u'growth'],
#  [u'addition', u'forecast', u'growth'],
#  [u'staff',
#   u'project',
#   u'pace',
#   u'year',
#   u'year',
#   u'growth',
#   u'rate',
#   u'output'],
#  [u'pace',
#   u'growth',
#   u'easing',
#   u'restraint',
#   u'change',
#   u'policy',
#   u'increase',
#   u'consumer',
#   u'business',
#   u'confidence',
#   u'improvement',
#   u'credit',
#   u'availability',
#   u'condition',
#   u'pickup',
#   u'rate',
#   u'growth'],
#  [u'expansion',
#   u'activity',
#   u'resource',
#   u'slack',
#   u'projection',
#   u'period',
#   u'unemployment',
#   u'rate',
#   u'staff',
#   u'estimate',
#   u'rate'],
#  [u'staff', u'forecast', u'inflation', u'projection', u'meeting'],
#  [u'staff', u'inflation', u'objective', u'percent', u'year'],
#  [u'inflation',
#   u'expectation',
#   u'change',
#   u'commodity',
#   u'import',
#   u'price',
#   u'slack',
#   u'labor',
#   u'product',
#   u'market',
#   u'inflation',
#   u'objective'],
#  [u'staff',
#   u'extent',
#   u'uncertainty',
#   u'projection',
#   u'growth',
#   u'inflation',
#   u'unemployment',
#   u'rate',
#   u'line',
#   u'year'],
#  [u'risk',
#   u'forecast',
#   u'growth',
#   u'downside',
#   u'economy',
#   u'shock',
#   u'target',
#   u'fund',
#   u'rate'],
#  [u'participant',
#   u'view',
#   u'condition',
#   u'outlook',
#   u'discussion',
#   u'situation',
#   u'outlook',
#   u'meeting',
#   u'participant',
#   u'assessment',
#   u'outlook',
#   u'meeting'],
#  [u'winter',
#   u'weather',
#   u'slowing',
#   u'activity',
#   u'quarter',
#   u'indicator',
#   u'rebound',
#   u'economy',
#   u'trajectory',
#   u'growth'],
#  [u'participant', u'bounceback', u'activity', u'economy', u'path', u'growth'],
#  [u'participant', u'risk', u'outlook', u'economy', u'labor', u'market'],
#  [u'number',
#   u'participant',
#   u'source',
#   u'risk',
#   u'growth',
#   u'slowdown',
#   u'housing',
#   u'sector',
#   u'development',
#   u'slowing',
#   u'growth',
#   u'increase',
#   u'tension'],
#  [u'participant',
#   u'business',
#   u'contact',
#   u'country',
#   u'prospect',
#   u'report',
#   u'sale',
#   u'automobile',
#   u'production',
#   u'industry',
#   u'usage',
#   u'power',
#   u'addition',
#   u'couple',
#   u'firm',
#   u'presence',
#   u'increase',
#   u'demand',
#   u'customer'],
#  [u'district',
#   u'plan',
#   u'capital',
#   u'expenditure',
#   u'demand',
#   u'commercial',
#   u'loan'],
#  [u'sector',
#   u'planting',
#   u'season',
#   u'way',
#   u'concern',
#   u'effect',
#   u'drought',
#   u'production',
#   u'area'],
#  [u'range',
#   u'factor',
#   u'housing',
#   u'market',
#   u'home',
#   u'price',
#   u'construction',
#   u'bottleneck',
#   u'scarcity',
#   u'labor',
#   u'winter',
#   u'weather',
#   u'input',
#   u'cost',
#   u'pressure',
#   u'shortage',
#   u'supply',
#   u'lot'],
#  [u'view',
#   u'outlook',
#   u'sector',
#   u'increase',
#   u'unit',
#   u'market',
#   u'pressure',
#   u'price',
#   u'rent',
#   u'demand',
#   u'type',
#   u'housing',
#   u'population',
#   u'age'],
#  [u'couple',
#   u'participant',
#   u'mortgage',
#   u'credit',
#   u'availability',
#   u'lending',
#   u'standard',
#   u'norm',
#   u'purchase',
#   u'mortgage'],
#  [u'report',
#   u'district',
#   u'estate',
#   u'business',
#   u'activity',
#   u'gain',
#   u'consumer',
#   u'spending'],
#  [u'condition',
#   u'labor',
#   u'market',
#   u'period',
#   u'participant',
#   u'improvement'],
#  [u'participant',
#   u'range',
#   u'research',
#   u'analysis',
#   u'slack',
#   u'remaining',
#   u'labor',
#   u'market'],
#  [u'number',
#   u'indicator',
#   u'labor',
#   u'underutilization',
#   u'labor',
#   u'force',
#   u'participation',
#   u'rate',
#   u'rate',
#   u'unemployment',
#   u'worker',
#   u'time',
#   u'reason',
#   u'labor',
#   u'market',
#   u'unemployment',
#   u'rate'],
#  [u'wage', u'inflation', u'slack', u'labor', u'market'],
#  [u'participant',
#   u'labor',
#   u'underutilization',
#   u'index',
#   u'employment',
#   u'transition',
#   u'rate',
#   u'account',
#   u'period',
#   u'unemployment',
#   u'rate',
#   u'level',
#   u'unemployment',
#   u'rate',
#   u'recovery'],
#  [u'effect',
#   u'labor',
#   u'market',
#   u'condition',
#   u'inflation',
#   u'number',
#   u'participant',
#   u'skepticism',
#   u'study',
#   u'unemployment',
#   u'pressure',
#   u'wage',
#   u'price',
#   u'inflation',
#   u'unemployment'],
#  [u'couple',
#   u'participant',
#   u'research',
#   u'finding',
#   u'unemployment',
#   u'rate',
#   u'pressure',
#   u'wage',
#   u'effect',
#   u'unemployment',
#   u'level',
#   u'unemployment'],
#  [u'participant',
#   u'wage',
#   u'rigidity',
#   u'recession',
#   u'wage',
#   u'increase',
#   u'time',
#   u'recovery',
#   u'labor',
#   u'market'],
#  [u'inflation',
#   u'percent',
#   u'objective',
#   u'unemployment',
#   u'rate',
#   u'participant',
#   u'estimate',
#   u'level',
#   u'present',
#   u'tradeoff',
#   u'employment',
#   u'inflation',
#   u'objective',
#   u'expansion',
#   u'demand',
#   u'progress',
#   u'objective'],
#  [u'inflation', u'percent', u'objective', u'period'],
#  [u'participant',
#   u'behavior',
#   u'price',
#   u'food',
#   u'energy',
#   u'shelter',
#   u'import',
#   u'stabilization',
#   u'inflation',
#   u'factor',
#   u'inflation',
#   u'decline',
#   u'price',
#   u'service'],
#  [u'participant',
#   u'inflation',
#   u'percent',
#   u'year',
#   u'policy',
#   u'inflation',
#   u'expectation',
#   u'recovery',
#   u'activity'],
#  [u'concern', u'return', u'percent', u'inflation'],
#  [u'discussion',
#   u'stability',
#   u'participant',
#   u'imbalance',
#   u'risk',
#   u'economy',
#   u'development',
#   u'future',
#   u'risk'],
#  [u'couple',
#   u'participant',
#   u'condition',
#   u'loan',
#   u'market',
#   u'equity',
#   u'cushion',
#   u'deal',
#   u'level',
#   u'crisis'],
#  [u'credit',
#   u'spread',
#   u'bond',
#   u'increase',
#   u'investor',
#   u'appetite',
#   u'risk'],
#  [u'addition',
#   u'participant',
#   u'level',
#   u'volatility',
#   u'market',
#   u'price',
#   u'increase',
#   u'risk',
#   u'appetite'],
#  [u'policy', u'response', u'risk', u'stability'],
#  [u'change', u'guidance', u'meeting', u'investor'],
#  [u'number',
#   u'participant',
#   u'importance',
#   u'policy',
#   u'intention',
#   u'time',
#   u'increase',
#   u'fund',
#   u'rate'],
#  [u'thought',
#   u'reasoning',
#   u'language',
#   u'postmeeting',
#   u'statement',
#   u'employment',
#   u'inflation',
#   u'level',
#   u'condition',
#   u'time',
#   u'target',
#   u'fund',
#   u'rate',
#   u'level',
#   u'view'],
#  [u'addition',
#   u'participant',
#   u'clarity',
#   u'reaction',
#   u'function',
#   u'event',
#   u'condition',
#   u'rise',
#   u'target',
#   u'fund',
#   u'rate'],
#  [u'number',
#   u'participant',
#   u'information',
#   u'policy',
#   u'security',
#   u'auction',
#   u'payment',
#   u'agency',
#   u'debt',
#   u'agency',
#   u'security',
#   u'agency',
#   u'security'],
#  [u'information',
#   u'period',
#   u'growth',
#   u'slowdown',
#   u'winter',
#   u'weather',
#   u'condition'],
#  [u'labor', u'market', u'indicator', u'improvement'],
#  [u'unemployment', u'rate'],
#  [u'policy', u'growth', u'extent', u'restraint'],
#  [u'policy',
#   u'accommodation',
#   u'activity',
#   u'pace',
#   u'labor',
#   u'market',
#   u'condition',
#   u'judge',
#   u'mandate'],
#  [u'inflation',
#   u'objective',
#   u'risk',
#   u'performance',
#   u'member',
#   u'inflation',
#   u'expectation',
#   u'activity',
#   u'time',
#   u'return',
#   u'inflation',
#   u'percent',
#   u'target'],
#  [u'light',
#   u'concern',
#   u'persistence',
#   u'inflation',
#   u'member',
#   u'inflation',
#   u'development',
#   u'evidence',
#   u'inflation',
#   u'objective'],
#  [u'discussion',
#   u'policy',
#   u'period',
#   u'member',
#   u'change',
#   u'outlook',
#   u'meeting',
#   u'reduction',
#   u'pace',
#   u'asset',
#   u'purchase',
#   u'meeting'],
#  [u'holding',
#   u'agency',
#   u'security',
#   u'pace',
#   u'month',
#   u'month',
#   u'holding',
#   u'security',
#   u'pace',
#   u'month',
#   u'month'],
#  [u'member', u'economy', u'pace', u'asset', u'purchase', u'step', u'meeting'],
#  [u'member',
#   u'pace',
#   u'asset',
#   u'purchase',
#   u'course',
#   u'contingent',
#   u'outlook',
#   u'labor',
#   u'market',
#   u'inflation',
#   u'assessment',
#   u'efficacy',
#   u'cost',
#   u'purchase'],
#  [u'change',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'guidance',
#   u'meeting',
#   u'paragraph',
#   u'guidance',
#   u'meeting',
#   u'change',
#   u'guidance',
#   u'change',
#   u'policy',
#   u'intention',
#   u'member',
#   u'language'],
#  [u'conclusion',
#   u'discussion',
#   u'transaction',
#   u'accordance',
#   u'policy',
#   u'directive'],
#  [u'mandate', u'condition', u'employment', u'price', u'stability'],
#  [u'condition',
#   u'reserve',
#   u'market',
#   u'fund',
#   u'trading',
#   u'range',
#   u'percent'],
#  [u'market', u'operation', u'condition'],
#  [u'security', u'pace', u'month', u'agency', u'security', u'pace', u'month'],
#  [u'dollar',
#   u'roll',
#   u'coupon',
#   u'swap',
#   u'transaction',
#   u'settlement',
#   u'agency',
#   u'security',
#   u'transaction'],
#  [u'policy',
#   u'security',
#   u'issue',
#   u'policy',
#   u'payment',
#   u'agency',
#   u'debt',
#   u'agency',
#   u'security',
#   u'agency',
#   u'security'],
#  [u'development',
#   u'balance',
#   u'sheet',
#   u'attainment',
#   u'time',
#   u'objective',
#   u'employment',
#   u'price',
#   u'stability'],
#  [u'information', u'growth', u'activity', u'winter', u'weather', u'condition'],
#  [u'labor', u'market', u'indicator', u'balance', u'improvement'],
#  [u'unemployment', u'rate'],
#  [u'policy', u'growth', u'extent', u'restraint'],
#  [u'inflation', u'objective', u'inflation', u'expectation', u'stable'],
#  [u'mandate', u'employment', u'price', u'stability'],
#  [u'policy',
#   u'accommodation',
#   u'activity',
#   u'pace',
#   u'labor',
#   u'market',
#   u'condition',
#   u'judge',
#   u'mandate'],
#  [u'inflation',
#   u'percent',
#   u'objective',
#   u'risk',
#   u'performance',
#   u'inflation',
#   u'development',
#   u'evidence',
#   u'inflation',
#   u'objective',
#   u'medium',
#   u'term'],
#  [u'judge',
#   u'strength',
#   u'economy',
#   u'improvement',
#   u'labor',
#   u'market',
#   u'condition'],
#  [u'light',
#   u'progress',
#   u'employment',
#   u'improvement',
#   u'outlook',
#   u'labor',
#   u'market',
#   u'condition',
#   u'inception',
#   u'asset',
#   u'purchase',
#   u'program',
#   u'reduction',
#   u'pace',
#   u'asset',
#   u'purchase'],
#  [u'holding',
#   u'agency',
#   u'security',
#   u'pace',
# ...
#   u'risk',
#   u'outlook',
#   u'agreement',
#   u'plan',
#   u'budget',
#   u'tightening',
#   u'start'],
#  [u'participant',
#   u'uncertainty',
#   u'trajectory',
#   u'policy',
#   u'business',
#   u'hiring',
#   u'investment'],
#  [u'agreement',
#   u'plan',
#   u'country',
#   u'challenge',
#   u'uncertainty',
#   u'effect',
#   u'consumer',
#   u'business',
#   u'sentiment'],
#  [u'export',
#   u'growth',
#   u'year',
#   u'participant',
#   u'risk',
#   u'export',
#   u'picture',
#   u'weakness',
#   u'slowdown',
#   u'pace',
#   u'expansion'],
#  [u'labor',
#   u'market',
#   u'condition',
#   u'weather',
#   u'payroll',
#   u'job',
#   u'figure',
#   u'year'],
#  [u'country', u'worker', u'supply', u'wage', u'pressure'],
#  [u'decline',
#   u'labor',
#   u'force',
#   u'participation',
#   u'worker',
#   u'factor',
#   u'percentage',
#   u'point',
#   u'decline',
#   u'unemployment',
#   u'rate',
#   u'drop',
#   u'relationship',
#   u'growth',
#   u'change',
#   u'unemployment',
#   u'rate'],
#  [u'extent',
#   u'change',
#   u'labor',
#   u'force',
#   u'participation',
#   u'factor',
#   u'recovery',
#   u'change',
#   u'trend',
#   u'rate',
#   u'participation',
#   u'unemployment',
#   u'dynamic'],
#  [u'participant',
#   u'research',
#   u'half',
#   u'decline',
#   u'labor',
#   u'force',
#   u'participation',
#   u'factor',
#   u'participation',
#   u'unemployment',
#   u'quarters',
#   u'pace'],
#  [u'strength',
#   u'payroll',
#   u'job',
#   u'growth',
#   u'month',
#   u'reaction',
#   u'layoff',
#   u'job',
#   u'gain',
#   u'pace',
#   u'growth'],
#  [u'participant',
#   u'range',
#   u'view',
#   u'extent',
#   u'unemployment',
#   u'rate',
#   u'factor',
#   u'mismatch',
#   u'skill',
#   u'worker',
#   u'firm'],
#  [u'participant',
#   u'factor',
#   u'work',
#   u'view',
#   u'slack',
#   u'demand',
#   u'reason',
#   u'unemployment'],
#  [u'possibility',
#   u'level',
#   u'unemployment',
#   u'unemployment',
#   u'outcome',
#   u'aggregate',
#   u'demand'],
#  [u'participant',
#   u'measure',
#   u'labor',
#   u'market',
#   u'slack',
#   u'factor',
#   u'portion',
#   u'level',
#   u'unemployment'],
#  [u'result', u'measure', u'guide', u'economy', u'employment'],
#  [u'participant',
#   u'time',
#   u'estimate',
#   u'level',
#   u'output',
#   u'consequence',
#   u'estimate',
#   u'level',
#   u'slack'],
#  [u'participant',
#   u'rise',
#   u'inflation',
#   u'effect',
#   u'rise',
#   u'energy',
#   u'price',
#   u'view',
#   u'level',
#   u'slack'],
#  [u'participant', u'condition', u'credit', u'market', u'meeting'],
#  [u'credit',
#   u'quality',
#   u'consumer',
#   u'business',
#   u'loan',
#   u'demand',
#   u'estate',
#   u'lending'],
#  [u'equity',
#   u'price',
#   u'period',
#   u'period',
#   u'net',
#   u'bond',
#   u'yield',
#   u'level'],
#  [u'institution',
#   u'step',
#   u'resiliency',
#   u'capital',
#   u'level',
#   u'liquidity',
#   u'buffer',
#   u'exposure'],
#  [u'participant',
#   u'sign',
#   u'rate',
#   u'investor',
#   u'risk',
#   u'search',
#   u'return'],
#  [u'contrast',
#   u'condition',
#   u'credit',
#   u'market',
#   u'investor',
#   u'concern',
#   u'debt',
#   u'banking',
#   u'situation',
#   u'area',
#   u'period'],
#  [u'participant',
#   u'policy',
#   u'action',
#   u'ease',
#   u'stress',
#   u'market',
#   u'view',
#   u'solution',
#   u'banking',
#   u'problem',
#   u'area',
#   u'adjustment',
#   u'banking',
#   u'sector'],
#  [u'participant', u'market', u'situation'],
#  [u'week',
#   u'oil',
#   u'price',
#   u'reading',
#   u'oil',
#   u'future',
#   u'market',
#   u'commodity',
#   u'price'],
#  [u'inflation',
#   u'expectation',
#   u'unemployment',
#   u'rate',
#   u'participant',
#   u'effect',
#   u'rise',
#   u'oil',
#   u'gasoline',
#   u'price',
#   u'course',
#   u'inflation',
#   u'percent',
#   u'rate',
#   u'judge',
#   u'mandate'],
#  [u'participant', u'risk', u'inflation', u'outlook'],
#  [u'participant',
#   u'risk',
#   u'inflation',
#   u'pressure',
#   u'expansion',
#   u'fact',
#   u'inflation',
#   u'target',
#   u'model',
#   u'slack',
#   u'inflation',
#   u'difficulty',
#   u'slack',
#   u'time'],
#  [u'participant',
#   u'stance',
#   u'policy',
#   u'medium',
#   u'run',
#   u'stability',
#   u'inflation',
#   u'expectation',
#   u'inflation'],
#  [u'regard',
#   u'participant',
#   u'risk',
#   u'cost',
#   u'balance',
#   u'sheet',
#   u'action'],
#  [u'discussion',
#   u'outlook',
#   u'policy',
#   u'participant',
#   u'usefulness',
#   u'policy',
#   u'rule',
#   u'type',
#   u'reviews',
#   u'guide',
#   u'policy',
#   u'decisionmaking',
#   u'communication',
#   u'policy'],
#  [u'participant',
#   u'rule',
#   u'indication',
#   u'policy',
#   u'change',
#   u'condition',
#   u'relationship',
#   u'policy',
#   u'evolution',
#   u'outlook'],
#  [u'difference',
#   u'participant',
#   u'type',
#   u'rule',
#   u'example',
#   u'participant',
#   u'preference',
#   u'rule',
#   u'growth',
#   u'rate',
#   u'output',
#   u'gap',
#   u'measurement',
#   u'issue',
#   u'participant',
#   u'degree',
#   u'commonality',
#   u'participant',
#   u'approach'],
#  [u'participant'],
#  [u'thought',
#   u'prescription',
#   u'rule',
#   u'benchmark',
#   u'rule',
#   u'thought',
#   u'assumption'],
#  [u'participant',
#   u'value',
#   u'rate',
#   u'rule',
#   u'policy',
#   u'rate',
#   u'rate',
#   u'policy',
#   u'option',
#   u'rule',
#   u'factor'],
#  [u'usefulness',
#   u'policy',
#   u'rule',
#   u'environment',
#   u'environment',
#   u'policy',
#   u'rate',
#   u'asset',
#   u'purchase',
#   u'maturity',
#   u'extension',
#   u'program'],
#  [u'participant',
#   u'meeting',
#   u'merit',
#   u'drawback',
#   u'rule',
#   u'guide',
#   u'policy',
#   u'decisionmaking',
#   u'communication'],
#  [u'information',
#   u'activity',
#   u'period',
#   u'economy',
#   u'outlook',
#   u'time',
#   u'meeting'],
#  [u'labor',
#   u'market',
#   u'condition',
#   u'month',
#   u'unemployment',
#   u'rate',
#   u'member',
#   u'unemployment',
#   u'rate',
#   u'level',
#   u'mandate'],
#  [u'growth', u'quarters', u'time'],
#  [u'strain',
#   u'market',
#   u'debt',
#   u'banking',
#   u'situation',
#   u'risk',
#   u'activity'],
#  [u'possibility',
#   u'policy',
#   u'contractionary',
#   u'uncertainty',
#   u'policy',
#   u'hiring',
#   u'investment',
#   u'downside',
#   u'risk'],
#  [u'reading',
#   u'inflation',
#   u'percent',
#   u'target',
#   u'increase',
#   u'oil',
#   u'gasoline',
#   u'price',
#   u'year'],
#  [u'inflation',
#   u'expectation',
#   u'stable',
#   u'member',
#   u'increase',
#   u'inflation',
#   u'inflation',
#   u'rate',
#   u'judge',
#   u'mandate'],
#  [u'member', u'risk', u'inflation', u'degree', u'policy', u'year'],
#  [u'discussion',
#   u'policy',
#   u'period',
#   u'member',
#   u'judgment',
#   u'stance',
#   u'policy'],
#  [u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'percent',
#   u'program',
#   u'maturity',
#   u'holding',
#   u'security',
#   u'policy',
#   u'reinvestment',
#   u'payment',
#   u'holding',
#   u'security'],
#  [u'respect',
#   u'statement',
#   u'meeting',
#   u'member',
#   u'modification',
#   u'paragraph',
#   u'datum',
#   u'change',
#   u'outlook'],
#  [u'outlook',
#   u'medium',
#   u'term',
#   u'member',
#   u'stance',
#   u'policy',
#   u'condition',
#   u'rate',
#   u'resource',
#   u'utilization',
#   u'outlook',
#   u'inflation',
#   u'medium',
#   u'run',
#   u'level',
#   u'fund',
#   u'rate'],
#  [u'member',
#   u'unemployment',
#   u'rate',
#   u'estimate',
#   u'level',
#   u'inflation',
#   u'objective'],
#  [u'member',
#   u'policy',
#   u'judgment',
#   u'perception',
#   u'risk',
#   u'growth',
#   u'ability',
#   u'condition',
#   u'constraint',
#   u'policy',
#   u'policy',
#   u'rate'],
#  [u'need',
#   u'period',
#   u'policy',
#   u'rate',
#   u'bound',
#   u'member',
#   u'reason',
#   u'level',
#   u'fund',
#   u'rate',
#   u'period',
#   u'case'],
#  [u'member',
#   u'change',
#   u'outlook',
#   u'period',
#   u'adjustment',
#   u'guidance',
#   u'uncertainty',
#   u'forecast',
#   u'guidance',
#   u'development',
#   u'date',
#   u'statement',
#   u'revision',
#   u'change',
#   u'outlook'],
#  [u'member',
#   u'gain',
#   u'employment',
#   u'year',
#   u'effect',
#   u'winter',
#   u'weather',
#   u'trend',
#   u'datum'],
#  [u'factor',
#   u'case',
#   u'guidance',
#   u'meeting',
#   u'guidance',
#   u'outlook',
#   u'risk',
#   u'outlook'],
#  [u'contrast',
#   u'member',
#   u'guidance',
#   u'change',
#   u'development',
#   u'member',
#   u'threshold',
#   u'guidance'],
#  [u'size',
#   u'composition',
#   u'security',
#   u'holding',
#   u'holding',
#   u'recovery',
#   u'context',
#   u'price',
#   u'stability'],
#  [u'member',
#   u'policy',
#   u'accommodation',
#   u'recovery',
#   u'momentum',
#   u'risk',
#   u'forecast'],
#  [u'member',
#   u'desirability',
#   u'clarity',
#   u'condition',
#   u'warrant',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'change',
#   u'policy'],
#  [u'public', u'conditionality', u'guidance'],
#  [u'relationship',
#   u'statement',
#   u'view',
#   u'policy',
#   u'projection',
#   u'participant'],
#  [u'subcommittee',
#   u'communication',
#   u'enhancement',
#   u'refinement',
#   u'link',
#   u'development',
#   u'view',
#   u'stance',
#   u'policy'],
#  [u'conclusion',
#   u'discussion',
#   u'transaction',
#   u'accordance',
#   u'policy',
#   u'directive'],
#  [u'condition', u'price', u'stability', u'growth', u'output'],
#  [u'objective',
#   u'condition',
#   u'reserve',
#   u'market',
#   u'fund',
#   u'trading',
#   u'range',
#   u'percent'],
#  [u'maturity',
#   u'extension',
#   u'program',
#   u'end',
#   u'security',
#   u'maturity',
#   u'year',
#   u'year',
#   u'face',
#   u'value',
#   u'security',
#   u'maturity',
#   u'year',
#   u'face',
#   u'value'],
#  [u'existing',
#   u'policy',
#   u'security',
#   u'issue',
#   u'payment',
#   u'agency',
#   u'debt',
#   u'agency',
#   u'security',
#   u'agency',
#   u'security',
#   u'order',
#   u'face',
#   u'value',
#   u'security'],
#  [u'dollar',
#   u'roll',
#   u'transaction',
#   u'settlement',
#   u'agency',
#   u'transaction'],
#  [u'development',
#   u'balance',
#   u'sheet',
#   u'attainment',
#   u'time',
#   u'objective',
#   u'employment',
#   u'price',
#   u'stability'],
#  [u'labor', u'market', u'condition', u'month', u'unemployment', u'rate'],
#  [u'sign', u'improvement', u'housing', u'sector'],
#  [u'inflation', u'price', u'oil', u'gasoline'],
#  [u'inflation', u'expectation', u'stable'],
#  [u'mandate', u'employment', u'price', u'stability'],
#  [u'growth', u'quarters'],
#  [u'unemployment', u'rate', u'level', u'judge', u'mandate'],
#  [u'strain', u'market', u'risk', u'outlook'],
#  [u'increase',
#   u'oil',
#   u'gasoline',
#   u'price',
#   u'year',
#   u'inflation',
#   u'inflation',
#   u'rate',
#   u'judge',
#   u'mandate'],
#  [u'recovery',
#   u'inflation',
#   u'time',
#   u'rate',
#   u'mandate',
#   u'stance',
#   u'policy'],
#  [u'today',
#   u'target',
#   u'range',
#   u'fund',
#   u'rate',
#   u'percent',
#   u'condition',
#   u'rate',
#   u'resource',
#   u'utilization',
#   u'outlook',
#   u'inflation',
#   u'medium',
#   u'run',
#   u'level',
#   u'fund',
#   u'rate'],
#  [u'program', u'maturity', u'holding', u'security'],
#  [u'existing',
#   u'policy',
#   u'payment',
#   u'holding',
#   u'agency',
#   u'debt',
#   u'agency',
#   u'security',
#   u'agency',
#   u'security',
#   u'security',
#   u'auction'],
#  [u'size',
#   u'composition',
#   u'security',
#   u'holding',
#   u'holding',
#   u'recovery',
#   u'context',
#   u'price',
#   u'stability'],
#  [u'condition', u'level', u'fund', u'rate'],
#  [u'view',
#   u'increase',
#   u'fund',
#   u'rate',
#   u'mid-2013',
#   u'emergence',
#   u'pressure'],
#  [u'participant',
#   u'preference',
#   u'format',
#   u'format',
#   u'meeting',
#   u'possibility',
#   u'meeting',
#   u'schedule',
#   u'meeting',
#   u'time',
#   u'discussion'],
#  [u'member'],
#  [u'adviser', u'governor'],
#  [u'governor'],
#  [u'development',
#   u'session',
#   u'governor',
#   u'deputy',
#   u'manager',
#   u'development',
#   u'market',
#   u'market',
#   u'operation',
#   u'period'],
#  [u'addition',
#   u'deputy',
#   u'manager',
#   u'outcome',
#   u'test',
#   u'operation',
#   u'result',
#   u'agreement',
#   u'exercise',
#   u'implication',
#   u'bank',
#   u'policy',
#   u'action',
#   u'portion',
#   u'portfolio'],
#  [u'manager',
#   u'list',
#   u'counterparty',
#   u'operation',
#   u'criterium',
#   u'past',
#   u'counterparty'],
#  [u'manager',
#   u'staff',
#   u'work',
#   u'datum',
#   u'collection',
#   u'bank',
#   u'market',
#   u'datum',
#   u'measure',
#   u'bank',
#   u'funding',
#   u'rate'],
#  [u'manager',
#   u'arrangement',
#   u'institution',
#   u'pledge',
#   u'fund',
#   u'account',
#   u'collateral',
#   u'transaction',
#   u'creditor',
#   u'tool',
#   u'policy',
#   u'normalization',
#   u'manager',
#   u'step',
#   u'staff',
#   u'issue',
#   u'arrangement'],
#  [u'proposal', u'rate', u'operation', u'schedule'],
#  [u'spread',
#   u'rate',
#   u'reserve',
#   u'rate',
#   u'information',
#   u'effect',
#   u'spread',
#   u'money',
#   u'market',
#   u'demand'],
#  [u'proposal', u'series', u'term', u'operation', u'end', u'year'],
#  [u'discussion',
#   u'term',
#   u'rrp',
#   u'testing',
#   u'participant',
#   u'testing',
#   u'information',
#   u'effectiveness',
#   u'policy',
#   u'tool',
#   u'pressure',
#   u'rate',
#   u'year-end'],
#  [u'term',
#   u'information',
#   u'market',
#   u'participant',
#   u'investment',
#   u'arrangement'],
#  [u'participant',
#   u'pressure',
#   u'rate',
#   u'year-end',
#   u'size',
#   u'limit',
#   u'exercise'],
#  [u'cap',
#   u'operation',
#   u'year-end',
#   u'risk',
#   u'market',
#   u'cap',
#   u'concern',
#   u'program',
#   u'term',
#   u'operation'],
#  [u'term', u'operation', u'test', u'condition', u'operation', u'future.4'],
#  [u'discussion', u'testing', u'operation', u'resolution', u'exercise'],
#  [u'authorization', u'operation', u'meeting'],
#  [u'modification', u'beginning', u'operation', u'operation'],
#  [u'vote', u'resolution', u'term', u'operation'],
#  [u'operation',
#   u'ii',
#   u'size',
#   u'limit',
#   u'time',
#   u'iii',
#   u'bid',
#   u'rate',
#   u'basis',
#   u'point',
#   u'iv',
#   u'submitter',
#   u'rate',
#   u'sum',
#   u'bid',
#   u'size',
#   u'operation',
#   u'stopout',
#   u'rate',
#   u'bid',
#   u'order',
#   u'rate',
#   u'point',
#   u'total',
#   u'quantity',
#   u'bid',
#   u'size',
#   u'operation',
#   u'bid',
#   u'rate',
#   u'stopout',
#   u'rate',
#   u'bid',
#   u'stopout',
#   u'rate',
#   u'basis',
#   u'sum',
#   u'counterparty',
#   u'offer',
#   u'size',
#   u'operation'],
#  [u'operation', u'settlement'],
#  [u'manager', u'advance', u'term', u'operation'],
#  [u'operation', u'addition', u'agreement', u'size', u'limit', u'day'],
#  [u'vote', u'transaction', u'period'],
#  [u'intervention', u'operation', u'currency', u'account', u'period'],
#  [u'meeting',
#   u'end',
#   u'discussion',
#   u'development',
#   u'market',
#   u'balance',
#   u'sheet'],
#  [u'information',
#   u'meeting',
#   u'activity',
#   u'pace',
#   u'quarter',
#   u'labor',
#   u'market',
#   u'condition',
#   u'period'],
#  [u'price', u'inflation', u'objective', u'percent'],
#  [u'measure',
#   u'inflation',
#   u'compensation',
#   u'measure',
#   u'inflation',
#   u'expectation',
#   u'stable'],
#  [u'payroll',
#   u'employment',
#   u'gain',
#   u'increase',
#   u'quarter',
#   u'half',
#   u'year'],
#  [u'unemployment',
#   u'rate',
#   u'percent',
#   u'share',
#   u'worker',
#   u'time',
#   u'reason'],
#  [u'labor', u'force', u'participation', u'rate', u'ratio'],
#  [u'indicator', u'improvement', u'labor', u'market', u'condition'],
#  [u'rate',
#   u'private-sector',
#   u'hiring',
#   u'rate',
#   u'job',
#   u'opening',
#   u'measure',
#   u'firm',
#   u'hiring',
#   u'claim',
#   u'unemployment',
#   u'insurance',
#   u'measure',
#   u'household',
#   u'expectation',
#   u'labor',
#   u'market',
#   u'condition'],
#  [u'production',
#   u'net',
#   u'month',
#   u'quarter',
#   u'rate',
#   u'capacity',
#   u'utilization',
#   u'manufacturing',
#   u'sector'],
#  [u'reading',
#   u'order',
#   u'manufacturing',
#   u'survey',
#   u'increase',
#   u'factory',
#   u'output',
#   u'automaker',
#   u'production',
#   u'schedule',
#   u'quarter',
#   u'slowing',
#   u'pace',
#   u'motor',
#   u'vehicle',
#   u'assembly'],
#  [u'consumption', u'expenditure', u'pace', u'quarter'],
#  [u'component', u'sale', u'estimate', u'total', u'gain'],
#  [u'addition', u'sale', u'motor', u'vehicle', u'increase'],
#  [u'data', u'factor', u'household', u'spending'],
#  [u'income', u'consumer', u'sentiment', u'survey', u'consumer'],
#  [u'market', u'condition'],
#  [u'permit', u'home', u'net', u'month'],
#  [u'home', u'sale', u'sale', u'home', u'month'],
#  [u'spending',
#   u'business',
#   u'equipment',
#   u'property',
#   u'product',
#   u'pace',
#   u'quarter'],
#  [u'shipment', u'capital', u'good', u'aircraft', u'net', u'increase'],
#  [u'order', u'capital', u'good', u'level', u'shipment', u'shipment', u'month'],
#  [u'indicator',
#   u'survey',
#   u'business',
#   u'condition',
#   u'gain',
#   u'business',
#   u'equipment',
#   u'spending',
#   u'term'],
#  [u'business', u'spending', u'construction', u'vacancy', u'rate', u'building'],
#  [u'inventory',
#   u'industry',
#   u'line',
#   u'sale',
#   u'energy',
#   u'sector',
#   u'inventory',
#   u'year'],
#  [u'government', u'purchase', u'quarter'],
#  [u'government', u'purchase', u'defense', u'spending', u'quarter', u'quarter'],
#  [u'addition',
#   u'state',
#   u'government',
#   u'purchase',
#   u'payroll',
#   u'government',
#   u'construction',
#   u'expenditure',
#   u'quarter'],
#  ...]

# %%
from collections import Counter
frequency = Counter(nvocab)

# %%
id2word = {}; vocab = {}
for i,word in enumerate(frequency.keys()):
    vocab[word] = i 
    id2word[i] = word

# %%
len(vocab.keys())
# Out:
# 1757

# %%
from collections import defaultdict
def sentencelist(sentence):
    d = defaultdict(int); group = []
    for word in sentence:
        word_id = vocab[word] 
        d[word_id] += 1 
    group = [(a, d[a]) for a in d.keys()]
    return group
corpus = [sentencelist(sentence) for sentence in nvocab]

# %% [markdown]
# ## Topic Extraction

# %%
import gensim

# %%
lda2 = gensim.models.ldamodel.LdaModel(corpus, num_topics=3, id2word = id2word, update_every=1, chunksize=300)

# %%
lda2.print_topics()
# Out:
# [u'0.064*rate + 0.043*policy + 0.039*participant + 0.035*inflation + 0.024*fund + 0.023*security + 0.018*market + 0.018*percent + 0.016*condition + 0.016*objective',
#  u'0.055*market + 0.034*period + 0.024*price + 0.022*condition + 0.022*labor + 0.021*operation + 0.019*risk + 0.018*dollar + 0.017*bank + 0.016*currency',
#  u'0.054*price + 0.051*inflation + 0.033*quarter + 0.027*growth + 0.025*consumer + 0.024*year + 0.023*measure + 0.023*energy + 0.022*decline + 0.022*spending']

# %% [markdown]
# ## Naive Bayes Approach
