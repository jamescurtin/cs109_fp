# %% [markdown]
# # Sentiment Analysis

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import json

# %% [markdown]
# ### Natural Language Processing
#
# We begin by parsing the text and pre-processing it to prepare it for Latent Dirichlet Analysis. This step is meant to remove stopwords and identify nouns and adjectives.

# %%
from pattern.en import parse
from pattern.en import pprint
from pattern.vector import stem, PORTER, LEMMA
punctuation = list('.,;:!?()[]{}`''\"@#$^&*+-|=~_')

# %%
from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS

# %% [markdown]
# ### Financial Vocabulary and Adjectives
#
# **TO CHANGE: WE ARE GOING TO DO THIS FOR NAIVE BAYES PART!!!!!!!!**
# Since our analysis will focus on financial information and so will be heavily reliant on the "sentiments" of vocabulary from this field, we can enhance our analysis by using a financial dictionary. The **Loughran-McDonald 2014 Master Dictionary** is a good tool to use as it includes words that often appear in 10-K documents. The dictionary includes 9 sentiment categories, including "negative", "positive", "uncertainty", "litigious", "modal", and "constraining", among others.

# %%
import re
regex1=re.compile(r"\.{2,}")

def modified_get_parts(thetext):
    thetext=re.sub(regex1, ' ', thetext)
    nouns=[]
    descriptives=[]
    for i,sentence in enumerate(parse(thetext, tokenize=True, lemmata=True).split()):
        nouns.append([])
        descriptives.append([])
        for token in sentence:
            #print token
            if len(token[4]) >0:
                if token[1] in ['JJ', 'JJR', 'JJS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    descriptives[i].append(token[4])
                elif token[1] in ['NN', 'NNS']:
                    if token[4] in stopwords or token[4][0] in punctuation or token[4][-1] in punctuation or len(token[4])==1:
                        continue
                    if len(token[4]) > 20:
                        continue
                    nouns[i].append(token[4])
    out=zip(nouns, descriptives)
    nouns2=[]
    descriptives2=[]
    for n,d in out:
        if len(n)!=0 and len(d)!=0:
            nouns2.append(n)
            descriptives2.append(d)
    return nouns2, descriptives2

# %%
get_parts("In determining how long to maintain this target range, the Committee will assess progress--both realized and expected--toward its objectives of maximum employment and 2 percent inflation.")
# Out:
# ([[u'target',
#    u'range',
#    u'objective',
#    u'employment',
#    u'percent',
#    u'inflation']],
#  [[u'long', u'maximum']])

# %% [markdown]
# We load in the fomc_mins dictionary that we created in the Scraping.ipynb iPython Notebook.

# %%
with open("fomc_mins.json", "rb") as infile:
    fomc_mins = json.load(infile)

# %%
fomc_mins['20100127']
# Out:
# u'\n\n\n\n\n\nFRB: FOMC Minutes, January 26-27, 2010\n\n\n\n\n\n\n\n\n  (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n  ga(\'create\', \'UA-35121701-1\', \'federalreserve.gov\', {\'cookieExpires\': 0});\n  ga(\'set\', \'anonymizeIp\', true);\n  ga(\'send\', \'pageview\');\n\n\n\nskip to main navigation\nskip to secondary navigation\nskip to content\n\n\n\n\nWhat\'s New \xb7 \nWhat\'s Next \xb7 \nSite Map \xb7 \nA-Z Index \xb7 \nFAQs \xb7 \nCareers \xb7 \nRSS\n\n\n\nSearch\xa0\xa0Advanced Search\n\n\n\n\n\n\n\n\n\n\nAboutthe Fed\n\n\nNews& Events\n\n\nMonetaryPolicy\n\n\nBankingInformation& Regulation\n\n\nPaymentSystems\n\n\nEconomicResearch& Data\n\n\nConsumer Information\n\n\nCommunityDevelopment\n\n\nReportingForms\n\n\nPublications\n\n\n\n\n\n\n\nskip to content\n\n\n\n        <!--\n        buildMenu();\n        -->\n        \n\nMenu\n\n\n\n\n\n\nHome\n\n > Monetary Policy\n\n\n > Federal Open Market Committee \n\n\nPrint\n\n\n\nMinutes of the Federal Open Market Committee\n\nJanuary 26-27, 2010\n\n\n\n\n\n     FOMC Minutes\n\n                | Summary of Economic Projections\n\n\n\n\n\n\n\n       A joint meeting of the Federal Open Market Committee and the Board of Governors of the Federal Reserve System was held in the offices of the Board of Governors in Washington, D.C., on Tuesday, January 26, 2010, at 2:00 p.m. and continued on Wednesday, January 27, 2010, at 8:30 a.m.\n    \n    \n       PRESENT:\n       Ben Bernanke, Chairman\n       William C. Dudley, Vice Chairman\n       James Bullard\n       Elizabeth Duke\n       Thomas M. Hoenig\n       Donald L. Kohn\n       Sandra Pianalto\n       Eric Rosengren\n       Daniel K. Tarullo\n       Kevin Warsh\n    \n\n       Christine Cumming, Charles L. Evans, Richard Fisher, Narayana Kocherlakota, and Charles I. Plosser, Alternate Members of the Federal Open Market Committee\n    \n\n       Jeffrey M. Lacker, Dennis P. Lockhart, and Janet L. Yellen, Presidents of the Federal Reserve Banks of Richmond, Atlanta, and San Francisco, respectively\n    \n\n       Brian F. Madigan, Secretary and Economist\n       Matthew M. Luecke, Assistant Secretary\n       David W. Skidmore, Assistant Secretary\n       Michelle A. Smith, Assistant Secretary\n       Scott G. Alvarez, General Counsel\n       Nathan Sheets, Economist\n       David J. Stockton, Economist\n    \n\n       Alan D. Barkema, Thomas A. Connors, William B. English, Jeff Fuhrer, Steven B. Kamin, Simon Potter, Lawrence Slifman, Mark S. Sniderman, Christopher J. Waller, and David W. Wilcox, Associate Economists\n    \n\n       Brian Sack, Manager, System Open Market Account\n    \n\n       Jennifer J. Johnson, Secretary of the Board, Office of the Secretary, Board of Governors\n    \n\n       Patrick M. Parkinson, Director, Division of Bank Supervision and Regulation, Board of Governors\n    \n\n       Robert deV. Frierson,1 Deputy Secretary, Office of the Secretary, Board of Governors\n    \n\n       Charles S. Struckmeyer, Deputy Staff Director, Office of the Staff Director for Management, Board of Governors\n    \n\n       James A. Clouse, Deputy Director, Division of Monetary Affairs, Board of Governors\n    \n\n       Linda Robertson,2 Assistant to the Board, Office of Board Members, Board of Governors\n    \n\n       Sherry Edwards, Andrew T. Levin, and William R. Nelson, Senior Associate Directors, Division of Monetary Affairs, Board of Governors; David Reifschneider and William Wascher, Senior Associate Directors, Division of Research and Statistics, Board of Governors\n    \n\n       Stephen A. Meyer, Senior Adviser, Division of Monetary Affairs, Board of Governors; Stephen D. Oliner, Senior Adviser, Division of Research and Statistics, ...

# %%
get_parts(fomc_mins['20100127'])
# Out:
# ([[u'm=s.getelementsbytagname(o)[0];a.async=1;a.src=g;m.parentnode.insertbefore(a,m',
#    u'window,document',
#    u"script','",
#    u"ga('create",
#    u'federalreserve.gov',
#    u'cookieexpire',
#    u'ga',
#    u'set',
#    u'ga',
#    u'pageview'],
#   [u'skip', u'navigation', u'skip', u'navigation', u'skip'],
#   [u'meeting', u'governor', u'office', u'governor'],
#   [u'member'],
#   [u'matter',
#    u'agenda',
#    u'meeting',
#    u'advice',
#    u'election',
#    u'member',
#    u'member',
#    u'term',
#    u'individual',
#    u'oath',
#    u'office'],
#   [u'member', u'member'],
#   [u'vote',
#    u'officer',
#    u'selection',
#    u'successor',
#    u'meeting',
#    u'event',
#    u'discontinuance',
#    u'connection',
#    u'connection'],
#   [u'vote', u'addition', u'summary', u'rule', u'access', u'information'],
#   [u'vote', u'transaction'],
#   [u'vote', u'pleasure', u'selection'],
#   [u'review',
#    u'authorization',
#    u'market',
#    u'operation',
#    u'currency',
#    u'transaction',
#    u'dollar',
#    u'roll',
#    u'transaction',
#    u'process',
#    u'settling',
#    u'agency',
#    u'security',
#    u'purchase',
#    u'staff',
#    u'sentence',
#    u'directive',
#    u'dollar',
#    u'roll',
#    u'transaction',
#    u'purpose',
#    u'purchase',
#    u'date'],
#   [u'repurchase',
#    u'agreement',
#    u'course',
#    u'year',
#    u'readiness',
#    u'tool',
#    u'bank',
#    u'reserve'],
#   [u'capability',
#    u'agency',
#    u'administration',
#    u'trading',
#    u'settlement',
#    u'resource',
#    u'agent',
#    u'task',
#    u'capability'],
#   [u'vote',
#    u'amendment',
#    u'paragraph',
#    u'use',
#    u'security',
#    u'obligation',
#    u'agency',
#    u'investment',
#    u'transaction',
#    u'account',
#    u'agency',
#    u'account'],
#   [u'authorization'],
#   [u'extent', u'policy', u'directive', u'meeting'],
#   [u'government',
#    u'security',
#    u'security',
#    u'security',
#    u'obligation',
#    u'agency',
#    u'market',
#    u'security',
#    u'dealer',
#    u'account',
#    u'cash',
#    u'delivery',
#    u'basis',
#    u'market',
#    u'price',
#    u'exchange',
#    u'government',
#    u'agency',
#    u'security',
#    u'agency',
#    u'replacement',
#    u'market',
#    u'government',
#    u'security',
#    u'security',
#    u'obligation',
#    u'agency',
#    u'agreement',
#    u'security',
#    u'obligation',
#    u'transaction',
#    u'repo',
#    u'transaction',
#    u'business',
#    u'day',
#    u'rate',
#    u'bidding',
#    u'limitation',
#    u'volume',
#    u'agreement',
#    u'individual',
#    u'counterparty'],
#   [u'order',
#    u'conduct',
#    u'market',
#    u'operation',
#    u'agent',
#    u'agency',
#    u'transaction'],
#   [u'order',
#    u'conduct',
#    u'market',
#    u'operation',
#    u'basis',
#    u'government',
#    u'security',
#    u'security',
#    u'obligation',
#    u'agency',
#    u'dealer',
#    u'rate',
#    u'bidding'],
#   [u'minimum',
#    u'fee',
#    u'objective',
#    u'program',
#    u'limitation',
#    u'issue',
#    u'security',
#    u'dealer'],
#   [u'bid', u'dealer', u'ability', u'issue'],
#   [u'order',
#    u'conduct',
#    u'market',
#    u'operation',
#    u'provision',
#    u'investment',
#    u'account',
#    u'account',
#    u'agent',
#    u'section'],
#   [u'government',
#    u'security',
#    u'security',
#    u'obligation',
#    u'agency',
#    u'account',
#    u'basis',
#    u'paragraph',
#    u'agreement',
#    u'resale',
#    u'account',
#    u'security',
#    u'business',
#    u'day',
#    u'term',
#    u'transaction',
#    u'market',
#    u'account',
#    u'dealer',
#    u'subject',
#    u'condition',
#    u'purchase',
#    u'sale',
#    u'security',
#    u'paragraph',
#    u'l.b',
#    u'repurchase',
#    u'agreement',
#    u'government',
#    u'security',
#    u'security',
#    u'obligation',
#    u'agency',
#    u'sale',
#    u'repurchase',
#    u'agreement',
#    u'account',
#    u'agency',
#    u'account'],
#   [u'transaction', u'account', u'provision', u'paragraph', u'service', u'fee'],
#   [u'execution',
#    u'decision',
#    u'policy',
#    u'period',
#    u'instruction',
#    u'circumstance',
#    u'degree',
#    u'pressure',
#    u'reserve',
#    u'position',
#    u'fund',
#    u'rate',
#    u'action',
#    u'result',
#    u'material',
#    u'change',
#    u'composition',
#    u'size',
#    u'asset',
#    u'meeting'],
#   [u'adjustment',
#    u'context',
#    u'discussion',
#    u'decision',
#    u'meeting',
#    u'objective',
#    u'price',
#    u'stability',
#    u'growth',
#    u'development',
#    u'period'],
#   [u'practice', u'adjustment'],
#   [u'vote', u'instruction', u'respect', u'form'],
#   [u'vote', u'document', u'approval', u'warehousing', u'agreement'],
#   [u'extent',
#    u'currency',
#    u'directive',
#    u'authorization',
#    u'conformity',
#    u'instruction',
#    u'time',
#    u'time'],
#   [u'currency',
#    u'form',
#    u'cable',
#    u'transfer',
#    u'spot',
#    u'transaction',
#    u'market',
#    u'home',
#    u'transaction',
#    u'section',
#    u'authority',
#    u'institution',
#    u'dollar',
#    u'reais',
#    u'dollar',
#    u'kroner',
#    u'yen',
#    u'peso',
#    u'dollar',
#    u'kroner',
#    u'pound',
#    u'sterling',
#    u'dollar',
#    u'kronor',
#    u'franc'],
#   [u'balance', u'forward', u'contract', u'currency', u'paragraph'],
#   [u'currency',
#    u'bank',
#    u'dollar',
#    u'currency',
#    u'arrangement',
#    u'paragraph',
#    u'drawing',
#    u'party',
#    u'arrangement',
#    u'month',
#    u'time',
#    u'circumstance',
#    u'delay'],
#   [u'position', u'currency'],
#   [u'purpose',
#    u'position',
#    u'currency',
#    u'sum',
#    u'sign',
#    u'position',
#    u'currency',
#    u'change',
#    u'dollar',
#    u'value',
#    u'exchange',
#    u'rate',
#    u'movement',
#    u'accrual'],
#   [u'net',
#    u'position',
#    u'currency',
#    u'holding',
#    u'balance',
#    u'currency',
#    u'contract',
#    u'receipt',
#    u'contract',
#    u'delivery',
#    u'currency',
#    u'sum',
#    u'element',
#    u'regard'],
#   [u'currency',
#    u'arrangement',
#    u'swap',
#    u'arrangement',
#    u'period',
#    u'maximum',
#    u'month',
#    u'bank',
#    u'governor',
#    u'section',
#    u'regulation',
#    u'relation',
#    u'approval',
#    u'arrangement',
#    u'maturity'],
#   [u'bank'],
#   [u'arrangement', u'million', u'dollar'],
#   [u'change',
#    u'term',
#    u'swap',
#    u'arrangement',
#    u'term',
#    u'arrangement',
#    u'review',
#    u'approval'],
#   [u'transaction', u'currency', u'paragraph', u'market', u'rate'],
#   [u'purpose',
#    u'investment',
#    u'return',
#    u'holding',
#    u'currency',
#    u'purpose',
#    u'rate',
#    u'connection',
#    u'swap',
#    u'drawing',
#    u'transaction',
#    u'bank',
#    u'exchange',
#    u'rate'],
#   [u'practice', u'bank', u'coordination', u'currency', u'transaction'],
#   [u'arrangement', u'bank', u'holding', u'currency', u'balance'],
#   [u'agreement',
#    u'understanding',
#    u'administration',
#    u'account',
#    u'bank',
#    u'governor',
#    u'section',
#    u'regulation',
#    u'review',
#    u'approval'],
#   [u'currency',
#    u'holding',
#    u'liquidity',
#    u'need',
#    u'currency',
#    u'portfolio',
#    u'duration',
#    u'month',
#    u'duration'],
#   [u'investment',
#    u'buying',
#    u'obligation',
#    u'government',
#    u'agency',
#    u'security',
#    u'agreement',
#    u'repurchase',
#    u'security',
#    u'security',
#    u'agreement',
#    u'resale',
#    u'security',
#    u'time',
#    u'deposit',
#    u'account',
#    u'institution'],
#   [u'addition',
#    u'connection',
#    u'arrangement',
#    u'investment',
#    u'facility',
#    u'currency',
#    u'holding',
#    u'government',
#    u'security',
#    u'bank',
#    u'agreement',
#    u'repurchase',
#    u'security',
#    u'calendar',
#    u'day'],
#   [u'operation', u'paragraph'],
#   [u'governor', u'member', u'absence', u'member', u'member', u'absence'],
#   [u'meeting',
#    u'request',
#    u'member',
#    u'request',
#    u'purpose',
#    u'operation',
#    u'matter',
#    u'responsibility'],
#   [u'approval',
#    u'agreement',
#    u'division',
#    u'responsibility',
#    u'currency',
#    u'operation',
#    u'currency',
#    u'operation',
#    u'policy',
#    u'matter',
#    u'currency',
#    u'operation'],
#   [u'time', u'time', u'report', u'information', u'policy'],
#   [u'staff',
#    u'officer',
#    u'information',
#    u'currency',
#    u'operation',
#    u'official'],
#   [u'currency',
#    u'operation',
#    u'accordance',
#    u'paragraph',
#    u'statement',
#    u'procedure',
#    u'respect'],
#   [u'operation',
#    u'currency',
#    u'market',
#    u'condition',
#    u'market',
#    u'exchange',
#    u'rate',
#    u'dollar',
#    u'reflect',
#    u'action',
#    u'behavior'],
#   [u'spot', u'purchase', u'sale', u'exchange'],
#   [u'currency', u'swap', u'arrangement', u'bank'],
#   [u'respect', u'bank', u'country', u'institution'],
#   [u'balance', u'light', u'future', u'currency'],
#   [u'mean', u'meeting', u'commitment', u'currency', u'operation'],
#   [u'currency', u'operation'],
#   [u'consultation', u'cooperation'],
#   [u'cooperation', u'authority'],
#   [u'manner', u'obligation', u'exchange', u'arrangement'],
#   [u'instruction'],
#   [u'operation',
#    u'authorization',
#    u'direction',
#    u'set',
#    u'understanding',
#    u'respect',
#    u'consultation',
#    u'clearance'],
#   [u'operation', u'clearance'],
#   [u'consultation', u'time'],
#   [u'operation', u'change', u'position', u'currency', u'day', u'meeting'],
#   [u'operation',
#    u'change',
#    u'day',
#    u'net',
#    u'position',
#    u'currency',
#    u'operation',
#    u'repayment',
#    u'swap',
#    u'drawing'],
#   [u'operation',
#    u'volume',
#    u'trading',
#    u'currency',
#    u'change',
#    u'net',
#    u'position',
#    u'currency',
#    u'limit'],
#   [u'swap', u'bank', u'ii', u'percent', u'size', u'swap', u'arrangement'],
#   [u'consultation', u'time', u'consultation', u'time'],
#   [u'operation', u'change', u'position', u'currency', u'meeting'],
#   [u'swap', u'bank', u'ii', u'percent', u'size', u'swap', u'arrangement'],
#   [u'swap', u'drawing', u'operation', u'character'],
#   [u'development', u'development', u'market', u'period'],
#   [u'market',
#    u'condition',
#    u'growth',
#    u'volatility',
#    u'security',
#    u'market',
#    u'end',
#    u'period'],
#   [u'year-end', u'funding', u'pressure'],
#   [u'market', u'strain', u'result', u'closing', u'liquidity', u'facility'],
#   [u'market', u'operation', u'agency', u'debt', u'agency', u'period'],
#   [u'dollar',
#    u'roll',
#    u'transaction',
#    u'agency',
#    u'security',
#    u'settlement',
#    u'purchase'],
#   [u'vote', u'transaction'],
#   [u'participant', u'approach', u'proceed', u'agency', u'security'],
#   [u'market', u'operation', u'currency', u'account', u'period'],
#   [u'staff',
#    u'usage',
#    u'discount',
#    u'window',
#    u'liquidity',
#    u'facility',
#    u'step',
#    u'policymaker',
#    u'liquidity',
#    u'provision'],
#   [u'step',
#    u'auction',
#    u'pre-crisis',
#    u'standard',
#    u'maturity',
#    u'primary',
#    u'credit',
#    u'loan',
#    u'depository',
#    u'institution',
#    u'basis',
#    u'point',
#    u'basis',
#    u'point',
#    u'spread',
#    u'credit',
#    u'rate',
#    u'end',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate'],
#   [u'spread',
#    u'balance',
#    u'objective',
#    u'institution',
#    u'discount',
#    u'window',
#    u'source',
#    u'liquidity',
#    u'liquidity',
#    u'shortfall',
#    u'market',
#    u'depository',
#    u'institution',
#    u'discount',
#    u'window',
#    u'source',
#    u'fund',
#    u'funding'],
#   [u'spread',
#    u'basis',
#    u'point',
#    u'crisis',
#    u'spread',
#    u'basis',
#    u'point',
#    u'basis',
#    u'point',
#    u'response',
#    u'crisis'],
#   [u'participant',
#    u'improvement',
#    u'bank',
#    u'market',
#    u'auction',
#    u'step',
#    u'month',
#    u'plan',
#    u'stability',
#    u'growth'],
#   [u'maturity',
#    u'credit',
#    u'loan',
#    u'spread',
#    u'credit',
#    u'rate',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate'],
#   [u'participant', u'spread', u'decision', u'approach', u'policy', u'term'],
#   [u'participant',
#    u'step',
#    u'liquidity',
#    u'provision',
#    u'footing',
#    u'adjustment',
#    u'diminution',
#    u'market',
#    u'strain',
#    u'creation',
#    u'liquidity',
#    u'facility',
#    u'expansion',
#    u'facility',
#    u'step',
#    u'change',
#    u'assessment',
#    u'stance',
#    u'policy',
#    u'time',
#    u'policy',
#    u'stance'],
#   [u'note',
#    u'meeting',
#    u'authority',
#    u'governor',
#    u'auction',
#    u'auction',
#    u'auction'],
#   [u'staff',
#    u'policymaker',
#    u'tool',
#    u'strategy',
#    u'withdrawal',
#    u'policy',
#    u'accommodation',
#    u'linkage',
#    u'tool',
#    u'strategy',
#    u'framework',
#    u'policy'],
#   [u'tool',
#    u'policy',
#    u'stance',
#    u'rate',
#    u'reserve',
#    u'balance',
#    u'rate',
#    u'term',
#    u'reverse',
#    u'repurchase',
#    u'agreement',
#    u'dealer',
#    u'term',
#    u'range',
#    u'counterparty',
#    u'term',
#    u'deposit',
#    u'facility',
#    u'reserve',
#    u'redeeming',
#    u'security',
#    u'proceed',
#    u'selling',
#    u'security'],
#   [u'ability',
#    u'term',
#    u'dealer',
#    u'transaction',
#    u'security',
#    u'agency',
#    u'debt',
#    u'collateral',
#    u'staff',
#    u'term',
#    u'spring',
#    u'capability',
#    u'set',
#    u'counterparty'],
#   [u'week',
#    u'staff',
#    u'comment',
#    u'response',
#    u'notice',
#    u'public',
#    u'input',
#    u'proposal'],
#   [u'staff', u'proposal', u'consideration'],
#   [u'staff',
#    u'strategy',
#    u'tool',
#    u'return',
#    u'stance',
#    u'policy',
#    u'tool',
#    u'supply',
#    u'reserve',
#    u'level',
#    u'consequence',
#    u'expansion',
#    u'liquidity',
#    u'lending',
#    u'facility',
#    u'asset',
#    u'purchase',
#    u'crisis--before',
#    u'rate',
#    u'target',
#    u'fund',
#    u'rate',
#    u'rate',
#    u'line',
#    u'increase',
#    u'fund',
#    u'rate',
#    u'target',
#    u'tool',
#    u'supply',
#    u'reserve',
#    u'balance',
#    u'rate',
#    u'target',
#    u'fund',
#    u'rate',
#    u'reserve',
#    u'draining',
#    u'tool',
#    u'fund',
#    u'rate',
#    u'line',
#    u'target'],
#   [u'participant',
#    u'range',
#    u'view',
#    u'tool',
#    u'strategy',
#    u'policy',
#    u'accommodation',
#    u'step'],
#   [u'rate', u'target', u'fund', u'rate', u'element', u'policy'],
#   [u'thought',
#    u'supply',
#    u'reserve',
#    u'balance',
#    u'extent',
#    u'increase',
#    u'rate',
#    u'target',
#    u'fund',
#    u'rate',
#    u'link',
#    u'market',
#    u'rate',
#    u'rate',
#    u'draining',
#    u'operation',
#    u'precursor',
#    u'increase',
#    u'target',
#    u'fund',
#    u'rate'],
#   [u'reason', u'reserve', u'increase', u'target', u'rate'],
#   [u'respect',
#    u'approach',
#    u'policy',
#    u'policymaker',
#    u'benefit',
#    u'fund',
#    u'rate',
#    u'operating',
#    u'target',
#    u'policy',
#    u'money',
#    u'market',
#    u'rate',
#    u'fund',
#    u'rate'],
#   [u'thought',
#    u'approach',
#    u'credit',
#    u'rate',
#    u'target',
#    u'fund',
#    u'rate',
#    u'rate',
#    u'target--a',
#    u'corridor'],
#   [u'participant',
#    u'supply',
#    u'reserve',
#    u'balance',
#    u'fund',
#    u'rate',
#    u'rate'],
#   [u'advantage', u'rate', u'target', u'market', u'rate', u'stance', u'policy'],
#   [u'participant',
#    u'judgment',
#    u'tentative',
#    u'operating',
#    u'regime',
#    u'information',
#    u'approach',
#    u'withdrawal',
#    u'policy',
#    u'accommodation'],
#   [u'staff', u'size', u'balance', u'sheet', u'composition'],
#   [u'policymaker',
#    u'view',
#    u'supply',
#    u'reserve',
#    u'balance',
#    u'size',
#    u'balance',
#    u'sheet',
#    u'time'],
#   [u'security', u'crisis'],
#   [u'portfolio', u'security'],
#   [u'participant',
#    u'policy',
#    u'redeeming',
#    u'agency',
#    u'debt',
#    u'security',
#    u'goal'],
#   [u'thought',
#    u'security',
#    u'point',
#    u'future',
#    u'purchase',
#    u'security',
#    u'reduction',
#    u'asset',
#    u'growth',
#    u'public',
#    u'demand',
#    u'currency'],
#   [u'program',
#    u'asset',
#    u'sale',
#    u'size',
#    u'balance',
#    u'sheet',
#    u'reserve',
#    u'balance',
#    u'composition',
#    u'security',
#    u'holding',
#    u'security',
#    u'transaction',
#    u'market',
#    u'disruption',
#    u'implication',
#    u'recovery',
#    u'recovery',
#    u'tightening',
#    u'condition',
#    u'rate'],
#   [u'thought',
#    u'program',
#    u'asset',
#    u'sale',
#    u'future',
#    u'balance',
#    u'sheet',
#    u'manner',
#    u'security',
#    u'prepayment',
#    u'program',
#    u'asset',
#    u'sale',
#    u'number',
#    u'year',
#    u'determination',
#    u'period',
#    u'policy',
#    u'manner',
#    u'pace',
#    u'inflation',
#    u'effect',
#    u'asset',
#    u'price',
#    u'market',
#    u'rate'],
#   [u'pace',
#    u'asset',
#    u'sale',
#    u'purchase',
#    u'time',
#    u'response',
#    u'development',
#    u'economy',
#    u'evolution',
#    u'outlook'],
#   [u'information', u'meeting', u'activity', u'month'],
#   [u'spending',
#    u'quarter',
#    u'business',
#    u'expenditure',
#    u'equipment',
#    u'software'],
#   [u'improvement', u'housing', u'market', u'spending', u'structure'],
#   [u'data', u'pace', u'inventory', u'liquidation', u'quarter', u'activity'],
#   [u'production', u'pace', u'quarter'],
#   [u'labor',
#    u'market',
#    u'layoff',
#    u'month',
#    u'year',
#    u'unemployment',
#    u'rate'],
#   [u'increase',
#    u'energy',
#    u'price',
#    u'headline',
#    u'consumer',
#    u'price',
#    u'inflation',
#    u'consumer',
#    u'price',
#    u'inflation'],
#   [u'pace', u'job', u'loss', u'change', u'payroll', u'pattern', u'industry'],
#   [u'unemployment', u'rate'],
#   [u'labor',
#    u'force',
#    u'participation',
#    u'rate',
#    u'spring',
#    u'labor',
#    u'market',
#    u'condition'],
#   [u'hiring',
#    u'number',
#    u'individual',
#    u'unemployment',
#    u'emergency',
#    u'length',
#    u'unemployment',
#    u'spell',
#    u'joblessness'],
#   [u'production', u'increase', u'trough'],
#   [u'gain', u'jump', u'output', u'gas', u'utility', u'weather'],
#   [u'gain'],
#   [u'quarter',
#    u'increase',
#    u'manufacturing',
#    u'recovery',
#    u'motor',
#    u'vehicle',
#    u'output',
#    u'export',
#    u'demand',
#    u'pace',
#    u'business',
#    u'inventory',
#    u'liquidation'],
#   [u'output',
#    u'consumer',
#    u'good',
#    u'business',
#    u'equipment',
#    u'material',
#    u'quarter',
#    u'gain',
#    u'category',
#    u'quarter'],
#   [u'indicator', u'production', u'month'],
#   [u'spending', u'trend', u'year', u'pre-recession', u'level'],
#   [u'increase', u'consumption', u'expenditure'],
#   [u'sale', u'weather', u'purchase', u'light', u'motor', u'vehicle'],
#   [u'determinant', u'household', u'income', u'balance', u'end', u'year'],
#   [u'improvement',
#    u'year',
#    u'measure',
#    u'consumer',
#    u'sentiment',
#    u'norm',
#    u'term',
#    u'standard',
#    u'consumer',
#    u'loan',
#    u'credit',
#    u'card',
#    u'loan'],
#   [u'recovery',
#    u'housing',
#    u'market',
#    u'half',
#    u'number',
#    u'factor',
#    u'housing',
#    u'demand'],
#   [u'rate', u'mortgage'],
#   [u'sale',
#    u'home',
#    u'pattern',
#    u'sale',
#    u'anticipation',
#    u'expiration',
#    u'homebuyer',
#    u'credit'],
#   [u'home', u'sale', u'level', u'quarters'],
#   [u'sale', u'home', u'recovery', u'year'],
#   [u'home', u'spring'],
#   [u'pace',
#    u'construction',
#    u'pace',
#    u'home',
#    u'sale',
#    u'overhang',
#    u'single-family',
#    u'house'],
#   [u'spending',
#    u'equipment',
#    u'software',
#    u'quarter',
#    u'increase',
#    u'quarter'],
#   [u'equipment',
#    u'clip',
#    u'quarter',
#    u'order',
#    u'shipment',
#    u'equipment',
#    u'net'],
#   [u'business', u'purchase', u'motor', u'vehicle', u'quarter'],
#   [u'transportation',
#    u'sector',
#    u'business',
#    u'outlay',
#    u'equipment',
#    u'software',
#    u'quarter'],
#   [u'condition', u'construction', u'sector'],
#   [u'spending',
#    u'structure',
#    u'drilling',
#    u'mining',
#    u'sector',
#    u'quarter',
#    u'datum',
#    u'expenditure',
#    u'rate',
#    u'decline',
#    u'quarter'],
#   [u'pace', u'business', u'inventory', u'liquidation', u'quarter'],
#   [u'quarters',
#    u'decline',
#    u'inventory',
#    u'pace',
#    u'book-value',
#    u'data',
#    u'category',
#    u'inventory',
#    u'term'],
#   [u'datum',
#    u'change',
#    u'inventory',
#    u'accumulation',
#    u'stock',
#    u'farm',
#    u'contribution',
#    u'increase',
#    u'product',
#    u'quarter'],
#   [u'price', u'inflation', u'month', u'increase', u'energy', u'price'],
#   [u'price',
#    u'increase',
#    u'service',
#    u'year',
#    u'price',
#    u'housing',
#    u'service',
#    u'deceleration',
#    u'labor',
#    u'cost'],
#   [u'price', u'increase', u'core', u'good', u'half'],
#   [u'survey',
#    u'result',
#    u'household',
#    u'expectation',
#    u'inflation',
#    u'addition',
#    u'longer-term',
#    u'inflation',
#    u'expectation',
#    u'end',
#    u'range',
#    u'year'],
#   [u'trade', u'deficit', u'rise', u'import', u'increase', u'export'],
#   [u'rise',
#    u'export',
#    u'gain',
#    u'export',
#    u'decline',
#    u'export',
#    u'consumer',
#    u'good',
#    u'growth'],
#   [u'import',
#    u'oil',
#    u'one-third',
#    u'increase',
#    u'import',
#    u'category',
#    u'import',
#    u'gain'],
#   [u'datum', u'activity', u'economy', u'quarter', u'pace'],
#   [u'unemployment', u'rate', u'consumption', u'indicator'],
#   [u'condition', u'lending', u'sector', u'economy'],
#   [u'increase', u'export', u'import', u'volume', u'recovery', u'trade'],
#   [u'activity', u'market', u'economy', u'quarter', u'pace', u'quarter'],
#   [u'growth'],
#   [u'indicator',
#    u'continuation',
#    u'growth',
#    u'region',
#    u'growth',
#    u'quarter',
#    u'gain'],
#   [u'energy', u'price', u'headline', u'inflation', u'economy', u'deflation'],
#   [u'headline', u'inflation', u'pace'],
#   [u'decision',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'meeting',
#    u'retention',
#    u'period',
#    u'language',
#    u'statement',
#    u'market',
#    u'participant',
#    u'price',
#    u'response'],
#   [u'period',
#    u'path',
#    u'fund',
#    u'rate',
#    u'fund',
#    u'eurodollar',
#    u'future',
#    u'quote',
#    u'investor',
#    u'communication',
#    u'discussion',
#    u'asset',
#    u'purchase',
#    u'minute',
#    u'period',
#    u'policy'],
#   [u'contrast', u'yield', u'security', u'net'],
#   [u'inflation',
#    u'compensation',
#    u'security',
#    u'tip',
#    u'increase',
#    u'inflation',
#    u'risk',
#    u'premium',
#    u'improvement',
#    u'tip',
#    u'market',
#    u'liquidity',
#    u'rise',
#    u'inflation',
#    u'expectation',
#    u'increase',
#    u'oil',
#    u'price'],
#   [u'market', u'condition', u'growth', u'period', u'market'],
#   [u'spread',
#    u'rate',
#    u'index',
#    u'swap',
#    u'rate',
#    u'maturity',
#    u'spread',
#    u'maturity'],
#   [u'spread', u'paper', u'end', u'range', u'mid-2007'],
#   [u'demand',
#    u'cash',
#    u'agreement',
#    u'repo',
#    u'market',
#    u'decline',
#    u'pressure',
#    u'yield',
#    u'repo',
#    u'rate'],
#   [u'pressure',
#    u'market',
#    u'liquidity',
#    u'market',
#    u'dislocation',
#    u'transaction',
#    u'rate'],
#   [u'use',
#    u'credit',
#    u'facility',
#    u'period',
#    u'market',
#    u'commentary',
#    u'concern',
#    u'impending',
#    u'expiration',
#    u'number',
#    u'facility'],
#   [u'period',
#    u'stock',
#    u'price',
#    u'index',
#    u'course',
#    u'volatility',
#    u'period',
#    u'balance'],
#   [u'gap',
#    u'staff',
#    u'estimate',
#    u'equity',
#    u'return',
#    u'year',
#    u'firm',
#    u'yield--a',
#    u'gauge',
#    u'equity',
#    u'risk',
#    u'level',
#    u'decade'],
#   [u'period', u'yield', u'bond', u'comparable-maturity', u'security'],
#   [u'estimate', u'spread', u'bonds--a', u'measure', u'liquidity', u'bond'],
#   [u'loan', u'market', u'bid', u'price', u'spread'],
#   [u'debt',
#    u'financing',
#    u'business',
#    u'quarter',
#    u'demand',
#    u'credit',
#    u'credit',
#    u'standard',
#    u'term',
#    u'bank'],
#   [u'public',
#    u'equity',
#    u'issuance',
#    u'firm',
#    u'pace',
#    u'issuance',
#    u'firm',
#    u'bank',
#    u'share',
#    u'proceed',
#    u'capital',
#    u'injection'],
#   [u'financing', u'condition', u'estate'],
#   [u'index', u'property', u'price', u'drop', u'index', u'level'],
#   [u'rate', u'loan', u'security', u'pool'],
#   [u'rate', u'mortgage', u'period', u'range', u'value', u'month'],
#   [u'credit', u'month', u'decline', u'credit'],
#   [u'contrast', u'spread', u'auto', u'loan', u'downtrend'],
#   [u'rate', u'consumer', u'loan', u'month'],
#   [u'issuance',
#    u'credit',
#    u'card',
#    u'security',
#    u'extension',
#    u'safe-harbor',
#    u'rule',
#    u'handling',
#    u'asset',
#    u'bank',
#    u'receivership'],
#   [u'bank',
#    u'credit',
#    u'contract',
#    u'increase',
#    u'bank',
#    u'security',
#    u'holding',
#    u'offset',
#    u'drop',
#    u'loan'],
#   [u'loan', u'estate', u'loan'],
#   [u'fraction',
#    u'bank',
#    u'credit',
#    u'policy',
#    u'estate',
#    u'loan',
#    u'quarter',
#    u'lending',
#    u'standard',
#    u'type',
#    u'loan',
#    u'lending',
#    u'practice'],
#   [u'standard', u'term', u'loan', u'type', u'demand', u'loan'],
#   [u'growth',
#    u'deposit',
#    u'time',
#    u'deposit',
#    u'money',
#    u'market',
#    u'fund',
#    u'pace',
#    u'response',
#    u'yield',
#    u'asset'],
#   [u'base',
#    u'bank',
#    u'reserve',
#    u'contraction',
#    u'credit',
#    u'liquidity',
#    u'credit',
#    u'facility',
#    u'purchase',
#    u'agency',
#    u'debt'],
#   [u'period', u'yield', u'economy', u'volatility', u'net'],
#   [u'bond',
#    u'offering',
#    u'start',
#    u'year',
#    u'concern',
#    u'investor',
#    u'debt',
#    u'government',
#    u'yield',
#    u'extent',
#    u'country',
#    u'issue',
#    u'concern',
#    u'investor'],
#   [u'bank', u'policy', u'rate'],
#   [u'equity', u'price', u'period'],
#   [u'stock',
#    u'profit',
#    u'report',
#    u'quarter',
#    u'bank',
#    u'concern',
#    u'health',
#    u'banking'],
#   [u'index',
#    u'exchange',
#    u'value',
#    u'dollar',
#    u'perception',
#    u'growth',
#    u'prospect'],
#   [u'concern',
#    u'policy',
#    u'tightening',
#    u'recovery',
#    u'dollar',
#    u'appreciation',
#    u'currency',
#    u'period'],
#   [u'outlook',
#    u'forecast',
#    u'meeting',
#    u'staff',
#    u'estimate',
#    u'increase',
#    u'quarter'],
#   [u'revision',
#    u'inventory',
#    u'investment',
#    u'staff',
#    u'projection',
#    u'increase',
#    u'demand'],
#   [u'business', u'pace', u'inventory', u'liquidation', u'staff'],
#   [u'result', u'economy', u'production', u'alignment', u'sale', u'staff'],
#   [u'fluctuation', u'inventory', u'development', u'staff'],
#   [u'information',
#    u'labor',
#    u'market',
#    u'production',
#    u'staff',
#    u'expectation',
#    u'housing',
#    u'activity',
#    u'trajectory',
#    u'data',
#    u'business',
#    u'capital',
#    u'spending',
#    u'expectation'],
#   [u'staff',
#    u'project',
#    u'recovery',
#    u'activity',
#    u'year',
#    u'growth',
#    u'stance',
#    u'policy',
#    u'factor',
#    u'spending',
#    u'production',
#    u'year'],
#   [u'staff', u'resource', u'slack', u'period'],
#   [u'surprise',
#    u'price',
#    u'datum',
#    u'slack',
#    u'resource',
#    u'utilization',
#    u'pressure',
#    u'cost',
#    u'inflation',
#    u'expectation'],
#   [u'staff',
#    u'projection',
#    u'consumer',
#    u'energy',
#    u'price',
#    u'headline',
#    u'inflation',
#    u'core',
#    u'inflation',
#    u'rate',
#    u'inflation'],
#   [u'participant',
#    u'view',
#    u'condition',
#    u'outlook',
#    u'conjunction',
#    u'meeting',
#    u'meeting',
#    u'member',
#    u'president',
#    u'projection',
#    u'growth',
#    u'unemployment',
#    u'rate',
#    u'consumer',
#    u'price',
#    u'inflation',
#    u'year',
#    u'horizon'],
#   [u'projection',
#    u'participant',
#    u'assessment',
#    u'rate',
#    u'time',
#    u'policy',
#    u'absence',
#    u'shock'],
#   [u'discussion',
#    u'situation',
#    u'outlook',
#    u'participant',
#    u'data',
#    u'information',
#    u'business',
#    u'contact',
#    u'growth',
#    u'quarter',
#    u'firm',
#    u'payroll',
#    u'pace',
#    u'risk',
#    u'outlook',
#    u'growth',
#    u'bit'],
#   [u'participant',
#    u'news',
#    u'line',
#    u'expectation',
#    u'growth',
#    u'inflation',
#    u'condition',
#    u'balance',
#    u'met'],
#   [u'participant', u'view', u'outlook'],
#   [u'evidence',
#    u'pace',
#    u'inventory',
#    u'decumulation',
#    u'quarter',
#    u'firm',
#    u'output',
#    u'production',
#    u'alignment',
#    u'sale'],
#   [u'participant',
#    u'pace',
#    u'inventory',
#    u'reduction',
#    u'indication',
#    u'firm',
#    u'inventory',
#    u'overhang'],
#   [u'business',
#    u'contact',
#    u'reluctance',
#    u'inventory',
#    u'increase',
#    u'payroll',
#    u'capacity'],
#   [u'participant',
#    u'recovery',
#    u'pickup',
#    u'output',
#    u'employment',
#    u'growth',
#    u'recovery',
#    u'recession'],
#   [u'pace',
#    u'expansion',
#    u'improvement',
#    u'labor',
#    u'market',
#    u'year',
#    u'unemployment'],
#   [u'participant',
#    u'economy',
#    u'decline',
#    u'unemployment',
#    u'rate',
#    u'condition',
#    u'availability',
#    u'credit'],
#   [u'participant', u'upside', u'risk', u'outlook', u'growth'],
#   [u'participant', u'inflation', u'time'],
#   [u'risk',
#    u'output',
#    u'potential',
#    u'couple',
#    u'year',
#    u'inflation',
#    u'rate',
#    u'mandate',
#    u'employment',
#    u'price',
#    u'stability',
#    u'risk',
#    u'inflation',
#    u'expectation',
#    u'challenge',
#    u'accommodation',
#    u'manner',
#    u'inflation',
#    u'risk',
#    u'upside',
#    u'medium',
#    u'term'],
#   [u'weakness',
#    u'labor',
#    u'market',
#    u'concern',
#    u'prospect',
#    u'job',
#    u'growth',
#    u'source',
#    u'uncertainty',
#    u'outlook',
#    u'outlook',
#    u'consumer',
#    u'spending'],
#   [u'pace', u'layoff', u'month', u'firm'],
#   [u'fraction',
#    u'individual',
#    u'time',
#    u'reason',
#    u'level',
#    u'workweek',
#    u'increase',
#    u'payroll',
#    u'time',
#    u'hour',
#    u'recovery'],
#   [u'business',
#    u'contact',
#    u'hiring',
#    u'increase',
#    u'demand',
#    u'employee',
#    u'hour',
#    u'productivity',
#    u'need',
#    u'employee'],
#   [u'business',
#    u'productivity',
#    u'gain',
#    u'quarters',
#    u'firm',
#    u'worker',
#    u'term',
#    u'demand',
#    u'product'],
#   [u'productivity',
#    u'growth',
#    u'quarters',
#    u'job',
#    u'growth',
#    u'productivity',
#    u'level'],
#   [u'rise',
#    u'employment',
#    u'worker',
#    u'month',
#    u'experience',
#    u'use',
#    u'help',
#    u'increase',
#    u'job',
#    u'growth'],
#   [u'participant',
#    u'datum',
#    u'evidence',
#    u'growth',
#    u'demand',
#    u'good',
#    u'service',
#    u'variation',
#    u'sector'],
#   [u'report', u'holiday', u'sale'],
#   [u'consumer', u'pricing'],
#   [u'contact',
#    u'investment',
#    u'outlay',
#    u'resolution',
#    u'uncertainty',
#    u'sale',
#    u'prospect',
#    u'tax',
#    u'policy',
#    u'excess',
#    u'capacity',
#    u'need',
#    u'production',
#    u'facility'],
#   [u'datum', u'growth', u'business', u'spending', u'equipment', u'month'],
#   [u'evidence',
#    u'spending',
#    u'opportunity',
#    u'cost',
#    u'replacement',
#    u'investment',
#    u'firm',
#    u'downturn'],
#   [u'participant',
#    u'investment',
#    u'housing',
#    u'construction',
#    u'contribution',
#    u'growth',
#    u'year'],
#   [u'construction',
#    u'trend',
#    u'fundamental',
#    u'financing',
#    u'constraint',
#    u'role'],
#   [u'growth', u'growth', u'export', u'recovery', u'production'],
#   [u'policymaker', u'condition', u'balance', u'growth'],
#   [u'volatility',
#    u'equity',
#    u'price',
#    u'period',
#    u'equity',
#    u'price',
#    u'index',
#    u'credit',
#    u'spread',
#    u'market',
#    u'year'],
#   [u'survey',
#    u'evidence',
#    u'bank',
#    u'tightening',
#    u'standard',
#    u'type',
#    u'business',
#    u'consumer',
#    u'loan',
#    u'estate',
#    u'loan',
#    u'exception'],
#   [u'evidence', u'bank', u'opportunity', u'lending'],
#   [u'headline',
#    u'inflation',
#    u'swing',
#    u'energy',
#    u'price',
#    u'core',
#    u'measure',
#    u'inflation'],
#   [u'participant',
#    u'core',
#    u'inflation',
#    u'quarters',
#    u'increase',
#    u'price',
#    u'index',
#    u'shelter',
#    u'behavior',
#    u'inflation',
#    u'signal',
#    u'inflation',
#    u'trend'],
#   [u'report', u'business', u'contact', u'price', u'discounting', u'power'],
#   [u'price',
#    u'week',
#    u'participant',
#    u'upward',
#    u'pressure',
#    u'commodity',
#    u'price',
#    u'activity',
#    u'inflation',
#    u'risk'],
#   [u'degree', u'slack', u'resource', u'utilization', u'risk', u'inflation'],
#   [u'survey',
#    u'measure',
#    u'future',
#    u'inflation',
#    u'measure',
#    u'inflation',
#    u'expectation',
#    u'inflation',
#    u'risk',
#    u'concern',
#    u'market',
#    u'participant',
#    u'risk',
#    u'inflation',
#    u'deficit',
#    u'size',
#    u'balance',
#    u'sheet'],
#   [u'participant',
#    u'slack',
#    u'resource',
#    u'utilization',
#    u'judgment',
#    u'degree',
#    u'slack'],
#   [u'extension',
#    u'emergency',
#    u'unemployment',
#    u'insurance',
#    u'benefit',
#    u'unemployment',
#    u'rate',
#    u'level',
#    u'downturn',
#    u'job',
#    u'labor',
#    u'force'],
#   [u'effect',
#    u'estimate',
#    u'percentage',
#    u'point',
#    u'increase',
#    u'unemployment',
#    u'rate',
#    u'unemployment',
#    u'rate',
#    u'slack',
#    u'resource',
#    u'utilization',
#    u'period',
#    u'unemployment'],
#   [u'participant',
#    u'necessity',
#    u'labor',
#    u'sector',
#    u'recovery',
#    u'proceed',
#    u'loss',
#    u'skill',
#    u'level',
#    u'unemployment',
#    u'separation',
#    u'economy',
#    u'output',
#    u'experience',
#    u'shock',
#    u'effect'],
#   [u'hand',
#    u'productivity',
#    u'gain',
#    u'business',
#    u'contact',
#    u'output',
#    u'measure',
#    u'level',
#    u'unemployment',
#    u'rate',
#    u'indication',
#    u'slack',
#    u'resource',
#    u'utilization',
#    u'measure',
#    u'output',
#    u'gap'],
#   [u'discussion',
#    u'policy',
#    u'period',
#    u'member',
#    u'change',
#    u'asset',
#    u'purchase',
#    u'program',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'meeting',
#    u'asset',
#    u'purchase',
#    u'program',
#    u'completion',
#    u'outlook',
#    u'condition',
#    u'meeting'],
#   [u'intention',
#    u'total',
#    u'agency',
#    u'agency',
#    u'debt',
#    u'end',
#    u'quarter',
#    u'pace',
#    u'purchase',
#    u'transition',
#    u'market'],
#   [u'purchase', u'security', u'light', u'outlook', u'condition', u'market'],
#   [u'change', u'wording', u'possibility', u'point', u'security', u'security'],
#   [u'member',
#    u'change',
#    u'statement',
#    u'condition',
#    u'asset',
#    u'purchase',
#    u'program'],
#   [u'percent',
#    u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'outlook',
#    u'recovery',
#    u'anticipation',
#    u'condition',
#    u'level',
#    u'resource',
#    u'utilization',
#    u'inflation',
#    u'trend',
#    u'inflation',
#    u'expectation',
#    u'rate',
#    u'period'],
#   [u'member', u'path', u'rate', u'evolution', u'outlook'],
#   [u'member',
#    u'member',
#    u'exception',
#    u'functioning',
#    u'market',
#    u'interbank',
#    u'market',
#    u'impairment'],
#   [u'statement', u'meeting', u'liquidity', u'lending'],
#   [u'member', u'liquidity', u'swap', u'arrangement', u'bank'],
#   [u'addition', u'statement', u'auction', u'credit', u'credit', u'auction'],
#   [u'statement',
#    u'expiration',
#    u'date',
#    u'loan',
#    u'security',
#    u'loan',
#    u'type',
#    u'collateral'],
#   [u'member', u'plan', u'stability', u'growth'],
#   [u'conclusion',
#    u'discussion',
#    u'transaction',
#    u'accordance',
#    u'policy',
#    u'directive'],
#   [u'condition', u'price', u'stability', u'growth', u'output'],
#   [u'objective',
#    u'condition',
#    u'reserve',
#    u'market',
#    u'fund',
#    u'trading',
#    u'range',
#    u'percent'],
#   [u'agency',
#    u'debt',
#    u'agency',
#    u'period',
#    u'aim',
#    u'support',
#    u'credit',
#    u'market',
#    u'activity'],
#   [u'timing',
#    u'pace',
#    u'purchase',
#    u'condition',
#    u'market',
#    u'security',
#    u'assessment',
#    u'credit',
#    u'market',
#    u'condition'],
#   [u'purchase', u'agency', u'debt', u'agency', u'end', u'quarter'],
#   [u'purchase', u'security', u'size', u'balance', u'sheet', u'month'],
#   [u'dollar',
#    u'roll',
#    u'transaction',
#    u'settlement',
#    u'agency',
#    u'transaction',
#    u'end',
#    u'quarter'],
#   [u'development',
#    u'balance',
#    u'sheet',
#    u'attainment',
#    u'time',
#    u'objective',
#    u'employment',
#    u'price',
#    u'stability'],
#   [u'information', u'activity', u'deterioration', u'labor', u'market'],
#   [u'spending',
#    u'rate',
#    u'labor',
#    u'market',
#    u'income',
#    u'growth',
#    u'housing',
#    u'wealth',
#    u'credit'],
#   [u'spending',
#    u'equipment',
#    u'software',
#    u'investment',
#    u'structure',
#    u'employer',
#    u'payroll'],
#   [u'firm', u'inventory', u'stock', u'alignment', u'sale'],
#   [u'bank', u'lending', u'contract', u'market', u'condition', u'growth'],
#   [u'pace',
#    u'recovery',
#    u'time',
#    u'return',
#    u'level',
#    u'resource',
#    u'utilization',
#    u'context',
#    u'price',
#    u'stability'],
#   [u'resource',
#    u'slack',
#    u'cost',
#    u'pressure',
#    u'inflation',
#    u'expectation',
#    u'stable',
#    u'inflation',
#    u'time'],
#   [u'target',
#    u'range',
#    u'fund',
#    u'rate',
#    u'percent',
#    u'condition',
#    u'rate',
#    u'resource',
#    u'utilization',
#    u'inflation',
#    u'trend',
#    u'inflation',
#    u'expectation',
#    u'level',
#    u'fund',
#    u'rate',
#    u'period'],
#   [u'support',
#    u'mortgage',
#    u'lending',
#    u'housing',
#    u'market',
#    u'condition',
#    u'credit',
#    u'market',
#    u'process',
#    u'agency',
#    u'security',
#    u'agency',
#    u'debt'],
#   [u'order',
#    u'transition',
#    u'market',
#    u'pace',
#    u'purchase',
#    u'transaction',
#    u'end',
#    u'quarter'],
#   [u'purchase', u'security', u'light', u'outlook', u'condition', u'market'],
#   [u'light', u'functioning', u'market', u'liquidity', u'lending'],
#   [u'addition', u'liquidity', u'swap', u'arrangement', u'bank'],
#   [u'process', u'auction', u'credit', u'credit', u'auction'],
#   [u'expiration',
#    u'date',
#    u'set',
#    u'loan',
#    u'security',
#    u'loan',
#    u'type',
#    u'collateral'],
#   [u'plan', u'stability', u'growth'],
#   [u'condition', u'warrant', u'level', u'fund', u'rate', u'period'],
#   [u'month',
#    u'condition',
#    u'condition',
#    u'rate',
#    u'period',
#    u'time',
#    u'groundwork',
#    u'imbalance',
#    u'increase',
#    u'inflation',
#    u'expectation'],
#   [u'expectation', u'fund', u'rate', u'time--rather', u'period'],
#   [u'fund',
#    u'rate',
#    u'risk',
#    u'imbalance',
#    u'increase',
#    u'inflation',
#    u'expectation',
#    u'support',
#    u'recovery']],
#  [[u'i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new', u'true'],
#   [u'main', u'secondary'],
#   [u'joint'],
#   [u'alternate'],
#   [u'annual', u'organizational', u'alternate'],
#   [u'elected', u'alternate'],
#   [u'unanimous', u'official', u'official'],
#   [u'unanimous', u'noncitizen'],
#   [u'unanimous'],
#   [u'unanimous', u'subject', u'satisfactory'],
#   [u'annual',
#    u'domestic',
#    u'open',
#    u'foreign',
#    u'continuing',
#    u'mortgage-backed'],
#   [u'reverse'],
#   [u'internal'],
#   [u'unanimous',
#    u'direct',
#    u'temporary',
#    u'short-term',
#    u'foreign',
#    u'international',
#    u'fiscal'],
#   [u'open', u'amended'],
#   [u'necessary', u'recent', u'domestic'],
#   [u'direct',
#    u'open',
#    u'foreign',
#    u'international',
#    u'regular',
#    u'federal',
#    u'individual',
#    u'open',
#    u'direct',
#    u'repo',
#    u'competitive',
#    u'reasonable'],
#   [u'effective', u'open', u'mbs-related'],
#   [u'effective', u'open', u'overnight', u'direct', u'competitive'],
#   [u'lending', u'consistent', u'reasonable', u'total', u'specific'],
#   [u'single'],
#   [u'effective',
#    u'open',
#    u'short-term',
#    u'foreign',
#    u'international',
#    u'fiscal',
#    u'pursuant'],
#   [u'direct',
#    u'comparable',
#    u'available',
#    u'appropriate',
#    u'direct',
#    u'corresponding',
#    u'foreign',
#    u'international',
#    u'fiscal'],
#   [u'appropriate'],
#   [u'intermeeting', u'exceptional', u'intended', u'federal', u'recent'],
#   [u'recent',
#    u'long-run',
#    u'sustainable',
#    u'economic',
#    u'economic',
#    u'financial',
#    u'monetary',
#    u'intermeeting'],
#   [u'consistent', u'feasible'],
#   [u'unanimous', u'foreign', u'foreign', u'procedural', u'foreign'],
#   [u'included'],
#   [u'necessary', u'foreign', u'express', u'pursuant', u'procedural'],
#   [u'following',
#    u'foreign',
#    u'forward',
#    u'open',
#    u'foreign',
#    u'monetary',
#    u'international',
#    u'financial',
#    u'australian',
#    u'brazilian',
#    u'canadian',
#    u'danish',
#    u'japanese',
#    u'mexican',
#    u'norwegian',
#    u'swedish',
#    u'swiss'],
#   [u'outstanding', u'foreign'],
#   [u'foreign', u'foreign', u'reciprocal', u'outstanding', u'exceptional'],
#   [u'overall', u'open', u'foreign'],
#   [u'overall',
#    u'open',
#    u'foreign',
#    u'defined',
#    u'net',
#    u'individual',
#    u'foreign'],
#   [u'single',
#    u'foreign',
#    u'defined',
#    u'outstanding',
#    u'future',
#    u'outstanding',
#    u'future'],
#   [u'reciprocal', u'following', u'foreign'],
#   [u'foreign'],
#   [u'equivalent'],
#   [u'proposed', u'new'],
#   [u'foreign'],
#   [u'foreign', u'foreign', u'central', u'nonmarket'],
#   [u'normal', u'foreign', u'central', u'foreign'],
#   [u'foreign', u'central', u'foreign', u'specific'],
#   [u'foreign'],
#   [u'foreign', u'adequate', u'average', u'calculated'],
#   [u'selling', u'outright', u'foreign', u'various', u'foreign'],
#   [u'appropriate', u'foreign', u'foreign', u'central'],
#   [u'pursuant', u'foreign'],
#   [u'foreign', u'alternate'],
#   [u'manager', u'recent', u'contemplated', u'manager'],
#   [u'foreign', u'foreign', u'foreign'],
#   [u'appropriate'],
#   [u'pertinent', u'foreign', u'appropriate'],
#   [u'foreign'],
#   [u'foreign', u'disorderly', u'consistent'],
#   [u'forward', u'foreign'],
#   [u'reciprocal', u'selected', u'foreign', u'central'],
#   [u'central', u'international', u'monetary'],
#   [u'adjust', u'probable'],
#   [u'particular', u'facilitate'],
#   [u'foreign'],
#   [u'continuous'],
#   [u'appropriate', u'foreign', u'monetary'],
#   [u'consistent'],
#   [u'procedural'],
#   [u'pursuant',
#    u'foreign',
#    u'foreign',
#    u'manager',
#    u'following',
#    u'procedural',
#    u'foreign'],
#   [u'pursuant'],
#   [u'feasible', u'available'],
#   [u'overall', u'open', u'foreign', u'recent', u'regular'],
#   [u'single', u'foreign'],
#   [u'substantial', u'particular'],
#   [u'foreign', u'larger'],
#   [u'feasible', u'available', u'feasible', u'available'],
#   [u'overall', u'open', u'foreign', u'recent', u'regular'],
#   [u'foreign', u'larger'],
#   [u'routine'],
#   [u'domestic', u'foreign', u'financial'],
#   [u'supportive', u'economic', u'intermeeting'],
#   [u'minimal'],
#   [u'imminent', u'special'],
#   [u'open', u'intermeeting'],
#   [u'outright'],
#   [u'unanimous'],
#   [u'interim', u'prepaid'],
#   [u'open', u'foreign', u'intermeeting'],
#   [u'current', u'additional'],
#   [u'continuing',
#    u'term',
#    u'one-day',
#    u'smallest',
#    u'primary',
#    u'upper',
#    u'federal'],
#   [u'depository',
#    u'backup',
#    u'temporary',
#    u'discouraging',
#    u'routine',
#    u'available'],
#   [u'financial', u'financial'],
#   [u'necessary', u'financial', u'economic'],
#   [u'appropriate', u'primary', u'overnight', u'primary', u'federal'],
#   [u'optimal', u'eventual', u'suitable', u'monetary', u'longer'],
#   [u'normal',
#    u'technical',
#    u'notable',
#    u'new',
#    u'necessary',
#    u'appropriate',
#    u'monetary',
#    u'proper',
#    u'accommodative'],
#   [u'final'],
#   [u'eventual', u'alternative', u'monetary'],
#   [u'accommodative',
#    u'excess',
#    u'ioer',
#    u'primary',
#    u'broader',
#    u'excess',
#    u'prepaid'],
#   [u'primary', u'small-scale', u'able'],
#   [u'late'],
#   [u'final'],
#   [u'feasible',
#    u'gradual',
#    u'normal',
#    u'monetary',
#    u'high',
#    u'subsequent',
#    u'large-scale',
#    u'financial',
#    u'ioer',
#    u'federal',
#    u'ioer',
#    u'federal',
#    u'ioer',
#    u'federal',
#    u'federal'],
#   [u'appropriate'],
#   [u'ioer', u'federal', u'key', u'accommodative', u'monetary'],
#   [u'appropriate',
#    u'eventual',
#    u'ioer',
#    u'federal',
#    u'short-term',
#    u'ioer',
#    u'federal',
#    u'appropriate'],
#   [u'better', u'eventual'],
#   [u'longer-run', u'monetary', u'federal', u'monetary', u'federal'],
#   [u'primary', u'federal', u'ioer', u'beneficial'],
#   [u'ioer'],
#   [u'ioer'],
#   [u'ultimate', u'useful', u'longer-run', u'eventual'],
#   [u'eventual'],
#   [u'unanimous', u'appropriate'],
#   [u'appropriate', u'financial'],
#   [u'shorter-term'],
#   [u'appropriate'],
#   [u'desirable'],
#   [u'future',
#    u'gradual',
#    u'helpful',
#    u'adverse',
#    u'economic',
#    u'self-sustaining',
#    u'financial',
#    u'appropriate',
#    u'short-term'],
#   [u'important',
#    u'near',
#    u'predictable',
#    u'accommodative',
#    u'monetary',
#    u'large'],
#   [u'economic'],
#   [u'economic', u'recent'],
#   [u'fourth'],
#   [u'nonresidential'],
#   [u'recent', u'sizable', u'economic'],
#   [u'industrial', u'solid', u'fourth'],
#   [u'final', u'elevated', u'stayed', u'weak'],
#   [u'core'],
#   [u'moderate',
#    u'three-month',
#    u'private',
#    u'nonfarm',
#    u'negative',
#    u'widespread'],
#   [u'unchanged'],
#   [u'likely', u'adverse'],
#   [u'weak', u'total', u'average', u'ongoing', u'long-term', u'unemployed'],
#   [u'total', u'industrial', u'sixth', u'consecutive'],
#   [u'electric', u'natural', u'cold'],
#   [u'large', u'widespread'],
#   [u'fourth', u'solid', u'slower'],
#   [u'fourth', u'average', u'monthly', u'little', u'smaller'],
#   [u'available', u'near-term'],
#   [u'late'],
#   [u'strong', u'real', u'personal'],
#   [u'retail', u'bad', u'new'],
#   [u'fundamental', u'real', u'disposable', u'weak'],
#   [u'early', u'low', u'relative', u'historical'],
#   [u'second'],
#   [u'30-year', u'fixed-rate', u'low'],
#   [u'single-family', u'scheduled', u'first-time'],
#   [u'earlier'],
#   [u'new'],
#   [u'single-family', u'little'],
#   [u'slow', u'modest', u'new', u'sufficient', u'unsold', u'new'],
#   [u'real', u'fourth', u'slight', u'previous'],
#   [u'high-tech', u'particular', u'rapid', u'fourth', u'high-tech'],
#   [u'fourth'],
#   [u'high-tech', u'little', u'fourth'],
#   [u'nonresidential', u'poor'],
#   [u'real', u'outside', u'nominal', u'faster', u'fourth'],
#   [u'real', u'fourth'],
#   [u'sizable', u'real', u'nonfarm', u'modest', u'real'],
#   [u'available',
#    u'sizable',
#    u'wholesale',
#    u'appreciable',
#    u'real',
#    u'gross',
#    u'domestic',
#    u'fourth'],
#   [u'modest'],
#   [u'non-energy', u'early', u'modest'],
#   [u'modest', u'second'],
#   [u'near-term', u'median', u'lower', u'narrow', u'past'],
#   [u'international', u'sharp', u'nominal'],
#   [u'large', u'agricultural', u'robust'],
#   [u'total'],
#   [u'incoming', u'advanced', u'foreign', u'fourth', u'moderate'],
#   [u'elevated', u'mixed'],
#   [u'private'],
#   [u'gradual', u'international'],
#   [u'fourth', u'slower'],
#   [u'robust'],
#   [u'outsized'],
#   [u'12-month', u'advanced', u'foreign'],
#   [u'elevated'],
#   [u'federal', u'unchanged', u'extended', u'little'],
#   [u'intermeeting',
#    u'expected',
#    u'federal',
#    u'federal',
#    u'interpreted',
#    u'large-scale',
#    u'protracted',
#    u'accommodative',
#    u'monetary'],
#   [u'10-year', u'nominal', u'unchanged'],
#   [u'5-year', u'inflation-protected', u'higher', u'owing'],
#   [u'supportive', u'economic', u'intermeeting', u'short-term', u'stable'],
#   [u'offered', u'overnight', u'three-month', u'low', u'six-month'],
#   [u'a2', u'commercial', u'aa-rated', u'asset-backed', u'steady', u'low'],
#   [u'strong', u'seasonal', u'outstanding', u'downward', u'short-term'],
#   [u'year-end',
#    u'short-term',
#    u'modest',
#    u'ample',
#    u'repo',
#    u'year-end',
#    u'negative'],
#   [u'lower', u'intermeeting', u'little'],
#   [u'higher', u'intermeeting', u'broad', u'reversed', u'elevated'],
#   [u'expected', u'real', u'real', u'10-year', u'rough', u'average', u'past'],
#   [u'intermeeting', u'investment-grade', u'speculative-grade', u'corporate'],
#   [u'bid-asked', u'corporate', u'corporate', u'steady'],
#   [u'leveraged', u'average', u'bid-asked'],
#   [u'overall',
#    u'net',
#    u'nonfinancial',
#    u'near',
#    u'fourth',
#    u'consistent',
#    u'weak',
#    u'tight'],
#   [u'gross',
#    u'nonfinancial',
#    u'solid',
#    u'financial',
#    u'large',
#    u'issued',
#    u'troubled'],
#   [u'commercial', u'real', u'strained'],
#   [u'commercial', u'2002'],
#   [u'commercial', u'mortgage-backed'],
#   [u'average',
#    u'30-year',
#    u'fixed-rate',
#    u'residential',
#    u'intermeeting',
#    u'narrow',
#    u'recent'],
#   [u'10th', u'consecutive', u'owing', u'steep', u'revolving'],
#   [u'new', u'early'],
#   [u'high', u'recent'],
#   [u'asset-backed', u'minimal', u'temporary', u'securitized'],
#   [u'commercial', u'large', u'total'],
#   [u'industrial', u'commercial', u'real'],
#   [u'substantial', u'commercial', u'real', u'fourth'],
#   [u'major'],
#   [u'liquid', u'robust', u'small', u'retail', u'mutual', u'rapid', u'low'],
#   [u'monetary', u'total', u'flat', u'outstanding'],
#   [u'intermeeting',
#    u'benchmark',
#    u'sovereign',
#    u'advanced',
#    u'foreign',
#    u'little'],
#   [u'global',
#    u'sovereign',
#    u'fiscal',
#    u'reluctant',
#    u'greek',
#    u'sovereign',
#    u'lesser',
#    u'fiscal'],
#   [u'major', u'foreign', u'central', u'unchanged'],
#   [u'foreign', u'intermeeting'],
#   [u'european', u'financial', u'early', u'fourth'],
#   [u'broad', u'nominal', u'foreign', u'better'],
#   [u'global'],
#   [u'real', u'fourth'],
#   [u'upward', u'final', u'unchanged'],
#   [u'nonfarm'],
#   [u'closer'],
#   [u'economic'],
#   [u'incoming',
#    u'industrial',
#    u'consistent',
#    u'lower-than-anticipated',
#    u'recent'],
#   [u'moderate',
#    u'economic',
#    u'economic',
#    u'accommodative',
#    u'monetary',
#    u'past'],
#   [u'forecast'],
#   [u'significant',
#    u'incoming',
#    u'substantial',
#    u'downward',
#    u'longer-term',
#    u'stable'],
#   [u'subdued', u'core'],
#   [u'current', u'economic', u'longer'],
#   [u'longer-run', u'variable', u'appropriate', u'monetary'],
#   [u'economic',
#    u'incoming',
#    u'mixed',
#    u'economic',
#    u'fourth',
#    u'rapid',
#    u'downside',
#    u'economic'],
#   [u'economic', u'moderate', u'financial'],
#   [u'economic'],
#   [u'fourth', u'closer'],
#   [u'slower', u'welcome', u'general', u'large'],
#   [u'great'],
#   [u'economic', u'anticipated', u'relative', u'deep'],
#   [u'moderate', u'slow'],
#   [u'pronounced', u'financial'],
#   [u'general', u'downside', u'economic'],
#   [u'likely'],
#   [u'consistent', u'dual', u'maximum', u'monetary', u'timely', u'tilted'],
#   [u'important', u'important', u'economic'],
#   [u'average', u'recent'],
#   [u'large', u'economic', u'low', u'average', u'gradual', u'economic'],
#   [u'cautious', u'near-term'],
#   [u'able', u'large', u'recent', u'fewer', u'near'],
#   [u'rapid', u'recent', u'sustainable'],
#   [u'temporary',
#    u'recent',
#    u'historical',
#    u'increased',
#    u'temporary',
#    u'broader'],
#   [u'anecdotal', u'moderate', u'substantial'],
#   [u'mixed'],
#   [u'willing', u'sensitive'],
#   [u'business', u'future', u'regulatory', u'substantial', u'little'],
#   [u'solid', u'high-tech', u'recent'],
#   [u'anecdotal'],
#   [u'large', u'residential', u'sizable', u'economic'],
#   [u'commercial', u'weak'],
#   [u'stronger', u'economic', u'industrial'],
#   [u'financial', u'supportive'],
#   [u'intermeeting',
#    u'broad',
#    u'unchanged',
#    u'overall',
#    u'private',
#    u'financial',
#    u'better'],
#   [u'commercial', u'real', u'notable'],
#   [u'anecdotal'],
#   [u'variable'],
#   [u'recent', u'slow', u'recent', u'core', u'misleading'],
#   [u'pricing', u'limited'],
#   [u'recent', u'global', u'economic'],
#   [u'high', u'downside'],
#   [u'expected',
#    u'stable',
#    u'market-based',
#    u'higher',
#    u'medium-term',
#    u'large',
#    u'fiscal'],
#   [u'considerable'],
#   [u'measured', u'relative', u'past'],
#   [u'large--some', u'relative', u'past', u'high'],
#   [u'high',
#    u'long-term',
#    u'permanent',
#    u'potential',
#    u'historical',
#    u'large',
#    u'adverse',
#    u'financial'],
#   [u'recent',
#    u'potential',
#    u'higher',
#    u'standard',
#    u'high',
#    u'accurate',
#    u'usual'],
#   [u'monetary', u'large-scale', u'federal', u'economic', u'financial'],
#   [u'current', u'smooth'],
#   [u'economic', u'financial'],
#   [u'additional'],
#   [u'premature', u'economic', u'financial', u'current'],
#   [u'federal',
#    u'gradual',
#    u'economic',
#    u'economic',
#    u'low',
#    u'stable',
#    u'likely',
#    u'low',
#    u'extended'],
#   [u'short-term', u'economic'],
#   [u'financial', u'significant'],
#   [u'primary'],
#   [u'temporary', u'central'],
#   [u'available', u'term', u'28-day', u'28-day', u'final'],
#   [u'anticipated',
#    u'term',
#    u'asset-backed',
#    u'new-issue',
#    u'commercial',
#    u'mortgage-backed'],
#   [u'prepared', u'necessary', u'financial', u'economic'],
#   [u'following', u'domestic'],
#   [u'monetary', u'financial', u'sustainable'],
#   [u'long-run', u'consistent', u'federal'],
#   [u'intermeeting', u'private', u'economic'],
#   [u'broader', u'private'],
#   [u'housing-related'],
#   [u'outright'],
#   [u'necessary'],
#   [u'ongoing', u'maximum'],
#   [u'economic'],
#   [u'moderate', u'weak', u'modest', u'lower', u'tight'],
#   [u'business', u'reluctant'],
#   [u'better'],
#   [u'financial', u'supportive', u'economic'],
#   [u'economic', u'likely', u'moderate', u'gradual', u'higher'],
#   [u'substantial', u'longer-term', u'likely'],
#   [u'federal',
#    u'economic',
#    u'low',
#    u'stable',
#    u'likely',
#    u'low',
#    u'federal',
#    u'extended'],
#   [u'overall', u'private', u'mortgage-backed'],
#   [u'smooth'],
#   [u'economic', u'financial'],
#   [u'improved', u'financial', u'primary'],
#   [u'temporary', u'central'],
#   [u'term', u'28-day', u'28-day', u'final'],
#   [u'anticipated',
#    u'term',
#    u'asset-backed',
#    u'new-issue',
#    u'commercial',
#    u'mortgage-backed'],
#   [u'necessary', u'financial', u'economic'],
#   [u'advisable',
#    u'economic',
#    u'financial',
#    u'likely',
#    u'low',
#    u'federal',
#    u'extended'],
#   [u'recent',
#    u'economic',
#    u'financial',
#    u'short-term',
#    u'extended',
#    u'future',
#    u'financial'],
#   [u'appropriate', u'federal', u'low', u'low', u'extended'],
#   [u'higher', u'federal', u'longer-run', u'long-run', u'economic']])
